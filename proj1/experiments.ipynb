# %%
source_dir = '/content/dataset/'
destination_dir = '/content/dataset-split/'
training_data_dir = '/content/dataset-split/train'
test_data_dir = '/content/dataset-split/test'
valid_data_dir = '/content/dataset-split/valid'
image_size = (32, 32)

# %%
import os
from enum import Enum
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
import cv2
import random
from PIL import Image
import shutil
import random
import pickle
import pandas as pd

import tensorflow as tf
from tensorflow.keras.optimizers import Adam, SGD, Lion
from keras.regularizers import L2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization, Dropout, RandomRotation, RandomContrast, RandomBrightness, RandomFlip,RandomZoom
from efficientnet.tfkeras import EfficientNetB0
from keras_cv.layers import RandomCutout
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend

# %% [markdown]
# Handling randomness

# %%
seeds = [123,42,9]

# %%
def set_seed(seed=0):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    random.seed(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = "1"
    os.environ['TF_CUDNN_DETERMINISM'] = "1"
    os.environ['PYTHONHASHSEED'] = str(seed)

# %% [markdown]
# Data preprocessing

# %%
# Define the split percentages
train_percent = 0.7
test_percent = 0.2
valid_percent = 0.1

# Create destination directories
train_dir = os.path.join(destination_dir, 'train')
test_dir = os.path.join(destination_dir, 'test')
valid_dir = os.path.join(destination_dir, 'valid')

os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)
os.makedirs(valid_dir, exist_ok=True)
os.makedirs(destination_dir, exist_ok=True)

# Iterate over ttv (train, test, valid) folder
for ttv_folder in os.listdir(source_dir):
    ttv_path = os.path.join(source_dir, ttv_folder)
    if os.path.isdir(ttv_path):
        for class_folder in os.listdir(ttv_path):
            class_path = os.path.join(ttv_path, class_folder)
            if os.path.isdir(class_path):
                # Collect image files, ignoring .DS_Store files
                images = [f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f)) and not f.startswith('.DS_Store')]
                # Shuffle images
                random.shuffle(images)

                # Calculate split sizes
                num_images = len(images)
                num_train = int(num_images * train_percent)
                num_test = int(num_images * test_percent)
                num_valid = num_images - num_train - num_test

                # Split images
                train_images = images[:num_train]
                test_images = images[num_train:num_train + num_test]
                valid_images = images[num_train + num_test:]

                # Move images to respective directories preserving class folder structure
                for img in train_images:
                    src = os.path.join(class_path, img)
                    dst = os.path.join(destination_dir, "train", class_folder, img)
                    os.makedirs(os.path.dirname(dst), exist_ok=True)
                    shutil.copy(src, dst)

                for img in test_images:
                    src = os.path.join(class_path, img)
                    dst = os.path.join(destination_dir, "test", class_folder, img)
                    os.makedirs(os.path.dirname(dst), exist_ok=True)
                    shutil.copy(src, dst)

                for img in valid_images:
                    src = os.path.join(class_path, img)
                    dst = os.path.join(destination_dir, "valid", class_folder, img)
                    os.makedirs(os.path.dirname(dst), exist_ok=True)
                    shutil.copy(src, dst)

# %%
def load_data_from_directory(directory, target_size):
    images = []
    labels = []
    class_names = sorted(os.listdir(directory))
    class_names = [class_name for class_name in class_names if class_name != '.DS_Store']
    for class_name in class_names:
        class_dir = os.path.join(directory, class_name)
        for img_file in os.listdir(class_dir):
            if img_file == '.DS_Store':
                continue  # Skip .DS_Store files
            img_path = os.path.join(class_dir, img_file)
            try:
                img = Image.open(img_path).convert('RGB')  # Ensure images are in RGB format
                img = img.resize(target_size)
                img = np.array(img) / 255.0  # Normalize pixel values to [0, 1]
                images.append(img)
                labels.append(class_name)
            except Exception as e:
                print(f"Error loading image {img_path}: {e}")

    # Convert labels to one-hot encoded vectors
    label_map = {label: i for i, label in enumerate(class_names)}
    labels = [label_map[label] for label in labels]
    labels = tf.keras.utils.to_categorical(labels, num_classes=len(class_names))

    return np.array(images), np.array(labels)

# %%
# Load data from directories
pre_train_images, pre_train_labels = load_data_from_directory(training_data_dir, image_size)
pre_valid_images, pre_valid_labels = load_data_from_directory(valid_data_dir, image_size)
pre_test_images, pre_test_labels = load_data_from_directory(test_data_dir, image_size)

# %%
# Combine images and labels into a single array
train_data = list(zip(pre_train_images, pre_train_labels))
valid_data = list(zip(pre_valid_images, pre_valid_labels))
test_data = list(zip(pre_test_images, pre_test_labels))

# Shuffle the data
np.random.shuffle(train_data)
np.random.shuffle(valid_data)
np.random.shuffle(test_data)

# Unzip the shuffled data
train_images, train_labels = zip(*train_data)
valid_images, valid_labels = zip(*valid_data)
test_images, test_labels = zip(*test_data)

train_images = np.array(train_images)
train_labels = np.array(train_labels)
valid_images = np.array(valid_images)
valid_labels = np.array(valid_labels)
test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %% [markdown]
# ## Pipeline

# %% [markdown]
# Classes

# %%
class AugmentationTechnique(Enum):
    NoAugmentation = 0
    Rotation = 1
    Flipping = 2
    Contrast = 3
    Zoom = 4
    Brightness = 5
    RandomErasing = 6

class ModelType(Enum):
    MobileNet =1
    EfficientNet = 2

class OptimizerType(Enum):
    Adam = 1
    Sgd=2
    Lion=3
class RegularizationType(Enum):
    NoRegularization = 1
    L2 =2
    Dropout=3
def getRegularizer(regularizerType,value):
    match regularizerType:
        case RegularizationType.L2:
            return L2(value)
def getDenseLayer(model,regularization, activation,nodes):
        match regularization['type']:
            case RegularizationType.Dropout:
                model.add(Dropout(rate=regularization['value']))
                model.add(Dense(nodes, activation=activation))
            case RegularizationType.NoRegularization:
                model.add(Dense(nodes, activation=activation))
            case RegularizationType.L2:
                model.add(Dense(nodes, activation=activation, kernel_regularizer=getRegularizer(regularizerType=regularization['type'],value=regularization['value'])))
def getAugmentationLayer(model,technique, seed):
    match technique:
        case AugmentationTechnique.NoAugmentation:
            return;
        case AugmentationTechnique.Rotation:
            model.add(RandomRotation(factor=(-0.2, 0.3),seed=seed))
        case AugmentationTechnique.Flipping:
            model.add(RandomFlip(mode="horizontal_and_vertical", seed=seed))
        case AugmentationTechnique.Brightness:
            model.add(RandomBrightness(factor=(-0.4,0.4),seed=seed))
        case AugmentationTechnique.Contrast:
            model.add(RandomContrast(factor=0.4,seed=seed))
        case AugmentationTechnique.RandomErasing:
            model.add(RandomCutout(height_factor=0.5,width_factor=0.5,seed=seed))
        case AugmentationTechnique.Zoom:
            model.add(RandomZoom(.5, .2,seed=seed))


class Model:
    def fit(self,batch_size,epochs,train_images,train_labels,valid_images,valid_labels):
        pass
    def predict(self,test_images):
        pass
    def __init__(self,optimizer,loss,metrics):
        pass

class CustomMobileNetModel(Model):
    def __init__(self,optimizer,loss,metrics,regularizer,seed,augmentation):
        # Load MobileNetV3Large without the top classification layer
        base_model = MobileNetV3Large(include_top=False, weights='imagenet', input_shape=(32, 32, 3))

        # Freeze the base model layers
        base_model.trainable = False

        # Add additional layers on top of MobileNetV3Large
        model = tf.keras.Sequential()
        getAugmentationLayer(model,technique=augmentation,seed=seed)
        model.add(base_model)
        model.add(GlobalAveragePooling2D())

        getDenseLayer(model=model,regularization=regularizer,activation='relu',nodes=1024)
        model.add(BatchNormalization())
        getDenseLayer(model=model,regularization=regularizer,activation='relu',nodes=512)
        model.add(BatchNormalization())
        getDenseLayer(model=model,regularization=regularizer,activation='softmax',nodes=10)
            # Output layer with size 10 for classification
        model.build(input_shape=(None, 32, 32, 3))
        for layer in model.layers[1:]:
            layer.trainable = True
        # Compile the model
        model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
        self.model=model

    def fit(self,batch_size,epochs,train_images,train_labels,valid_images,valid_labels):
        return self.model.fit(
        train_images,
        train_labels,
        batch_size=batch_size,
        epochs=epochs,
        validation_data=(valid_images,valid_labels)
        )
    def predict(self,test_images):
        return self.model.predict(test_images)

class CustomEfficientNetModel(Model):
    def __init__(self,optimizer,loss,metrics, regularizer,seed,augmentation):
        # Load MobileNetV3Large without the top classification layer
        base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(32, 32, 3))

        # Freeze the base model layers
        base_model.trainable = False
        # Add additional layers on top of EfficientNet
        model = tf.keras.Sequential()
        getAugmentationLayer(model,technique=augmentation,seed=seed)
        model.add(base_model)
        model.add(GlobalAveragePooling2D())
        getDenseLayer(model=model,regularization=regularizer,activation='relu',nodes=1024)
        model.add(BatchNormalization())
        getDenseLayer(model=model,regularization=regularizer,activation='relu',nodes=512)
        model.add(BatchNormalization())
        getDenseLayer(model=model,regularization=regularizer,activation='softmax',nodes=10)
            # Output layer with size 10 for classification
        model.build(input_shape=(None, 32, 32, 3))
        # Compile the model
        model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
        self.model=model
    def fit(self,batch_size,epochs,train_images,train_labels,valid_images,valid_labels):
        return self.model.fit(
        train_images,
        train_labels,
        batch_size=batch_size,
        epochs=epochs,
        validation_data=(valid_images,valid_labels)
        )
    def predict(self,test_images):
        return self.model.predict(test_images)

# %% [markdown]
# Helper functions

# %%
def createModel(modelType, optimizer, loss, metrics, regularizer,seed,augmentation)->Model:
    match modelType:
        case ModelType.MobileNet:
            return CustomMobileNetModel(optimizer=optimizer,loss=loss,metrics=metrics,regularizer=regularizer,seed=seed,augmentation=augmentation)
        case ModelType.EfficientNet:
            return CustomEfficientNetModel(optimizer=optimizer,loss=loss,metrics=metrics,regularizer=regularizer,seed=seed,augmentation=augmentation)

def getAccuracy(y_result, y_test):
    correct_amount =0
    for i, result in enumerate(y_result):
        if result == y_test[i]:
            correct_amount+=1
    return correct_amount/len(y_test)

def getOptimizer(type, learningRate):
    match type:
        case OptimizerType.Adam:
            return Adam(learning_rate=learningRate)
        case OptimizerType.Sgd:
            return SGD(learning_rate=learningRate)
        case OptimizerType.Lion:
            return Lion(learning_rate=learningRate)

# %% [markdown]
# # Arrays containing different hyper-parameter values

# %% [markdown]
# Main pipeline loop

# %%
def performSingleExperiment(modelType, batchSize, epochNumber, augmentation, regularizer, learningRate, seed, optimizerType):
    print(f"Performing experiment with model: {modelType}, batch size: {batchSize}, epochs: {epochNumber}, augmentation: {augmentation}, regularizer: {regularizer}, learning rate: {learningRate}, seed: {seed}")

    set_seed(seed)

    model = createModel(modelType=modelType,regularizer=regularizer,optimizer=getOptimizer(type=optimizerType,learningRate=learningRate), loss='categorical_crossentropy', metrics=['accuracy'],seed=seed, augmentation=augmentation)
    # train the model
    history = model.fit(batch_size=batchSize,epochs=epochNumber, train_images=train_images[:int(len(train_images)/20)],train_labels=train_labels[:int(len(train_labels)/20)],valid_images=valid_images[:int(len(valid_images)/20)],valid_labels=valid_labels[:int(len(valid_labels)/20)])

    # get accuracy
    y_pred = model.predict(test_images)
    # Convert probabilities to class labels
    predicted_classes = np.argmax(y_pred, axis=1)

    # Get true class labels
    true_classes = np.argmax(test_labels, axis=1)
    accuracy = getAccuracy(predicted_classes,true_classes)
    return [accuracy, augmentation,regularizer,batchSize,learningRate,epochNumber, seed], history


def performExperiment(batchSizes, learningRates, numberOfEpochs, augmentationTechniques, regularizers,modelType,seeds,optimizerType):
    results = []
    histories = []
    accuracy=0
    accuracyMean = 0
    accuracyArray=[]

    currentBestBatchSize = batchSizes[0]
    currentBestLearningRate = learningRates[0]
    currentBestNumberOfEpochs = 10
    lastExperimentNumberOfEpochs = 50
    currentBestAugmentation =augmentationTechniques[0]
    currentBestRegularizer = regularizers[0]

    for seed in seeds:
        result,history=performSingleExperiment(modelType=modelType,learningRate=currentBestLearningRate,batchSize=currentBestBatchSize,epochNumber=currentBestNumberOfEpochs,augmentation=currentBestAugmentation,regularizer=currentBestRegularizer,seed=seed,optimizerType=optimizerType)
        results.append(result)
        accuracyArray.append(result[0])
    accuracyMean=np.mean(accuracyArray)
    accuracyArray=[]


    for augmentation in augmentationTechniques[1:]:
        for seed in seeds:
            result,history=performSingleExperiment(modelType=modelType,learningRate=currentBestLearningRate,batchSize=currentBestBatchSize,epochNumber=currentBestNumberOfEpochs,augmentation=augmentation,regularizer=currentBestRegularizer,seed=seed,optimizerType=optimizerType)
            results.append(result)
            accuracyArray.append(result[0])
        if np.mean(accuracyArray)>accuracyMean:
            currentBestAugmentation=augmentation
            accuracyMean=np.mean(accuracyArray)

        accuracyArray=[]


    for regularizer in regularizers[1:]:
        for seed in seeds:
            result,history=performSingleExperiment(modelType=modelType,learningRate=currentBestLearningRate,batchSize=currentBestBatchSize,epochNumber=currentBestNumberOfEpochs,augmentation=currentBestAugmentation,regularizer=regularizer,seed=seed,optimizerType=optimizerType)
            results.append(result)
            accuracyArray.append(result[0])
        if np.mean(accuracyArray)>accuracyMean:
            currentBestRegularizer=regularizer
            accuracyMean=np.mean(accuracyArray)

        accuracyArray=[]


    for batchSize in batchSizes[1:]:
        for seed in seeds:
            result,history=performSingleExperiment(modelType=modelType,learningRate=currentBestLearningRate,batchSize=batchSize,epochNumber=currentBestNumberOfEpochs,augmentation=currentBestAugmentation,regularizer=currentBestRegularizer,seed=seed,optimizerType=optimizerType)
            results.append(result)
            accuracyArray.append(result[0])
        if np.mean(accuracyArray)>accuracyMean:
            currentBestBatchSize=batchSize
            accuracyMean=np.mean(accuracyArray)

        accuracyArray=[]

    for learningRate in learningRates[1:]:
        for seed in seeds:
            result,history=performSingleExperiment(modelType=modelType,learningRate=learningRate,batchSize=currentBestBatchSize,epochNumber=currentBestNumberOfEpochs,augmentation=currentBestAugmentation,regularizer=currentBestRegularizer,seed=seed,optimizerType=optimizerType)
            results.append(result)
            accuracyArray.append(result[0])
        if np.mean(accuracyArray)>accuracyMean:
            currentBestLearningRate=learningRate
            accuracyMean=np.mean(accuracyArray)

        accuracyArray=[]


    result,history=performSingleExperiment(modelType=modelType,learningRate=currentBestLearningRate,batchSize=currentBestBatchSize,epochNumber=lastExperimentNumberOfEpochs,augmentation=currentBestAugmentation,regularizer=currentBestRegularizer,seed=seed,optimizerType=optimizerType)
    accuracy = result[0]
    results.append(result)
    histories.append(history)



    return results, [accuracy,currentBestBatchSize, currentBestLearningRate,currentBestNumberOfEpochs, currentBestAugmentation,currentBestRegularizer], histories

# %% [markdown]
# # Arrays containing different hyper-parameter values

# %%
# training process
batchSizes =[128,64,32]
#batchSizes = [512]
learningRates = [0.01,0.005,0.001]
#learningRates=[0.1]
#numberOfEpochs =[5,10,15]
numberOfEpochs=[10]

# regularization
#regularizers = [{"type":RegularizationType.NoRegularization,"value":0},{"type":RegularizationType.Dropout,"value":0.5},{"type":RegularizationType.L2,"value":0.01}]
regularizers=[{"type":RegularizationType.NoRegularization,"value":0},{"type":RegularizationType.Dropout,"value":0.3},{"type":RegularizationType.Dropout,"value":0.5},{"type":RegularizationType.Dropout,"value":0.8},{"type":RegularizationType.L2,"value":0.001},{"type":RegularizationType.L2,"value":0.01},{"type":RegularizationType.L2,"value":0.1}]

# augmentation
augmentationTechniques =[AugmentationTechnique.NoAugmentation,AugmentationTechnique.Rotation,AugmentationTechnique.Flipping,AugmentationTechnique.Zoom,AugmentationTechnique.Brightness,AugmentationTechnique.RandomErasing]
#augmentationTechniques=[AugmentationTechnique.Flipping]

# %%
results, best, histories = performExperiment(modelType=ModelType.EfficientNet,batchSizes=batchSizes,learningRates=learningRates,numberOfEpochs=numberOfEpochs,augmentationTechniques=augmentationTechniques,regularizers=regularizers,seeds=seeds, optimizerType=OptimizerType.Sgd)
# Out:
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learnign rate: 0.01, seed: 123
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b0_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 16804768/16804768 [==============================] - 0s 0us/step
# Epoch 1/10
# 74/74 [==============================] - 12s 38ms/step - loss: 2.1904 - accuracy: 0.2737 - val_loss: 2.1552 - val_accuracy: 0.2630
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.8051 - accuracy: 0.3776 - val_loss: 2.0554 - val_accuracy: 0.3000
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.6685 - accuracy: 0.4179 - val_loss: 1.9425 - val_accuracy: 0.3178
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.5720 - accuracy: 0.4454 - val_loss: 1.8149 - val_accuracy: 0.3704
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.5004 - accuracy: 0.4713 - val_loss: 1.7014 - val_accuracy: 0.4044
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.4281 - accuracy: 0.4992 - val_loss: 1.6316 - val_accuracy: 0.4333
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.3927 - accuracy: 0.5076 - val_loss: 1.6529 - val_accuracy: 0.3970
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.3546 - accuracy: 0.5222 - val_loss: 1.6263 - val_accuracy: 0.4215
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.3116 - accuracy: 0.5426 - val_loss: 1.6419 - val_accuracy: 0.4193
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.2679 - accuracy: 0.5582 - val_loss: 1.6246 - val_accuracy: 0.4378
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learnign rate: 0.01, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 9s 33ms/step - loss: 2.1857 - accuracy: 0.2727 - val_loss: 2.1584 - val_accuracy: 0.2748
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.7948 - accuracy: 0.3739 - val_loss: 2.0586 - val_accuracy: 0.2704
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.6501 - accuracy: 0.4200 - val_loss: 1.9410 - val_accuracy: 0.3304
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.5581 - accuracy: 0.4454 - val_loss: 1.8105 - val_accuracy: 0.3630
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.4930 - accuracy: 0.4681 - val_loss: 1.6962 - val_accuracy: 0.4163
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.4383 - accuracy: 0.4916 - val_loss: 1.6514 - val_accuracy: 0.4089
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.3833 - accuracy: 0.5147 - val_loss: 1.6233 - val_accuracy: 0.4230
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.3463 - accuracy: 0.5290 - val_loss: 1.6219 - val_accuracy: 0.4193
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.3035 - accuracy: 0.5402 - val_loss: 1.6512 - val_accuracy: 0.4363
# Epoch 10/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.2712 - accuracy: 0.5589 - val_loss: 1.6258 - val_accuracy: 0.4444
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learnign rate: 0.01, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 8s 33ms/step - loss: 2.1810 - accuracy: 0.2711 - val_loss: 2.1589 - val_accuracy: 0.2644
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.7981 - accuracy: 0.3692 - val_loss: 2.0793 - val_accuracy: 0.2896
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.6649 - accuracy: 0.4098 - val_loss: 1.9545 - val_accuracy: 0.3163
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.5691 - accuracy: 0.4416 - val_loss: 1.8210 - val_accuracy: 0.3511
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.5072 - accuracy: 0.4710 - val_loss: 1.7229 - val_accuracy: 0.3681
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.4479 - accuracy: 0.4933 - val_loss: 1.6618 - val_accuracy: 0.4148
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.3954 - accuracy: 0.5148 - val_loss: 1.6234 - val_accuracy: 0.4237
# Epoch 8/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.3400 - accuracy: 0.5250 - val_loss: 1.6361 - val_accuracy: 0.4222
# Epoch 9/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.3158 - accuracy: 0.5384 - val_loss: 1.6262 - val_accuracy: 0.4311
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.2753 - accuracy: 0.5565 - val_loss: 1.6375 - val_accuracy: 0.4281
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Rotation, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learnign rate: 0.01, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 9s 33ms/step - loss: 2.3532 - accuracy: 0.2217 - val_loss: 2.2139 - val_accuracy: 0.1904
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.0897 - accuracy: 0.2834 - val_loss: 2.1423 - val_accuracy: 0.1978
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.9762 - accuracy: 0.3040 - val_loss: 2.0494 - val_accuracy: 0.2630
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.9278 - accuracy: 0.3254 - val_loss: 1.9712 - val_accuracy: 0.2859
# Epoch 5/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.8936 - accuracy: 0.3338 - val_loss: 1.8769 - val_accuracy: 0.3237
# Epoch 6/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.8476 - accuracy: 0.3460 - val_loss: 1.8139 - val_accuracy: 0.3563
# Epoch 7/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.8194 - accuracy: 0.3540 - val_loss: 1.8053 - val_accuracy: 0.3504
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.8078 - accuracy: 0.3610 - val_loss: 1.7969 - val_accuracy: 0.3578
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.7831 - accuracy: 0.3701 - val_loss: 1.7781 - val_accuracy: 0.3570
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.7777 - accuracy: 0.3632 - val_loss: 1.7718 - val_accuracy: 0.3778
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Rotation, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learnign rate: 0.01, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 8s 33ms/step - loss: 2.3545 - accuracy: 0.2250 - val_loss: 2.2032 - val_accuracy: 0.2370
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.0698 - accuracy: 0.2886 - val_loss: 2.1254 - val_accuracy: 0.2570
# Epoch 3/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.9795 - accuracy: 0.3086 - val_loss: 2.0484 - val_accuracy: 0.2719
# Epoch 4/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.9110 - accuracy: 0.3231 - val_loss: 1.9041 - val_accuracy: 0.3511
# Epoch 5/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.8813 - accuracy: 0.3383 - val_loss: 1.8255 - val_accuracy: 0.3696
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.8453 - accuracy: 0.3462 - val_loss: 1.7925 - val_accuracy: 0.3859
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.8117 - accuracy: 0.3584 - val_loss: 1.7548 - val_accuracy: 0.3785
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.7956 - accuracy: 0.3672 - val_loss: 1.7674 - val_accuracy: 0.3822
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.7761 - accuracy: 0.3695 - val_loss: 1.7475 - val_accuracy: 0.3763
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.7692 - accuracy: 0.3715 - val_loss: 1.7362 - val_accuracy: 0.3793
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Rotation, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learnign rate: 0.01, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 9s 34ms/step - loss: 2.3368 - accuracy: 0.2269 - val_loss: 2.2002 - val_accuracy: 0.2378
# Epoch 2/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.0676 - accuracy: 0.2861 - val_loss: 2.1444 - val_accuracy: 0.2615
# Epoch 3/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.9736 - accuracy: 0.3152 - val_loss: 2.0784 - val_accuracy: 0.2881
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.9113 - accuracy: 0.3292 - val_loss: 1.9789 - val_accuracy: 0.2970
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.8732 - accuracy: 0.3363 - val_loss: 1.8886 - val_accuracy: 0.3104
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.8440 - accuracy: 0.3486 - val_loss: 1.8329 - val_accuracy: 0.3407
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.8237 - accuracy: 0.3514 - val_loss: 1.7939 - val_accuracy: 0.3481
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.8005 - accuracy: 0.3540 - val_loss: 1.8070 - val_accuracy: 0.3504
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.7708 - accuracy: 0.3690 - val_loss: 1.7919 - val_accuracy: 0.3570
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.7640 - accuracy: 0.3779 - val_loss: 1.7818 - val_accuracy: 0.3607
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Flipping, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learnign rate: 0.01, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 8s 34ms/step - loss: 2.2021 - accuracy: 0.2665 - val_loss: 2.1612 - val_accuracy: 0.2407
# Epoch 2/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.8869 - accuracy: 0.3471 - val_loss: 2.0696 - val_accuracy: 0.2652
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.7858 - accuracy: 0.3737 - val_loss: 1.9625 - val_accuracy: 0.3044
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.7322 - accuracy: 0.3875 - val_loss: 1.8504 - val_accuracy: 0.3489
# Epoch 5/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.6773 - accuracy: 0.4061 - val_loss: 1.7276 - val_accuracy: 0.3874
# Epoch 6/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.6560 - accuracy: 0.4131 - val_loss: 1.6881 - val_accuracy: 0.4000
# Epoch 7/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.6294 - accuracy: 0.4218 - val_loss: 1.6828 - val_accuracy: 0.3844
# Epoch 8/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.5902 - accuracy: 0.4313 - val_loss: 1.6619 - val_accuracy: 0.4052
# Epoch 9/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.5673 - accuracy: 0.4375 - val_loss: 1.6791 - val_accuracy: 0.4141
# Epoch 10/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.5421 - accuracy: 0.4493 - val_loss: 1.6746 - val_accuracy: 0.4059
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Flipping, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learnign rate: 0.01, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 8s 33ms/step - loss: 2.2123 - accuracy: 0.2590 - val_loss: 2.1650 - val_accuracy: 0.2607
# Epoch 2/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.8775 - accuracy: 0.3472 - val_loss: 2.0721 - val_accuracy: 0.2244
# Epoch 3/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.7868 - accuracy: 0.3733 - val_loss: 1.9552 - val_accuracy: 0.3437
# Epoch 4/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.7224 - accuracy: 0.3940 - val_loss: 1.8322 - val_accuracy: 0.3548
# Epoch 5/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.6808 - accuracy: 0.4000 - val_loss: 1.7280 - val_accuracy: 0.4044
# Epoch 6/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.6334 - accuracy: 0.4215 - val_loss: 1.6952 - val_accuracy: 0.3926
# Epoch 7/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.6154 - accuracy: 0.4301 - val_loss: 1.6898 - val_accuracy: 0.3978
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.5893 - accuracy: 0.4361 - val_loss: 1.6635 - val_accuracy: 0.4030
# Epoch 9/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.5787 - accuracy: 0.4304 - val_loss: 1.6541 - val_accuracy: 0.4059
# Epoch 10/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.5472 - accuracy: 0.4489 - val_loss: 1.6359 - val_accuracy: 0.4230
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Flipping, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learnign rate: 0.01, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 8s 33ms/step - loss: 2.1919 - accuracy: 0.2640 - val_loss: 2.1609 - val_accuracy: 0.2778
# Epoch 2/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.8908 - accuracy: 0.3467 - val_loss: 2.0775 - val_accuracy: 0.2689
# Epoch 3/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.7996 - accuracy: 0.3706 - val_loss: 1.9682 - val_accuracy: 0.3222
# Epoch 4/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.7384 - accuracy: 0.3817 - val_loss: 1.8329 - val_accuracy: 0.3422
# Epoch 5/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.6834 - accuracy: 0.3981 - val_loss: 1.7501 - val_accuracy: 0.3652
# Epoch 6/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.6521 - accuracy: 0.4175 - val_loss: 1.6874 - val_accuracy: 0.3822
# Epoch 7/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.6200 - accuracy: 0.4273 - val_loss: 1.6625 - val_accuracy: 0.4133
# Epoch 8/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.5821 - accuracy: 0.4329 - val_loss: 1.6607 - val_accuracy: 0.3985
# Epoch 9/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.5752 - accuracy: 0.4387 - val_loss: 1.6424 - val_accuracy: 0.4067
# Epoch 10/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.5521 - accuracy: 0.4434 - val_loss: 1.6368 - val_accuracy: 0.4185
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Zoom, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learnign rate: 0.01, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 8s 33ms/step - loss: 2.2757 - accuracy: 0.2441 - val_loss: 2.1843 - val_accuracy: 0.1904
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.9858 - accuracy: 0.3123 - val_loss: 2.0844 - val_accuracy: 0.2719
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.8827 - accuracy: 0.3431 - val_loss: 1.9634 - val_accuracy: 0.3200
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.8258 - accuracy: 0.3613 - val_loss: 1.8657 - val_accuracy: 0.3378
# Epoch 5/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.7743 - accuracy: 0.3691 - val_loss: 1.7657 - val_accuracy: 0.3874
# Epoch 6/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.7457 - accuracy: 0.3831 - val_loss: 1.7015 - val_accuracy: 0.3963
# Epoch 7/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.7179 - accuracy: 0.3887 - val_loss: 1.6943 - val_accuracy: 0.4104
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.6908 - accuracy: 0.4000 - val_loss: 1.6580 - val_accuracy: 0.4163
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.6785 - accuracy: 0.4040 - val_loss: 1.6440 - val_accuracy: 0.4281
# Epoch 10/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.6441 - accuracy: 0.4161 - val_loss: 1.6629 - val_accuracy: 0.4074
# 1688/1688 [==============================] - 16s 9ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Zoom, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learnign rate: 0.01, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 8s 33ms/step - loss: 2.2643 - accuracy: 0.2460 - val_loss: 2.1731 - val_accuracy: 0.2667
# Epoch 2/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.9724 - accuracy: 0.3177 - val_loss: 2.0804 - val_accuracy: 0.2593
# Epoch 3/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.8823 - accuracy: 0.3436 - val_loss: 1.9885 - val_accuracy: 0.3170
# Epoch 4/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.8030 - accuracy: 0.3646 - val_loss: 1.8454 - val_accuracy: 0.3630
# Epoch 5/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.7794 - accuracy: 0.3728 - val_loss: 1.7462 - val_accuracy: 0.3970
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.7408 - accuracy: 0.3760 - val_loss: 1.6961 - val_accuracy: 0.3904
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.7088 - accuracy: 0.3927 - val_loss: 1.6788 - val_accuracy: 0.4022
# Epoch 8/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.6815 - accuracy: 0.4029 - val_loss: 1.6602 - val_accuracy: 0.4000
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.6660 - accuracy: 0.4057 - val_loss: 1.6607 - val_accuracy: 0.4052
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.6536 - accuracy: 0.4153 - val_loss: 1.6554 - val_accuracy: 0.4089
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Zoom, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learnign rate: 0.01, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 9s 35ms/step - loss: 2.2669 - accuracy: 0.2443 - val_loss: 2.1814 - val_accuracy: 0.2607
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.9815 - accuracy: 0.3151 - val_loss: 2.0942 - val_accuracy: 0.2830
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.8831 - accuracy: 0.3388 - val_loss: 1.9983 - val_accuracy: 0.3148
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.8186 - accuracy: 0.3586 - val_loss: 1.8514 - val_accuracy: 0.3333
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.7697 - accuracy: 0.3666 - val_loss: 1.7505 - val_accuracy: 0.3756
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.7461 - accuracy: 0.3797 - val_loss: 1.7002 - val_accuracy: 0.3919
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.7019 - accuracy: 0.3971 - val_loss: 1.6687 - val_accuracy: 0.4000
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.6871 - accuracy: 0.3956 - val_loss: 1.6454 - val_accuracy: 0.4126
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.6725 - accuracy: 0.4014 - val_loss: 1.6436 - val_accuracy: 0.4059
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.6497 - accuracy: 0.4147 - val_loss: 1.6436 - val_accuracy: 0.4156
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Brightness, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learnign rate: 0.01, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 9s 33ms/step - loss: 2.5732 - accuracy: 0.1003 - val_loss: 2.3070 - val_accuracy: 0.1074
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.4522 - accuracy: 0.1061 - val_loss: 2.3095 - val_accuracy: 0.0948
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.4138 - accuracy: 0.1014 - val_loss: 2.3084 - val_accuracy: 0.1037
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.4046 - accuracy: 0.1054 - val_loss: 2.3079 - val_accuracy: 0.0956
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3948 - accuracy: 0.1006 - val_loss: 2.3061 - val_accuracy: 0.1111
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3761 - accuracy: 0.1023 - val_loss: 2.3060 - val_accuracy: 0.1081
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3711 - accuracy: 0.1063 - val_loss: 2.3038 - val_accuracy: 0.1074
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3682 - accuracy: 0.1056 - val_loss: 2.3044 - val_accuracy: 0.1074
# Epoch 9/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.3606 - accuracy: 0.1060 - val_loss: 2.3048 - val_accuracy: 0.1230
# Epoch 10/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.3560 - accuracy: 0.1042 - val_loss: 2.3011 - val_accuracy: 0.1059
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Brightness, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learnign rate: 0.01, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 8s 33ms/step - loss: 2.5824 - accuracy: 0.0953 - val_loss: 2.3032 - val_accuracy: 0.1148
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.4659 - accuracy: 0.1001 - val_loss: 2.3029 - val_accuracy: 0.1074
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.4163 - accuracy: 0.1046 - val_loss: 2.3066 - val_accuracy: 0.1089
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.4056 - accuracy: 0.1011 - val_loss: 2.3084 - val_accuracy: 0.1030
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3888 - accuracy: 0.0977 - val_loss: 2.3037 - val_accuracy: 0.1207
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3802 - accuracy: 0.0978 - val_loss: 2.3034 - val_accuracy: 0.0956
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3739 - accuracy: 0.1033 - val_loss: 2.3114 - val_accuracy: 0.1111
# Epoch 8/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.3716 - accuracy: 0.1019 - val_loss: 2.3074 - val_accuracy: 0.0807
# Epoch 9/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.3589 - accuracy: 0.1012 - val_loss: 2.3065 - val_accuracy: 0.1170
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3568 - accuracy: 0.1018 - val_loss: 2.3039 - val_accuracy: 0.1111
# 1688/1688 [==============================] - 16s 9ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Brightness, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learnign rate: 0.01, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 10s 55ms/step - loss: 2.5701 - accuracy: 0.0981 - val_loss: 2.3080 - val_accuracy: 0.0911
# Epoch 2/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.4598 - accuracy: 0.0995 - val_loss: 2.3074 - val_accuracy: 0.0896
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.4245 - accuracy: 0.1007 - val_loss: 2.3100 - val_accuracy: 0.1007
# Epoch 4/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.4016 - accuracy: 0.0975 - val_loss: 2.3091 - val_accuracy: 0.0970
# Epoch 5/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.3887 - accuracy: 0.1069 - val_loss: 2.3088 - val_accuracy: 0.0911
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3764 - accuracy: 0.0961 - val_loss: 2.3065 - val_accuracy: 0.0985
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3716 - accuracy: 0.1016 - val_loss: 2.3196 - val_accuracy: 0.1044
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3695 - accuracy: 0.1003 - val_loss: 2.3088 - val_accuracy: 0.1133
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3640 - accuracy: 0.1003 - val_loss: 2.3037 - val_accuracy: 0.1193
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3568 - accuracy: 0.0975 - val_loss: 2.3033 - val_accuracy: 0.0867
# 1688/1688 [==============================] - 17s 9ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.RandomErasing, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learnign rate: 0.01, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 10s 38ms/step - loss: 2.3074 - accuracy: 0.2294 - val_loss: 2.2025 - val_accuracy: 0.2274
# Epoch 2/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.0084 - accuracy: 0.3034 - val_loss: 2.1306 - val_accuracy: 0.2200
# Epoch 3/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.9154 - accuracy: 0.3254 - val_loss: 2.0131 - val_accuracy: 0.2837
# Epoch 4/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.8427 - accuracy: 0.3483 - val_loss: 1.9392 - val_accuracy: 0.3148
# Epoch 5/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.7930 - accuracy: 0.3649 - val_loss: 1.8447 - val_accuracy: 0.3519
# Epoch 6/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.7538 - accuracy: 0.3788 - val_loss: 1.7872 - val_accuracy: 0.3556
# Epoch 7/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.7384 - accuracy: 0.3789 - val_loss: 1.7366 - val_accuracy: 0.3852
# Epoch 8/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.7042 - accuracy: 0.3919 - val_loss: 1.7694 - val_accuracy: 0.3593
# Epoch 9/10
# 74/74 [==============================] - 1s 15ms/step - loss: 1.6907 - accuracy: 0.4011 - val_loss: 1.7482 - val_accuracy: 0.3881
# Epoch 10/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.6634 - accuracy: 0.4087 - val_loss: 1.7246 - val_accuracy: 0.3704
# 1688/1688 [==============================] - 17s 9ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.RandomErasing, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learnign rate: 0.01, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 9s 37ms/step - loss: 2.3144 - accuracy: 0.2268 - val_loss: 2.2008 - val_accuracy: 0.2407
# Epoch 2/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.9794 - accuracy: 0.3079 - val_loss: 2.1163 - val_accuracy: 0.2207
# Epoch 3/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.8961 - accuracy: 0.3309 - val_loss: 2.0348 - val_accuracy: 0.2756
# Epoch 4/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.8356 - accuracy: 0.3496 - val_loss: 1.9133 - val_accuracy: 0.3089
# Epoch 5/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.7784 - accuracy: 0.3568 - val_loss: 1.8348 - val_accuracy: 0.3489
# Epoch 6/10
# 74/74 [==============================] - 1s 15ms/step - loss: 1.7672 - accuracy: 0.3705 - val_loss: 1.7893 - val_accuracy: 0.3615
# Epoch 7/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.7315 - accuracy: 0.3781 - val_loss: 1.7181 - val_accuracy: 0.3770
# Epoch 8/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.7058 - accuracy: 0.3894 - val_loss: 1.7376 - val_accuracy: 0.3859
# Epoch 9/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.6839 - accuracy: 0.3990 - val_loss: 1.7488 - val_accuracy: 0.3859
# Epoch 10/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.6695 - accuracy: 0.4069 - val_loss: 1.7349 - val_accuracy: 0.3815
# 1688/1688 [==============================] - 18s 9ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.RandomErasing, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learnign rate: 0.01, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 11s 38ms/step - loss: 2.2983 - accuracy: 0.2296 - val_loss: 2.1967 - val_accuracy: 0.2511
# Epoch 2/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.9900 - accuracy: 0.3058 - val_loss: 2.1375 - val_accuracy: 0.2452
# Epoch 3/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.8988 - accuracy: 0.3337 - val_loss: 2.0262 - val_accuracy: 0.2896
# Epoch 4/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.8263 - accuracy: 0.3546 - val_loss: 1.9558 - val_accuracy: 0.3000
# Epoch 5/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.8003 - accuracy: 0.3654 - val_loss: 1.8369 - val_accuracy: 0.3437
# Epoch 6/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.7580 - accuracy: 0.3794 - val_loss: 1.7652 - val_accuracy: 0.3807
# Epoch 7/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.7321 - accuracy: 0.3810 - val_loss: 1.7494 - val_accuracy: 0.3800
# Epoch 8/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.6961 - accuracy: 0.3926 - val_loss: 1.7283 - val_accuracy: 0.3837
# Epoch 9/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.6817 - accuracy: 0.4024 - val_loss: 1.7417 - val_accuracy: 0.3674
# Epoch 10/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.6602 - accuracy: 0.4107 - val_loss: 1.7538 - val_accuracy: 0.3756
# 1688/1688 [==============================] - 18s 9ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.3}, learnign rate: 0.01, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 8s 33ms/step - loss: 2.8411 - accuracy: 0.1734 - val_loss: 2.1592 - val_accuracy: 0.2259
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.5102 - accuracy: 0.2224 - val_loss: 2.0488 - val_accuracy: 0.3022
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3555 - accuracy: 0.2475 - val_loss: 1.9302 - val_accuracy: 0.3400
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.2528 - accuracy: 0.2733 - val_loss: 1.8264 - val_accuracy: 0.3711
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.1814 - accuracy: 0.2785 - val_loss: 1.7472 - val_accuracy: 0.3837
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.1269 - accuracy: 0.2812 - val_loss: 1.6988 - val_accuracy: 0.3896
# Epoch 7/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.0804 - accuracy: 0.2924 - val_loss: 1.6785 - val_accuracy: 0.3896
# Epoch 8/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.0423 - accuracy: 0.2963 - val_loss: 1.6700 - val_accuracy: 0.3911
# Epoch 9/10
# 74/74 [==============================] - 1s 14ms/step - loss: 1.9885 - accuracy: 0.3091 - val_loss: 1.6656 - val_accuracy: 0.3993
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.9703 - accuracy: 0.3159 - val_loss: 1.6568 - val_accuracy: 0.3970
# 1688/1688 [==============================] - 16s 9ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.3}, learnign rate: 0.01, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 8s 33ms/step - loss: 2.8377 - accuracy: 0.1721 - val_loss: 2.1433 - val_accuracy: 0.2719
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.4750 - accuracy: 0.2340 - val_loss: 2.0351 - val_accuracy: 0.2622
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3650 - accuracy: 0.2436 - val_loss: 1.9291 - val_accuracy: 0.3326
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.2460 - accuracy: 0.2669 - val_loss: 1.8123 - val_accuracy: 0.3741
# Epoch 5/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.1839 - accuracy: 0.2811 - val_loss: 1.7606 - val_accuracy: 0.3815
# Epoch 6/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.1246 - accuracy: 0.2765 - val_loss: 1.7117 - val_accuracy: 0.3978
# Epoch 7/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.0791 - accuracy: 0.2968 - val_loss: 1.6966 - val_accuracy: 0.3970
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.0328 - accuracy: 0.2996 - val_loss: 1.6828 - val_accuracy: 0.3993
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.9978 - accuracy: 0.3079 - val_loss: 1.6717 - val_accuracy: 0.3956
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.9598 - accuracy: 0.3141 - val_loss: 1.6608 - val_accuracy: 0.4007
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.3}, learnign rate: 0.01, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 8s 33ms/step - loss: 2.8075 - accuracy: 0.1803 - val_loss: 2.1441 - val_accuracy: 0.2459
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.4882 - accuracy: 0.2216 - val_loss: 2.0596 - val_accuracy: 0.2741
# Epoch 3/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.3532 - accuracy: 0.2494 - val_loss: 1.9419 - val_accuracy: 0.3081
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.2389 - accuracy: 0.2642 - val_loss: 1.8255 - val_accuracy: 0.3452
# Epoch 5/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.1837 - accuracy: 0.2708 - val_loss: 1.7478 - val_accuracy: 0.3807
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.1127 - accuracy: 0.2894 - val_loss: 1.7033 - val_accuracy: 0.3941
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.0626 - accuracy: 0.2937 - val_loss: 1.6760 - val_accuracy: 0.3926
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.0226 - accuracy: 0.2964 - val_loss: 1.6661 - val_accuracy: 0.4059
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.9869 - accuracy: 0.3068 - val_loss: 1.6587 - val_accuracy: 0.3970
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.9655 - accuracy: 0.3133 - val_loss: 1.6513 - val_accuracy: 0.3978
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.5}, learnign rate: 0.01, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 8s 33ms/step - loss: 3.3562 - accuracy: 0.1344 - val_loss: 2.1846 - val_accuracy: 0.1963
# Epoch 2/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.9254 - accuracy: 0.1729 - val_loss: 2.0840 - val_accuracy: 0.2859
# Epoch 3/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.7358 - accuracy: 0.1866 - val_loss: 1.9929 - val_accuracy: 0.3156
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.5842 - accuracy: 0.2055 - val_loss: 1.9081 - val_accuracy: 0.3407
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.4755 - accuracy: 0.2102 - val_loss: 1.8615 - val_accuracy: 0.3467
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3770 - accuracy: 0.2206 - val_loss: 1.8259 - val_accuracy: 0.3489
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3046 - accuracy: 0.2281 - val_loss: 1.8035 - val_accuracy: 0.3600
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.2322 - accuracy: 0.2415 - val_loss: 1.7897 - val_accuracy: 0.3637
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.1882 - accuracy: 0.2407 - val_loss: 1.7856 - val_accuracy: 0.3644
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.1323 - accuracy: 0.2492 - val_loss: 1.7870 - val_accuracy: 0.3600
# 1688/1688 [==============================] - 16s 9ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.5}, learnign rate: 0.01, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 10s 33ms/step - loss: 3.3236 - accuracy: 0.1335 - val_loss: 2.1828 - val_accuracy: 0.2015
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.9069 - accuracy: 0.1721 - val_loss: 2.0944 - val_accuracy: 0.2400
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.7308 - accuracy: 0.1873 - val_loss: 1.9989 - val_accuracy: 0.3015
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.5900 - accuracy: 0.2004 - val_loss: 1.9201 - val_accuracy: 0.3370
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.4776 - accuracy: 0.2094 - val_loss: 1.8776 - val_accuracy: 0.3385
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3655 - accuracy: 0.2210 - val_loss: 1.8393 - val_accuracy: 0.3533
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3213 - accuracy: 0.2224 - val_loss: 1.8168 - val_accuracy: 0.3600
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.2384 - accuracy: 0.2326 - val_loss: 1.8055 - val_accuracy: 0.3630
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.1919 - accuracy: 0.2420 - val_loss: 1.8087 - val_accuracy: 0.3630
# Epoch 10/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.1480 - accuracy: 0.2443 - val_loss: 1.7988 - val_accuracy: 0.3607
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.5}, learnign rate: 0.01, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 9s 35ms/step - loss: 3.3111 - accuracy: 0.1413 - val_loss: 2.1732 - val_accuracy: 0.2067
# Epoch 2/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.9187 - accuracy: 0.1739 - val_loss: 2.0882 - val_accuracy: 0.2407
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.7484 - accuracy: 0.1814 - val_loss: 1.9971 - val_accuracy: 0.2874
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.5531 - accuracy: 0.2112 - val_loss: 1.9182 - val_accuracy: 0.3296
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.4619 - accuracy: 0.2153 - val_loss: 1.8577 - val_accuracy: 0.3378
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3682 - accuracy: 0.2180 - val_loss: 1.8229 - val_accuracy: 0.3526
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.2883 - accuracy: 0.2356 - val_loss: 1.8028 - val_accuracy: 0.3563
# Epoch 8/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.2299 - accuracy: 0.2363 - val_loss: 1.7933 - val_accuracy: 0.3615
# Epoch 9/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.1678 - accuracy: 0.2441 - val_loss: 1.7884 - val_accuracy: 0.3622
# Epoch 10/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.1453 - accuracy: 0.2484 - val_loss: 1.7844 - val_accuracy: 0.3644
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.8}, learnign rate: 0.01, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 8s 33ms/step - loss: 4.8501 - accuracy: 0.1049 - val_loss: 2.3006 - val_accuracy: 0.1237
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 4.0483 - accuracy: 0.1098 - val_loss: 2.2962 - val_accuracy: 0.0956
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 3.4619 - accuracy: 0.1163 - val_loss: 2.2704 - val_accuracy: 0.1378
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 3.0420 - accuracy: 0.1192 - val_loss: 2.2715 - val_accuracy: 0.1407
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.7463 - accuracy: 0.1190 - val_loss: 2.2688 - val_accuracy: 0.1326
# Epoch 6/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.5696 - accuracy: 0.1265 - val_loss: 2.2657 - val_accuracy: 0.1148
# Epoch 7/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.4475 - accuracy: 0.1279 - val_loss: 2.2490 - val_accuracy: 0.1259
# Epoch 8/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.3696 - accuracy: 0.1323 - val_loss: 2.2398 - val_accuracy: 0.1356
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3231 - accuracy: 0.1406 - val_loss: 2.2368 - val_accuracy: 0.1193
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3104 - accuracy: 0.1379 - val_loss: 2.2343 - val_accuracy: 0.1193
# 1688/1688 [==============================] - 16s 9ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.8}, learnign rate: 0.01, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 8s 33ms/step - loss: 4.7875 - accuracy: 0.1020 - val_loss: 2.2989 - val_accuracy: 0.1585
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 4.0316 - accuracy: 0.1119 - val_loss: 2.3156 - val_accuracy: 0.1141
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 3.4812 - accuracy: 0.1151 - val_loss: 2.2822 - val_accuracy: 0.1141
# Epoch 4/10
# 74/74 [==============================] - 1s 14ms/step - loss: 3.0595 - accuracy: 0.1169 - val_loss: 2.2748 - val_accuracy: 0.1126
# Epoch 5/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.7785 - accuracy: 0.1242 - val_loss: 2.2548 - val_accuracy: 0.1104
# Epoch 6/10
# 74/74 [==============================] - 1s 14ms/step - loss: 2.5621 - accuracy: 0.1265 - val_loss: 2.2415 - val_accuracy: 0.1222
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.4415 - accuracy: 0.1350 - val_loss: 2.2377 - val_accuracy: 0.1244
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3744 - accuracy: 0.1351 - val_loss: 2.2452 - val_accuracy: 0.1170
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3273 - accuracy: 0.1383 - val_loss: 2.2332 - val_accuracy: 0.1296
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3026 - accuracy: 0.1400 - val_loss: 2.2410 - val_accuracy: 0.1170
# 1688/1688 [==============================] - 16s 9ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.8}, learnign rate: 0.01, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 8s 33ms/step - loss: 4.7820 - accuracy: 0.0996 - val_loss: 2.2737 - val_accuracy: 0.1207
# Epoch 2/10
# 74/74 [==============================] - 1s 14ms/step - loss: 3.9942 - accuracy: 0.1140 - val_loss: 2.2595 - val_accuracy: 0.1504
# Epoch 3/10
# 74/74 [==============================] - 1s 14ms/step - loss: 3.4559 - accuracy: 0.1156 - val_loss: 2.2461 - val_accuracy: 0.1400
# Epoch 4/10
# 74/74 [==============================] - 1s 14ms/step - loss: 3.0357 - accuracy: 0.1247 - val_loss: 2.2473 - val_accuracy: 0.1370
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.7660 - accuracy: 0.1241 - val_loss: 2.2411 - val_accuracy: 0.1215
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.5594 - accuracy: 0.1273 - val_loss: 2.2437 - val_accuracy: 0.1193
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.4620 - accuracy: 0.1192 - val_loss: 2.2376 - val_accuracy: 0.1207
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3797 - accuracy: 0.1342 - val_loss: 2.2420 - val_accuracy: 0.1156
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3311 - accuracy: 0.1337 - val_loss: 2.2414 - val_accuracy: 0.1156
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3102 - accuracy: 0.1434 - val_loss: 2.2432 - val_accuracy: 0.1156
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.L2: 2>, 'value': 0.001}, learnign rate: 0.01, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 8s 33ms/step - loss: 4.0251 - accuracy: 0.2748 - val_loss: 3.9907 - val_accuracy: 0.2541
# Epoch 2/10
# 74/74 [==============================] - 1s 14ms/step - loss: 3.6328 - accuracy: 0.3772 - val_loss: 3.8848 - val_accuracy: 0.2867
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 3.4914 - accuracy: 0.4123 - val_loss: 3.7654 - val_accuracy: 0.3067
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 3.3913 - accuracy: 0.4418 - val_loss: 3.6297 - val_accuracy: 0.3704
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 3.3124 - accuracy: 0.4719 - val_loss: 3.5130 - val_accuracy: 0.3948
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 3.2391 - accuracy: 0.4989 - val_loss: 3.4381 - val_accuracy: 0.4200
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 3.1929 - accuracy: 0.5096 - val_loss: 3.4424 - val_accuracy: 0.3919
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 3.1568 - accuracy: 0.5243 - val_loss: 3.4177 - val_accuracy: 0.4215
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 3.1067 - accuracy: 0.5392 - val_loss: 3.4270 - val_accuracy: 0.4059
# Epoch 10/10
# ...
# Epoch 1/10
# 74/74 [==============================] - 8s 34ms/step - loss: 20.5818 - accuracy: 0.2363 - val_loss: 20.3166 - val_accuracy: 0.2437
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 19.9193 - accuracy: 0.3323 - val_loss: 19.9649 - val_accuracy: 0.2333
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 19.5054 - accuracy: 0.3837 - val_loss: 19.5993 - val_accuracy: 0.2881
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 19.1528 - accuracy: 0.4072 - val_loss: 19.2150 - val_accuracy: 0.3511
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 18.8375 - accuracy: 0.4249 - val_loss: 18.8546 - val_accuracy: 0.3993
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 18.5352 - accuracy: 0.4435 - val_loss: 18.5372 - val_accuracy: 0.4126
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 18.2289 - accuracy: 0.4629 - val_loss: 18.2575 - val_accuracy: 0.4067
# Epoch 8/10
# 74/74 [==============================] - 1s 14ms/step - loss: 17.9523 - accuracy: 0.4786 - val_loss: 18.0062 - val_accuracy: 0.4170
# Epoch 9/10
# 74/74 [==============================] - 1s 14ms/step - loss: 17.6751 - accuracy: 0.4859 - val_loss: 17.7651 - val_accuracy: 0.4163
# Epoch 10/10
# 74/74 [==============================] - 1s 14ms/step - loss: 17.4046 - accuracy: 0.5025 - val_loss: 17.5043 - val_accuracy: 0.4356
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.L2: 2>, 'value': 0.01}, learnign rate: 0.005, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 8s 33ms/step - loss: 20.5876 - accuracy: 0.2381 - val_loss: 20.3340 - val_accuracy: 0.2444
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 19.9354 - accuracy: 0.3365 - val_loss: 20.0027 - val_accuracy: 0.2741
# Epoch 3/10
# 74/74 [==============================] - 1s 14ms/step - loss: 19.5387 - accuracy: 0.3717 - val_loss: 19.6346 - val_accuracy: 0.3067
# Epoch 4/10
# 74/74 [==============================] - 1s 14ms/step - loss: 19.1807 - accuracy: 0.4000 - val_loss: 19.2422 - val_accuracy: 0.3407
# Epoch 5/10
# 74/74 [==============================] - 1s 14ms/step - loss: 18.8620 - accuracy: 0.4247 - val_loss: 18.8846 - val_accuracy: 0.3593
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 18.5538 - accuracy: 0.4420 - val_loss: 18.5614 - val_accuracy: 0.3785
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 18.2564 - accuracy: 0.4673 - val_loss: 18.2687 - val_accuracy: 0.4015
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 17.9604 - accuracy: 0.4778 - val_loss: 18.0087 - val_accuracy: 0.4052
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 17.6960 - accuracy: 0.4898 - val_loss: 17.7620 - val_accuracy: 0.4133
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 17.4241 - accuracy: 0.4995 - val_loss: 17.5341 - val_accuracy: 0.4170
# 1688/1688 [==============================] - 16s 9ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.L2: 2>, 'value': 0.01}, learnign rate: 0.001, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 8s 34ms/step - loss: 21.0332 - accuracy: 0.1601 - val_loss: 20.5953 - val_accuracy: 0.1407
# Epoch 2/10
# 74/74 [==============================] - 1s 14ms/step - loss: 20.6470 - accuracy: 0.2302 - val_loss: 20.4861 - val_accuracy: 0.1600
# Epoch 3/10
# 74/74 [==============================] - 1s 14ms/step - loss: 20.4428 - accuracy: 0.2625 - val_loss: 20.3522 - val_accuracy: 0.2230
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 20.2868 - accuracy: 0.2912 - val_loss: 20.2019 - val_accuracy: 0.2770
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 20.1542 - accuracy: 0.3137 - val_loss: 20.0611 - val_accuracy: 0.3133
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 20.0327 - accuracy: 0.3316 - val_loss: 19.9466 - val_accuracy: 0.3296
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 19.9422 - accuracy: 0.3350 - val_loss: 19.8655 - val_accuracy: 0.3459
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 19.8592 - accuracy: 0.3446 - val_loss: 19.8010 - val_accuracy: 0.3459
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 19.7712 - accuracy: 0.3577 - val_loss: 19.7410 - val_accuracy: 0.3511
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 19.6830 - accuracy: 0.3643 - val_loss: 19.6832 - val_accuracy: 0.3556
# 1688/1688 [==============================] - 16s 9ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.L2: 2>, 'value': 0.01}, learnign rate: 0.001, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 8s 34ms/step - loss: 21.0675 - accuracy: 0.1503 - val_loss: 20.6023 - val_accuracy: 0.1644
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 20.6400 - accuracy: 0.2240 - val_loss: 20.4863 - val_accuracy: 0.1948
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 20.4277 - accuracy: 0.2704 - val_loss: 20.3532 - val_accuracy: 0.2289
# Epoch 4/10
# 74/74 [==============================] - 1s 14ms/step - loss: 20.2799 - accuracy: 0.2935 - val_loss: 20.2026 - val_accuracy: 0.2593
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 20.1615 - accuracy: 0.3078 - val_loss: 20.0661 - val_accuracy: 0.3015
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 20.0600 - accuracy: 0.3168 - val_loss: 19.9499 - val_accuracy: 0.3304
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 19.9455 - accuracy: 0.3401 - val_loss: 19.8640 - val_accuracy: 0.3474
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 19.8621 - accuracy: 0.3460 - val_loss: 19.7927 - val_accuracy: 0.3637
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 19.7703 - accuracy: 0.3600 - val_loss: 19.7323 - val_accuracy: 0.3659
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 19.6857 - accuracy: 0.3695 - val_loss: 19.6684 - val_accuracy: 0.3667
# 1688/1688 [==============================] - 16s 8ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.L2: 2>, 'value': 0.01}, learnign rate: 0.001, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 8s 33ms/step - loss: 21.0380 - accuracy: 0.1621 - val_loss: 20.6150 - val_accuracy: 0.1793
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 20.6421 - accuracy: 0.2270 - val_loss: 20.5235 - val_accuracy: 0.1963
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 20.4532 - accuracy: 0.2581 - val_loss: 20.4007 - val_accuracy: 0.2289
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 20.3001 - accuracy: 0.2903 - val_loss: 20.2507 - val_accuracy: 0.2615
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 20.1784 - accuracy: 0.3106 - val_loss: 20.1075 - val_accuracy: 0.2941
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 20.0734 - accuracy: 0.3192 - val_loss: 19.9874 - val_accuracy: 0.3200
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 19.9738 - accuracy: 0.3411 - val_loss: 19.8974 - val_accuracy: 0.3356
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 19.8734 - accuracy: 0.3493 - val_loss: 19.8241 - val_accuracy: 0.3393
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 19.7896 - accuracy: 0.3579 - val_loss: 19.7627 - val_accuracy: 0.3467
# Epoch 10/10
# 74/74 [==============================] - 1s 14ms/step - loss: 19.7041 - accuracy: 0.3683 - val_loss: 19.6994 - val_accuracy: 0.3489
# 1688/1688 [==============================] - 16s 9ms/step
# Performing experiment with model: ModelType.EfficientNet, batch size: 128, epochs: 50, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.L2: 2>, 'value': 0.01}, learnign rate: 0.01, seed: 9
# Epoch 1/50
# 74/74 [==============================] - 8s 34ms/step - loss: 20.3292 - accuracy: 0.2721 - val_loss: 20.0421 - val_accuracy: 0.2615
# Epoch 2/50
# 74/74 [==============================] - 1s 13ms/step - loss: 19.4140 - accuracy: 0.3729 - val_loss: 19.4402 - val_accuracy: 0.2919
# Epoch 3/50
# 74/74 [==============================] - 1s 13ms/step - loss: 18.7699 - accuracy: 0.4114 - val_loss: 18.8214 - val_accuracy: 0.3215
# Epoch 4/50
# 74/74 [==============================] - 1s 13ms/step - loss: 18.1731 - accuracy: 0.4451 - val_loss: 18.2045 - val_accuracy: 0.3548
# Epoch 5/50
# 74/74 [==============================] - 1s 13ms/step - loss: 17.6305 - accuracy: 0.4751 - val_loss: 17.6285 - val_accuracy: 0.3763
# Epoch 6/50
# 74/74 [==============================] - 1s 13ms/step - loss: 17.1024 - accuracy: 0.4943 - val_loss: 17.1097 - val_accuracy: 0.3970
# Epoch 7/50
# 74/74 [==============================] - 1s 13ms/step - loss: 16.6031 - accuracy: 0.5171 - val_loss: 16.6051 - val_accuracy: 0.4215
# Epoch 8/50
# 74/74 [==============================] - 1s 14ms/step - loss: 16.1091 - accuracy: 0.5307 - val_loss: 16.1683 - val_accuracy: 0.4252
# Epoch 9/50
# 74/74 [==============================] - 1s 14ms/step - loss: 15.6569 - accuracy: 0.5419 - val_loss: 15.7336 - val_accuracy: 0.4326
# Epoch 10/50
# 74/74 [==============================] - 1s 13ms/step - loss: 15.2076 - accuracy: 0.5560 - val_loss: 15.3267 - val_accuracy: 0.4311
# Epoch 11/50
# 74/74 [==============================] - 1s 13ms/step - loss: 14.7764 - accuracy: 0.5667 - val_loss: 14.9281 - val_accuracy: 0.4274
# Epoch 12/50
# 74/74 [==============================] - 1s 13ms/step - loss: 14.3609 - accuracy: 0.5745 - val_loss: 14.5551 - val_accuracy: 0.4133
# Epoch 13/50
# 74/74 [==============================] - 1s 13ms/step - loss: 13.9447 - accuracy: 0.5962 - val_loss: 14.1563 - val_accuracy: 0.4363
# Epoch 14/50
# 74/74 [==============================] - 1s 13ms/step - loss: 13.5522 - accuracy: 0.6023 - val_loss: 13.8189 - val_accuracy: 0.4252
# Epoch 15/50
# 74/74 [==============================] - 1s 13ms/step - loss: 13.1741 - accuracy: 0.6127 - val_loss: 13.4775 - val_accuracy: 0.4319
# Epoch 16/50
# 74/74 [==============================] - 1s 13ms/step - loss: 12.8076 - accuracy: 0.6231 - val_loss: 13.1463 - val_accuracy: 0.4304
# Epoch 17/50
# 74/74 [==============================] - 1s 14ms/step - loss: 12.4532 - accuracy: 0.6314 - val_loss: 12.8374 - val_accuracy: 0.4296
# Epoch 18/50
# 74/74 [==============================] - 1s 13ms/step - loss: 12.1059 - accuracy: 0.6380 - val_loss: 12.4921 - val_accuracy: 0.4281
# Epoch 19/50
# 74/74 [==============================] - 1s 13ms/step - loss: 11.7656 - accuracy: 0.6459 - val_loss: 12.1991 - val_accuracy: 0.4193
# Epoch 20/50
# 74/74 [==============================] - 1s 14ms/step - loss: 11.4405 - accuracy: 0.6504 - val_loss: 11.9494 - val_accuracy: 0.4141
# Epoch 21/50
# 74/74 [==============================] - 1s 14ms/step - loss: 11.1222 - accuracy: 0.6628 - val_loss: 11.6244 - val_accuracy: 0.4259
# Epoch 22/50
# 74/74 [==============================] - 1s 14ms/step - loss: 10.8153 - accuracy: 0.6722 - val_loss: 11.3483 - val_accuracy: 0.4119
# Epoch 23/50
# 74/74 [==============================] - 1s 13ms/step - loss: 10.5291 - accuracy: 0.6767 - val_loss: 11.0113 - val_accuracy: 0.4393
# Epoch 24/50
# 74/74 [==============================] - 1s 13ms/step - loss: 10.2245 - accuracy: 0.6892 - val_loss: 10.7968 - val_accuracy: 0.4348
# Epoch 25/50
# 74/74 [==============================] - 1s 13ms/step - loss: 9.9546 - accuracy: 0.6911 - val_loss: 10.5419 - val_accuracy: 0.4511
# Epoch 26/50
# 74/74 [==============================] - 1s 13ms/step - loss: 9.6698 - accuracy: 0.7057 - val_loss: 10.2551 - val_accuracy: 0.4467
# Epoch 27/50
# 74/74 [==============================] - 1s 13ms/step - loss: 9.4161 - accuracy: 0.7083 - val_loss: 10.0648 - val_accuracy: 0.4341
# Epoch 28/50
# 74/74 [==============================] - 1s 13ms/step - loss: 9.1544 - accuracy: 0.7162 - val_loss: 9.8935 - val_accuracy: 0.4007
# Epoch 29/50
# 74/74 [==============================] - 1s 13ms/step - loss: 8.9175 - accuracy: 0.7207 - val_loss: 9.5960 - val_accuracy: 0.4467
# Epoch 30/50
# 74/74 [==============================] - 1s 13ms/step - loss: 8.6616 - accuracy: 0.7304 - val_loss: 9.4252 - val_accuracy: 0.4193
# Epoch 31/50
# 74/74 [==============================] - 1s 13ms/step - loss: 8.4288 - accuracy: 0.7340 - val_loss: 9.2018 - val_accuracy: 0.4267
# Epoch 32/50
# 74/74 [==============================] - 1s 13ms/step - loss: 8.2197 - accuracy: 0.7330 - val_loss: 8.9918 - val_accuracy: 0.4304
# Epoch 33/50
# 74/74 [==============================] - 1s 14ms/step - loss: 7.9951 - accuracy: 0.7396 - val_loss: 8.8116 - val_accuracy: 0.4244
# Epoch 34/50
# 74/74 [==============================] - 1s 14ms/step - loss: 7.7679 - accuracy: 0.7442 - val_loss: 8.5734 - val_accuracy: 0.4363
# Epoch 35/50
# 74/74 [==============================] - 1s 14ms/step - loss: 7.5713 - accuracy: 0.7498 - val_loss: 8.4266 - val_accuracy: 0.4163
# Epoch 36/50
# 74/74 [==============================] - 1s 13ms/step - loss: 7.3653 - accuracy: 0.7581 - val_loss: 8.2093 - val_accuracy: 0.4348
# Epoch 37/50
# 74/74 [==============================] - 1s 13ms/step - loss: 7.1709 - accuracy: 0.7599 - val_loss: 8.0696 - val_accuracy: 0.4081
# Epoch 38/50
# 74/74 [==============================] - 1s 13ms/step - loss: 6.9833 - accuracy: 0.7646 - val_loss: 7.9183 - val_accuracy: 0.4222
# Epoch 39/50
# 74/74 [==============================] - 1s 13ms/step - loss: 6.8101 - accuracy: 0.7577 - val_loss: 7.7834 - val_accuracy: 0.4015
# Epoch 40/50
# 74/74 [==============================] - 1s 13ms/step - loss: 6.6226 - accuracy: 0.7703 - val_loss: 7.5466 - val_accuracy: 0.4289
# Epoch 41/50
# 74/74 [==============================] - 1s 13ms/step - loss: 6.4477 - accuracy: 0.7704 - val_loss: 7.4936 - val_accuracy: 0.4052
# Epoch 42/50
# 74/74 [==============================] - 1s 13ms/step - loss: 6.2900 - accuracy: 0.7743 - val_loss: 7.3292 - val_accuracy: 0.4096
# Epoch 43/50
# 74/74 [==============================] - 1s 13ms/step - loss: 6.1228 - accuracy: 0.7813 - val_loss: 7.1571 - val_accuracy: 0.4133
# Epoch 44/50
# 74/74 [==============================] - 1s 13ms/step - loss: 5.9717 - accuracy: 0.7815 - val_loss: 7.0428 - val_accuracy: 0.4200
# Epoch 45/50
# 74/74 [==============================] - 1s 14ms/step - loss: 5.8240 - accuracy: 0.7852 - val_loss: 6.8994 - val_accuracy: 0.4319
# Epoch 46/50
# 74/74 [==============================] - 1s 14ms/step - loss: 5.6691 - accuracy: 0.7828 - val_loss: 6.7802 - val_accuracy: 0.4304
# Epoch 47/50
# 74/74 [==============================] - 1s 14ms/step - loss: 5.5414 - accuracy: 0.7817 - val_loss: 6.7444 - val_accuracy: 0.4037
# Epoch 48/50
# 74/74 [==============================] - 1s 13ms/step - loss: 5.3925 - accuracy: 0.7902 - val_loss: 6.5431 - val_accuracy: 0.4081
# Epoch 49/50
# 74/74 [==============================] - 1s 13ms/step - loss: 5.2521 - accuracy: 0.7969 - val_loss: 6.4463 - val_accuracy: 0.4030
# Epoch 50/50
# 74/74 [==============================] - 1s 13ms/step - loss: 5.1229 - accuracy: 0.7943 - val_loss: 6.4546 - val_accuracy: 0.3807
# 1688/1688 [==============================] - 16s 8ms/step

# %%
print(results)
print(best)
print(histories)

with open("results","wb") as my_csv:
    pickle.dump(results,my_csv)

with open("best","wb") as my_csv:
    pickle.dump(best,my_csv)
with open("histories","wb") as my_csv:
    pickle.dump(histories,my_csv)
# Out:
# [[0.4072037037037037, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 123], [0.405, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 42], [0.40375925925925926, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 9], [0.35612962962962963, <AugmentationTechnique.Rotation: 1>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 123], [0.35562962962962963, <AugmentationTechnique.Rotation: 1>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 42], [0.3571111111111111, <AugmentationTechnique.Rotation: 1>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 9], [0.39946296296296296, <AugmentationTechnique.Flipping: 2>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 123], [0.3987037037037037, <AugmentationTechnique.Flipping: 2>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 42], [0.3983148148148148, <AugmentationTechnique.Flipping: 2>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 9], [0.3896851851851852, <AugmentationTechnique.Zoom: 4>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 123], [0.39331481481481484, <AugmentationTechnique.Zoom: 4>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 42], [0.39201851851851854, <AugmentationTechnique.Zoom: 4>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 9], [0.10635185185185185, <AugmentationTechnique.Brightness: 5>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 123], [0.12303703703703704, <AugmentationTechnique.Brightness: 5>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 42], [0.09648148148148149, <AugmentationTechnique.Brightness: 5>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 9], [0.37116666666666664, <AugmentationTechnique.RandomErasing: 6>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 123], [0.3663518518518519, <AugmentationTechnique.RandomErasing: 6>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 42], [0.3617962962962963, <AugmentationTechnique.RandomErasing: 6>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 9], [0.3855925925925926, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.3}, 128, 0.01, 10, 123], [0.38316666666666666, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.3}, 128, 0.01, 10, 42], [0.38775925925925925, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.3}, 128, 0.01, 10, 9], [0.3398703703703704, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.5}, 128, 0.01, 10, 123], [0.33770370370370373, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.5}, 128, 0.01, 10, 42], [0.3457962962962963, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.5}, 128, 0.01, 10, 9], [0.11155555555555556, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.8}, 128, 0.01, 10, 123], [0.1102962962962963, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.8}, 128, 0.01, 10, 42], [0.11237037037037037, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.8}, 128, 0.01, 10, 9], [0.4082777777777778, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.L2: 2>, 'value': 0.001}, 128, 0.01, 10, 123], [0.405 ...
# [0.37783333333333335, 128, 0.01, 10, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.L2: 2>, 'value': 0.01}]
# [<keras.src.callbacks.History object at 0x7fe698d57af0>, <keras.src.callbacks.History object at 0x7fe36840fa30>, <keras.src.callbacks.History object at 0x7fe34b44bb80>, <keras.src.callbacks.History object at 0x7fe34b0ada50>, <keras.src.callbacks.History object at 0x7fe34ac96b90>, <keras.src.callbacks.History object at 0x7fe34a9f9450>, <keras.src.callbacks.History object at 0x7fe34a7e2e00>, <keras.src.callbacks.History object at 0x7fe32fafb8b0>, <keras.src.callbacks.History object at 0x7fe34a40c3a0>, <keras.src.callbacks.History object at 0x7fe2b6455a50>, <keras.src.callbacks.History object at 0x7fe2b61c18d0>, <keras.src.callbacks.History object at 0x7fe34a6fb760>, <keras.src.callbacks.History object at 0x7fe287c05f90>, <keras.src.callbacks.History object at 0x7fe287106320>, <keras.src.callbacks.History object at 0x7fe2853d3d60>, <keras.src.callbacks.History object at 0x7fe26ed3ab30>, <keras.src.callbacks.History object at 0x7fe27734a770>, <keras.src.callbacks.History object at 0x7fe275c3f490>, <keras.src.callbacks.History object at 0x7fe26fdb8bb0>, <keras.src.callbacks.History object at 0x7fe26f3d18d0>, <keras.src.callbacks.History object at 0x7fe26e3de9e0>, <keras.src.callbacks.History object at 0x7fe26cef3b50>, <keras.src.callbacks.History object at 0x7fe26c316d40>, <keras.src.callbacks.History object at 0x7fe26ade72b0>, <keras.src.callbacks.History object at 0x7fe269aecc70>, <keras.src.callbacks.History object at 0x7fe2687476a0>, <keras.src.callbacks.History object at 0x7fe2675711b0>, <keras.src.callbacks.History object at 0x7fe26699a1a0>, <keras.src.callbacks.History object at 0x7fe2656975b0>, <keras.src.callbacks.History object at 0x7fe264247d60>, <keras.src.callbacks.History object at 0x7fe262c71090>, <keras.src.callbacks.History object at 0x7fe2619d0dc0>, <keras.src.callbacks.History object at 0x7fe260341de0>, <keras.src.callbacks.History object at 0x7fe25f91efb0>, <keras.src.callbacks.History object at 0x7fe25de1bb20>, <keras.src.callbacks.History object at 0x7fe25cddb7f0>, <keras.src.callbacks.History object at 0x7fe262d237c0>, <keras.src.callbacks.History object at 0x7fe25abaffa0>, <keras.src.callbacks.History object at 0x7fe2597f5750>, <keras.src.callbacks.History object at 0x7fe2581d60b0>, <keras.src.callbacks.History object at 0x7fe256fda860>, <keras.src.callbacks.History object at 0x7fe2566d7ee0>, <keras.src.callbacks.History object at 0x7fe2555db2e0>, <keras.src.callbacks.History object at 0x7fe254100c10>, <keras.src.callbacks.History object at 0x7fe25b1b4c40>, <keras.src.callbacks.History object at 0x7fe252b42410>, <keras.src.callbacks.History object at 0x7fe2518f6d10>, <keras.src.callbacks.History object at 0x7fe2502d6e00>, <keras.src.callbacks.History object at 0x7fe24ebf0e50>]

# %% [markdown]
# Results for 50 epochs with 5% of original dataset

# %%
# Plot training and validation accuracy
plt.plot(histories[len(histories)-1].history['accuracy'], label='Training Accuracy')
plt.plot(histories[len(histories)-1].history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.savefig("EfficientNet-50epochs-TrainingandValidationAccuracy.pdf", format="pdf", bbox_inches="tight")
plt.show()

# Plot training and validation loss
plt.plot(histories[len(histories)-1].history['loss'], label='Training Loss')
plt.plot(histories[len(histories)-1].history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.savefig("EfficientNet-50epochs-TrainingandValidationLoss.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
model = createModel(modelType=ModelType.EfficientNet,regularizer={"type":RegularizationType.L2,"value":0.01},optimizer=getOptimizer(type=OptimizerType.Sgd,learningRate=0.01), loss='categorical_crossentropy', metrics=['accuracy'],seed=123, augmentation=AugmentationTechnique.NoAugmentation)
# train the model
history = model.fit(batch_size=128,epochs=10, train_images=train_images,train_labels=train_labels,valid_images=valid_images,valid_labels=valid_labels)

# get accuracy
y_pred = model.predict(test_images)
# Convert probabilities to class labels
predicted_classes = np.argmax(y_pred, axis=1)

# Get true class labels
true_classes = np.argmax(test_labels, axis=1)
accuracy = getAccuracy(predicted_classes,true_classes)
# Out:
# Epoch 1/10
# 1477/1477 [==============================] - 28s 15ms/step - loss: 15.5864 - accuracy: 0.4020 - val_loss: 11.7338 - val_accuracy: 0.4497
# Epoch 2/10
# 1477/1477 [==============================] - 19s 13ms/step - loss: 9.2426 - accuracy: 0.4529 - val_loss: 7.1741 - val_accuracy: 0.4637
# Epoch 3/10
# 1477/1477 [==============================] - 20s 13ms/step - loss: 5.7917 - accuracy: 0.4646 - val_loss: 4.6652 - val_accuracy: 0.4659
# Epoch 4/10
# 1477/1477 [==============================] - 20s 14ms/step - loss: 3.8937 - accuracy: 0.4700 - val_loss: 3.3169 - val_accuracy: 0.4540
# Epoch 5/10
# 1477/1477 [==============================] - 20s 13ms/step - loss: 2.8478 - accuracy: 0.4714 - val_loss: 2.5222 - val_accuracy: 0.4679
# Epoch 6/10
# 1477/1477 [==============================] - 19s 13ms/step - loss: 2.2747 - accuracy: 0.4715 - val_loss: 2.1777 - val_accuracy: 0.4451
# Epoch 7/10
# 1477/1477 [==============================] - 20s 14ms/step - loss: 1.9556 - accuracy: 0.4739 - val_loss: 1.9552 - val_accuracy: 0.4399
# Epoch 8/10
# 1477/1477 [==============================] - 20s 13ms/step - loss: 1.7789 - accuracy: 0.4735 - val_loss: 1.7616 - val_accuracy: 0.4560
# Epoch 9/10
# 1477/1477 [==============================] - 20s 13ms/step - loss: 1.6823 - accuracy: 0.4726 - val_loss: 1.6613 - val_accuracy: 0.4719
# Epoch 10/10
# 1477/1477 [==============================] - 20s 13ms/step - loss: 1.6294 - accuracy: 0.4743 - val_loss: 1.6353 - val_accuracy: 0.4670
# 1688/1688 [==============================] - 16s 8ms/step

# %%
# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.savefig("EfficientNet-TrainingandValidationAccuracy.pdf", format="pdf", bbox_inches="tight")
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.savefig("EfficientNet-TrainingandValidationLoss.pdf", format="pdf", bbox_inches="tight")
plt.show()


# Predict probabilities for test data
predictions = model.predict(test_images)
# Convert probabilities to class labels
predicted_classes = np.argmax(predictions, axis=1)

# Get true class labels
true_classes = np.argmax(test_labels, axis=1)

# Get class labels
class_labels = sorted(os.listdir(test_data_dir))
class_labels = [class_name for class_name in class_labels if class_name != '.DS_Store']

# Create confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Normalize confusion matrix
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plot confusion matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.savefig("EfficientNet-ConfusionMatrix.pdf", format="pdf", bbox_inches="tight")
plt.show()
# Out:
# 1688/1688 [==============================] - 15s 8ms/step

# %%
with open("efficientnet-history","wb") as my_csv:
    pickle.dump(history,my_csv)

# %%
results, best, histories = performExperiment(modelType=ModelType.MobileNet,batchSizes=batchSizes,learningRates=learningRates,numberOfEpochs=numberOfEpochs,augmentationTechniques=augmentationTechniques,regularizers=regularizers,seeds=seeds, optimizerType=OptimizerType.Adam)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learning rate: 0.01, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 9s 32ms/step - loss: 2.5119 - accuracy: 0.1785 - val_loss: 24.9932 - val_accuracy: 0.0889
# Epoch 2/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.1988 - accuracy: 0.2315 - val_loss: 7.3235 - val_accuracy: 0.0933
# Epoch 3/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.1005 - accuracy: 0.2480 - val_loss: 3.7309 - val_accuracy: 0.1296
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.0404 - accuracy: 0.2653 - val_loss: 4.0483 - val_accuracy: 0.1496
# Epoch 5/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.0838 - accuracy: 0.2641 - val_loss: 9.6315 - val_accuracy: 0.1089
# Epoch 6/10
# 74/74 [==============================] - 1s 12ms/step - loss: 1.9952 - accuracy: 0.2832 - val_loss: 2.5253 - val_accuracy: 0.1578
# Epoch 7/10
# 74/74 [==============================] - 1s 12ms/step - loss: 1.9841 - accuracy: 0.2884 - val_loss: 2.8205 - val_accuracy: 0.1563
# Epoch 8/10
# 74/74 [==============================] - 1s 12ms/step - loss: 1.9733 - accuracy: 0.2903 - val_loss: 3.6961 - val_accuracy: 0.1600
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.9193 - accuracy: 0.3010 - val_loss: 3.4672 - val_accuracy: 0.1207
# Epoch 10/10
# 74/74 [==============================] - 1s 12ms/step - loss: 1.9099 - accuracy: 0.3097 - val_loss: 3.0497 - val_accuracy: 0.1615
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learning rate: 0.01, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 7s 30ms/step - loss: 2.5146 - accuracy: 0.1804 - val_loss: 23.0128 - val_accuracy: 0.0889
# Epoch 2/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.2062 - accuracy: 0.2246 - val_loss: 10.0682 - val_accuracy: 0.1133
# Epoch 3/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.1135 - accuracy: 0.2511 - val_loss: 10.8940 - val_accuracy: 0.1030
# Epoch 4/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.0812 - accuracy: 0.2636 - val_loss: 11.3348 - val_accuracy: 0.1111
# Epoch 5/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.0328 - accuracy: 0.2735 - val_loss: 2.9330 - val_accuracy: 0.1859
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.0210 - accuracy: 0.2783 - val_loss: 3.6126 - val_accuracy: 0.1519
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.9601 - accuracy: 0.2981 - val_loss: 2.7366 - val_accuracy: 0.1978
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.9413 - accuracy: 0.2992 - val_loss: 2.6196 - val_accuracy: 0.1607
# Epoch 9/10
# 74/74 [==============================] - 1s 12ms/step - loss: 1.9149 - accuracy: 0.3057 - val_loss: 4.7717 - val_accuracy: 0.1630
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.9196 - accuracy: 0.3050 - val_loss: 3.5246 - val_accuracy: 0.1156
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learning rate: 0.01, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 7s 31ms/step - loss: 2.4417 - accuracy: 0.1823 - val_loss: 28.7788 - val_accuracy: 0.1222
# Epoch 2/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.1920 - accuracy: 0.2276 - val_loss: 14.9873 - val_accuracy: 0.1378
# Epoch 3/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.1288 - accuracy: 0.2467 - val_loss: 6.5155 - val_accuracy: 0.1607
# Epoch 4/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.0774 - accuracy: 0.2702 - val_loss: 7.6594 - val_accuracy: 0.0904
# Epoch 5/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.0362 - accuracy: 0.2750 - val_loss: 7.0438 - val_accuracy: 0.1081
# Epoch 6/10
# 74/74 [==============================] - 1s 12ms/step - loss: 1.9856 - accuracy: 0.2889 - val_loss: 3.1030 - val_accuracy: 0.1637
# Epoch 7/10
# 74/74 [==============================] - 1s 12ms/step - loss: 1.9633 - accuracy: 0.2940 - val_loss: 6.0692 - val_accuracy: 0.1237
# Epoch 8/10
# 74/74 [==============================] - 1s 12ms/step - loss: 1.9348 - accuracy: 0.3010 - val_loss: 3.4468 - val_accuracy: 0.1622
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.9027 - accuracy: 0.3095 - val_loss: 6.4497 - val_accuracy: 0.1104
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 1.9133 - accuracy: 0.3070 - val_loss: 3.4691 - val_accuracy: 0.1667
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Rotation, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learning rate: 0.01, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 33s 59ms/step - loss: 2.7911 - accuracy: 0.1239 - val_loss: 321782592.0000 - val_accuracy: 0.0874
# Epoch 2/10
# 74/74 [==============================] - 3s 39ms/step - loss: 2.5803 - accuracy: 0.1154 - val_loss: 67912286208.0000 - val_accuracy: 0.0993
# Epoch 3/10
# 74/74 [==============================] - 3s 39ms/step - loss: 2.4692 - accuracy: 0.1413 - val_loss: 8162192384.0000 - val_accuracy: 0.0889
# Epoch 4/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.2894 - accuracy: 0.1758 - val_loss: 5305350144.0000 - val_accuracy: 0.1089
# Epoch 5/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.2364 - accuracy: 0.2016 - val_loss: 718828672.0000 - val_accuracy: 0.1037
# Epoch 6/10
# 74/74 [==============================] - 3s 39ms/step - loss: 2.1371 - accuracy: 0.2174 - val_loss: 38283988.0000 - val_accuracy: 0.1037
# Epoch 7/10
# 74/74 [==============================] - 3s 40ms/step - loss: 2.0993 - accuracy: 0.2218 - val_loss: 5796206.5000 - val_accuracy: 0.1037
# Epoch 8/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.0462 - accuracy: 0.2435 - val_loss: 1181204.3750 - val_accuracy: 0.0889
# Epoch 9/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.0007 - accuracy: 0.2530 - val_loss: 287595.3438 - val_accuracy: 0.0896
# Epoch 10/10
# 74/74 [==============================] - 3s 39ms/step - loss: 1.9860 - accuracy: 0.2619 - val_loss: 233567.9062 - val_accuracy: 0.1037
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Rotation, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learning rate: 0.01, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 30s 70ms/step - loss: 2.7189 - accuracy: 0.1236 - val_loss: 38807228416.0000 - val_accuracy: 0.1037
# Epoch 2/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.5315 - accuracy: 0.1396 - val_loss: 61833170944.0000 - val_accuracy: 0.0889
# Epoch 3/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.5606 - accuracy: 0.1503 - val_loss: 17888522240.0000 - val_accuracy: 0.1133
# Epoch 4/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.4734 - accuracy: 0.1465 - val_loss: 3126648064.0000 - val_accuracy: 0.0874
# Epoch 5/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.2401 - accuracy: 0.2035 - val_loss: 129713520.0000 - val_accuracy: 0.0993
# Epoch 6/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.1548 - accuracy: 0.2089 - val_loss: 58168860.0000 - val_accuracy: 0.1037
# Epoch 7/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.0740 - accuracy: 0.2328 - val_loss: 5328645.5000 - val_accuracy: 0.0896
# Epoch 8/10
# 74/74 [==============================] - 3s 45ms/step - loss: 2.0883 - accuracy: 0.2278 - val_loss: 340318.1562 - val_accuracy: 0.1089
# Epoch 9/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.0427 - accuracy: 0.2397 - val_loss: 145117.5625 - val_accuracy: 0.1133
# Epoch 10/10
# 74/74 [==============================] - 3s 42ms/step - loss: 1.9988 - accuracy: 0.2511 - val_loss: 134336.1719 - val_accuracy: 0.0874
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Rotation, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learning rate: 0.01, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 29s 60ms/step - loss: 2.7720 - accuracy: 0.1343 - val_loss: 116272456.0000 - val_accuracy: 0.1037
# Epoch 2/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.5453 - accuracy: 0.1366 - val_loss: 14857439232.0000 - val_accuracy: 0.1037
# Epoch 3/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.5493 - accuracy: 0.1254 - val_loss: 93449101312.0000 - val_accuracy: 0.0874
# Epoch 4/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.4661 - accuracy: 0.1235 - val_loss: 2587824128.0000 - val_accuracy: 0.1089
# Epoch 5/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.3902 - accuracy: 0.1251 - val_loss: 47043320.0000 - val_accuracy: 0.0874
# Epoch 6/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.3192 - accuracy: 0.1505 - val_loss: 3840415.0000 - val_accuracy: 0.1133
# Epoch 7/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.1832 - accuracy: 0.1901 - val_loss: 1565463.3750 - val_accuracy: 0.0896
# Epoch 8/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.1495 - accuracy: 0.1921 - val_loss: 113652.0391 - val_accuracy: 0.0993
# Epoch 9/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.1064 - accuracy: 0.2133 - val_loss: 81551.8516 - val_accuracy: 0.0896
# Epoch 10/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.1008 - accuracy: 0.2108 - val_loss: 11640.6602 - val_accuracy: 0.0993
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Flipping, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learning rate: 0.01, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 30s 60ms/step - loss: 2.7454 - accuracy: 0.1520 - val_loss: 13066804224.0000 - val_accuracy: 0.0874
# Epoch 2/10
# 74/74 [==============================] - 3s 46ms/step - loss: 2.4371 - accuracy: 0.1886 - val_loss: 265736448.0000 - val_accuracy: 0.1022
# Epoch 3/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.3766 - accuracy: 0.1619 - val_loss: 59823337472.0000 - val_accuracy: 0.0874
# Epoch 4/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.4011 - accuracy: 0.1352 - val_loss: 11805231104.0000 - val_accuracy: 0.0874
# Epoch 5/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.3438 - accuracy: 0.1344 - val_loss: 2077943680.0000 - val_accuracy: 0.0874
# Epoch 6/10
# 74/74 [==============================] - 3s 45ms/step - loss: 2.2844 - accuracy: 0.1587 - val_loss: 139505264.0000 - val_accuracy: 0.0874
# Epoch 7/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.2147 - accuracy: 0.1885 - val_loss: 5054549.5000 - val_accuracy: 0.0874
# Epoch 8/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.1054 - accuracy: 0.2203 - val_loss: 1262263.1250 - val_accuracy: 0.0874
# Epoch 9/10
# 74/74 [==============================] - 3s 45ms/step - loss: 2.0660 - accuracy: 0.2316 - val_loss: 290745.1875 - val_accuracy: 0.0874
# Epoch 10/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.0286 - accuracy: 0.2447 - val_loss: 135109.6406 - val_accuracy: 0.0889
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Flipping, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learning rate: 0.01, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 29s 60ms/step - loss: 2.6419 - accuracy: 0.1643 - val_loss: 13739416576.0000 - val_accuracy: 0.1059
# Epoch 2/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.4565 - accuracy: 0.1729 - val_loss: 1438534784.0000 - val_accuracy: 0.1022
# Epoch 3/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.4851 - accuracy: 0.1313 - val_loss: 174784397312.0000 - val_accuracy: 0.1133
# Epoch 4/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.4438 - accuracy: 0.1567 - val_loss: 267196368.0000 - val_accuracy: 0.1089
# Epoch 5/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.3783 - accuracy: 0.1444 - val_loss: 44543180.0000 - val_accuracy: 0.0993
# Epoch 6/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.3291 - accuracy: 0.1611 - val_loss: 952792.7500 - val_accuracy: 0.1037
# Epoch 7/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.2202 - accuracy: 0.1938 - val_loss: 114563.3438 - val_accuracy: 0.1022
# Epoch 8/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.1304 - accuracy: 0.2277 - val_loss: 164633.9688 - val_accuracy: 0.1089
# Epoch 9/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.1051 - accuracy: 0.2430 - val_loss: 37929.4141 - val_accuracy: 0.1059
# Epoch 10/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.0213 - accuracy: 0.2548 - val_loss: 23151.6973 - val_accuracy: 0.1037
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Flipping, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learning rate: 0.01, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 29s 59ms/step - loss: 2.6491 - accuracy: 0.1568 - val_loss: 5813665280.0000 - val_accuracy: 0.1059
# Epoch 2/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.4259 - accuracy: 0.1737 - val_loss: 12407872512.0000 - val_accuracy: 0.1037
# Epoch 3/10
# 74/74 [==============================] - 3s 45ms/step - loss: 2.4536 - accuracy: 0.1719 - val_loss: 36259627008.0000 - val_accuracy: 0.1133
# Epoch 4/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.2600 - accuracy: 0.1806 - val_loss: 62677647360.0000 - val_accuracy: 0.1022
# Epoch 5/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.2172 - accuracy: 0.1957 - val_loss: 2411004672.0000 - val_accuracy: 0.1037
# Epoch 6/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.0872 - accuracy: 0.2273 - val_loss: 133151872.0000 - val_accuracy: 0.1037
# Epoch 7/10
# 74/74 [==============================] - 3s 45ms/step - loss: 2.0822 - accuracy: 0.2314 - val_loss: 658616000.0000 - val_accuracy: 0.1037
# Epoch 8/10
# 74/74 [==============================] - 3s 43ms/step - loss: 1.9845 - accuracy: 0.2534 - val_loss: 39710524.0000 - val_accuracy: 0.1037
# Epoch 9/10
# 74/74 [==============================] - 3s 43ms/step - loss: 1.9474 - accuracy: 0.2605 - val_loss: 5033463.5000 - val_accuracy: 0.1037
# Epoch 10/10
# 74/74 [==============================] - 3s 43ms/step - loss: 1.9227 - accuracy: 0.2693 - val_loss: 2053985.1250 - val_accuracy: 0.1037
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Zoom, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learning rate: 0.01, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 29s 59ms/step - loss: 2.7044 - accuracy: 0.1414 - val_loss: 174447050752.0000 - val_accuracy: 0.1022
# Epoch 2/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.5585 - accuracy: 0.1497 - val_loss: 70899810304.0000 - val_accuracy: 0.0889
# Epoch 3/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.4669 - accuracy: 0.1572 - val_loss: 1012116032.0000 - val_accuracy: 0.1007
# Epoch 4/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.3245 - accuracy: 0.1728 - val_loss: 23296172.0000 - val_accuracy: 0.0874
# Epoch 5/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.2184 - accuracy: 0.2060 - val_loss: 8187586.0000 - val_accuracy: 0.1037
# Epoch 6/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.1311 - accuracy: 0.2234 - val_loss: 725551.5625 - val_accuracy: 0.1037
# Epoch 7/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.0820 - accuracy: 0.2458 - val_loss: 352396.9688 - val_accuracy: 0.1037
# Epoch 8/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.0296 - accuracy: 0.2526 - val_loss: 203427.2188 - val_accuracy: 0.1037
# Epoch 9/10
# 74/74 [==============================] - 3s 42ms/step - loss: 1.9744 - accuracy: 0.2695 - val_loss: 112765.9766 - val_accuracy: 0.1037
# Epoch 10/10
# 74/74 [==============================] - 3s 44ms/step - loss: 1.9245 - accuracy: 0.2751 - val_loss: 28290.1445 - val_accuracy: 0.1007
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Zoom, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learning rate: 0.01, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 29s 61ms/step - loss: 2.7607 - accuracy: 0.1433 - val_loss: 13839940608.0000 - val_accuracy: 0.0889
# Epoch 2/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.4472 - accuracy: 0.1764 - val_loss: 29554026496.0000 - val_accuracy: 0.1133
# Epoch 3/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.3187 - accuracy: 0.1989 - val_loss: 64233984000.0000 - val_accuracy: 0.0889
# Epoch 4/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.2921 - accuracy: 0.1782 - val_loss: 8621894656.0000 - val_accuracy: 0.1037
# Epoch 5/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.2246 - accuracy: 0.2091 - val_loss: 280558560.0000 - val_accuracy: 0.1037
# Epoch 6/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.1730 - accuracy: 0.2042 - val_loss: 66714100.0000 - val_accuracy: 0.1037
# Epoch 7/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.1680 - accuracy: 0.2032 - val_loss: 4396282.5000 - val_accuracy: 0.0874
# Epoch 8/10
# 74/74 [==============================] - 3s 45ms/step - loss: 2.0339 - accuracy: 0.2344 - val_loss: 2013010.2500 - val_accuracy: 0.1037
# Epoch 9/10
# 74/74 [==============================] - 3s 43ms/step - loss: 1.9944 - accuracy: 0.2541 - val_loss: 205447.0938 - val_accuracy: 0.1037
# Epoch 10/10
# 74/74 [==============================] - 3s 43ms/step - loss: 1.9803 - accuracy: 0.2602 - val_loss: 108551.8359 - val_accuracy: 0.0874
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Zoom, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learning rate: 0.01, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 29s 60ms/step - loss: 2.7300 - accuracy: 0.1352 - val_loss: 361607904.0000 - val_accuracy: 0.1007
# Epoch 2/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.4767 - accuracy: 0.1560 - val_loss: 3575860992.0000 - val_accuracy: 0.0874
# Epoch 3/10
# 74/74 [==============================] - 3s 45ms/step - loss: 2.4952 - accuracy: 0.1301 - val_loss: 2079726108672.0000 - val_accuracy: 0.1059
# Epoch 4/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.4582 - accuracy: 0.1159 - val_loss: 62265118720.0000 - val_accuracy: 0.1059
# Epoch 5/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.4493 - accuracy: 0.1279 - val_loss: 1107597056.0000 - val_accuracy: 0.1133
# Epoch 6/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.3071 - accuracy: 0.1583 - val_loss: 43777488.0000 - val_accuracy: 0.1059
# Epoch 7/10
# 74/74 [==============================] - 3s 45ms/step - loss: 2.1814 - accuracy: 0.1802 - val_loss: 14288638.0000 - val_accuracy: 0.1022
# Epoch 8/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.1178 - accuracy: 0.2042 - val_loss: 4265488.0000 - val_accuracy: 0.1133
# Epoch 9/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.0835 - accuracy: 0.2285 - val_loss: 465176.2188 - val_accuracy: 0.1059
# Epoch 10/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.0445 - accuracy: 0.2460 - val_loss: 232019.9844 - val_accuracy: 0.1089
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Brightness, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learning rate: 0.01, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 31s 61ms/step - loss: 2.7329 - accuracy: 0.1052 - val_loss: 152788768.0000 - val_accuracy: 0.0889
# Epoch 2/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.6140 - accuracy: 0.1038 - val_loss: 12682537984.0000 - val_accuracy: 0.1059
# Epoch 3/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.5956 - accuracy: 0.0981 - val_loss: 5625835520.0000 - val_accuracy: 0.0993
# Epoch 4/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.4833 - accuracy: 0.1013 - val_loss: 993928960.0000 - val_accuracy: 0.1037
# Epoch 5/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.4646 - accuracy: 0.1023 - val_loss: 36392500.0000 - val_accuracy: 0.0896
# Epoch 6/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.4099 - accuracy: 0.0976 - val_loss: 51419564.0000 - val_accuracy: 0.1089
# Epoch 7/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.3971 - accuracy: 0.1049 - val_loss: 3277986.7500 - val_accuracy: 0.0993
# Epoch 8/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.3826 - accuracy: 0.0969 - val_loss: 586989.3750 - val_accuracy: 0.1022
# Epoch 9/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.3436 - accuracy: 0.0978 - val_loss: 255292.7500 - val_accuracy: 0.1089
# Epoch 10/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.3289 - accuracy: 0.1023 - val_loss: 93384.8750 - val_accuracy: 0.0896
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Brightness, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learning rate: 0.01, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 29s 60ms/step - loss: 2.8011 - accuracy: 0.1007 - val_loss: 10722219008.0000 - val_accuracy: 0.1037
# Epoch 2/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.6180 - accuracy: 0.1019 - val_loss: 125698336.0000 - val_accuracy: 0.0993
# Epoch 3/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.6326 - accuracy: 0.1058 - val_loss: 58768808.0000 - val_accuracy: 0.1037
# Epoch 4/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.4204 - accuracy: 0.1039 - val_loss: 12262970368.0000 - val_accuracy: 0.1059
# Epoch 5/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.3917 - accuracy: 0.0985 - val_loss: 43826560.0000 - val_accuracy: 0.1022
# Epoch 6/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.3868 - accuracy: 0.0983 - val_loss: 5069743.5000 - val_accuracy: 0.1059
# Epoch 7/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.3634 - accuracy: 0.1001 - val_loss: 1496857.0000 - val_accuracy: 0.0889
# Epoch 8/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.3539 - accuracy: 0.0981 - val_loss: 390503.5625 - val_accuracy: 0.1037
# Epoch 9/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.3389 - accuracy: 0.0951 - val_loss: 25043.4141 - val_accuracy: 0.1133
# Epoch 10/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.3233 - accuracy: 0.1024 - val_loss: 6620.6934 - val_accuracy: 0.0993
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.Brightness, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learning rate: 0.01, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 29s 56ms/step - loss: 2.8512 - accuracy: 0.0995 - val_loss: 25606762496.0000 - val_accuracy: 0.0889
# Epoch 2/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.6654 - accuracy: 0.0995 - val_loss: 360662752.0000 - val_accuracy: 0.1007
# Epoch 3/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.5036 - accuracy: 0.1035 - val_loss: 8351384.5000 - val_accuracy: 0.1133
# Epoch 4/10
# 74/74 [==============================] - 3s 40ms/step - loss: 2.4786 - accuracy: 0.1022 - val_loss: 1583410.2500 - val_accuracy: 0.0896
# Epoch 5/10
# 74/74 [==============================] - 3s 40ms/step - loss: 2.4662 - accuracy: 0.0969 - val_loss: 16273998.0000 - val_accuracy: 0.0889
# Epoch 6/10
# 74/74 [==============================] - 3s 41ms/step - loss: 2.4130 - accuracy: 0.0941 - val_loss: 4942173.0000 - val_accuracy: 0.1133
# Epoch 7/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.3853 - accuracy: 0.0959 - val_loss: 179735.5781 - val_accuracy: 0.0889
# Epoch 8/10
# 74/74 [==============================] - 5s 65ms/step - loss: 2.3622 - accuracy: 0.0989 - val_loss: 41314.9688 - val_accuracy: 0.1133
# Epoch 9/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.3486 - accuracy: 0.1047 - val_loss: 3659.0432 - val_accuracy: 0.1007
# Epoch 10/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.3219 - accuracy: 0.1018 - val_loss: 603.5971 - val_accuracy: 0.0889
# 1688/1688 [==============================] - 14s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.RandomErasing, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learning rate: 0.01, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 31s 63ms/step - loss: 2.7942 - accuracy: 0.1200 - val_loss: 5625847296.0000 - val_accuracy: 0.1007
# Epoch 2/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.6141 - accuracy: 0.1138 - val_loss: 80717296.0000 - val_accuracy: 0.1059
# Epoch 3/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.5405 - accuracy: 0.1153 - val_loss: 47488252.0000 - val_accuracy: 0.1007
# Epoch 4/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.4885 - accuracy: 0.1135 - val_loss: 206626320.0000 - val_accuracy: 0.0874
# Epoch 5/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.4073 - accuracy: 0.1184 - val_loss: 4740479.5000 - val_accuracy: 0.1133
# Epoch 6/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.3712 - accuracy: 0.1140 - val_loss: 240481.1562 - val_accuracy: 0.1037
# Epoch 7/10
# 74/74 [==============================] - 3s 46ms/step - loss: 2.3283 - accuracy: 0.1125 - val_loss: 82831.5000 - val_accuracy: 0.1089
# Epoch 8/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.3135 - accuracy: 0.1211 - val_loss: 18946.2500 - val_accuracy: 0.1022
# Epoch 9/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.2972 - accuracy: 0.1330 - val_loss: 6758.1963 - val_accuracy: 0.1037
# Epoch 10/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.2767 - accuracy: 0.1429 - val_loss: 3988.1733 - val_accuracy: 0.1059
# 1688/1688 [==============================] - 15s 8ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.RandomErasing, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learning rate: 0.01, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 32s 96ms/step - loss: 2.5648 - accuracy: 0.1593 - val_loss: 2711594752.0000 - val_accuracy: 0.1022
# Epoch 2/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.4344 - accuracy: 0.1579 - val_loss: 2846596.0000 - val_accuracy: 0.1007
# Epoch 3/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.5649 - accuracy: 0.1241 - val_loss: 721124288.0000 - val_accuracy: 0.0874
# Epoch 4/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.3154 - accuracy: 0.1707 - val_loss: 246997952.0000 - val_accuracy: 0.1037
# Epoch 5/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.2327 - accuracy: 0.1935 - val_loss: 104905256.0000 - val_accuracy: 0.1059
# Epoch 6/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.1598 - accuracy: 0.2040 - val_loss: 12339688.0000 - val_accuracy: 0.1089
# Epoch 7/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.1420 - accuracy: 0.2051 - val_loss: 1232532.1250 - val_accuracy: 0.1089
# Epoch 8/10
# 74/74 [==============================] - 3s 46ms/step - loss: 2.0954 - accuracy: 0.2233 - val_loss: 216929.3750 - val_accuracy: 0.1133
# Epoch 9/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.0415 - accuracy: 0.2292 - val_loss: 69954.8594 - val_accuracy: 0.0889
# Epoch 10/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.0125 - accuracy: 0.2421 - val_loss: 4580.0708 - val_accuracy: 0.0889
# 1688/1688 [==============================] - 15s 8ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.RandomErasing, regularizer: {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, learning rate: 0.01, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 30s 64ms/step - loss: 2.7059 - accuracy: 0.1354 - val_loss: 9887503360.0000 - val_accuracy: 0.1059
# Epoch 2/10
# 74/74 [==============================] - 3s 46ms/step - loss: 2.4317 - accuracy: 0.1656 - val_loss: 5012196352.0000 - val_accuracy: 0.1133
# Epoch 3/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.4295 - accuracy: 0.1685 - val_loss: 82123352.0000 - val_accuracy: 0.0889
# Epoch 4/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.3222 - accuracy: 0.1705 - val_loss: 724675.0625 - val_accuracy: 0.0993
# Epoch 5/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.2777 - accuracy: 0.1812 - val_loss: 343071.0938 - val_accuracy: 0.0874
# Epoch 6/10
# 74/74 [==============================] - 3s 45ms/step - loss: 2.2451 - accuracy: 0.1758 - val_loss: 33807.4648 - val_accuracy: 0.0874
# Epoch 7/10
# 74/74 [==============================] - 3s 43ms/step - loss: 2.2923 - accuracy: 0.1510 - val_loss: 293122080.0000 - val_accuracy: 0.0874
# Epoch 8/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.1330 - accuracy: 0.1703 - val_loss: 9290200.0000 - val_accuracy: 0.1133
# Epoch 9/10
# 74/74 [==============================] - 3s 42ms/step - loss: 2.0949 - accuracy: 0.1929 - val_loss: 282962.7812 - val_accuracy: 0.1133
# Epoch 10/10
# 74/74 [==============================] - 3s 44ms/step - loss: 2.0458 - accuracy: 0.2190 - val_loss: 31005.2598 - val_accuracy: 0.0889
# 1688/1688 [==============================] - 15s 8ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.3}, learning rate: 0.01, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 7s 31ms/step - loss: 2.8082 - accuracy: 0.1298 - val_loss: 5.1785 - val_accuracy: 0.1089
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.4185 - accuracy: 0.1506 - val_loss: 2.5555 - val_accuracy: 0.1467
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3398 - accuracy: 0.1639 - val_loss: 2.1971 - val_accuracy: 0.2000
# Epoch 4/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.2753 - accuracy: 0.1725 - val_loss: 2.2630 - val_accuracy: 0.1800
# Epoch 5/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.2396 - accuracy: 0.1829 - val_loss: 2.1772 - val_accuracy: 0.1822
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.1850 - accuracy: 0.1916 - val_loss: 2.1946 - val_accuracy: 0.1785
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.1698 - accuracy: 0.1966 - val_loss: 2.1555 - val_accuracy: 0.2148
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.1579 - accuracy: 0.1950 - val_loss: 2.1168 - val_accuracy: 0.1963
# Epoch 9/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.1462 - accuracy: 0.2046 - val_loss: 2.1164 - val_accuracy: 0.2111
# Epoch 10/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.1379 - accuracy: 0.2089 - val_loss: 2.1234 - val_accuracy: 0.2044
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.3}, learning rate: 0.01, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 7s 31ms/step - loss: 2.8266 - accuracy: 0.1365 - val_loss: 4.2722 - val_accuracy: 0.1170
# Epoch 2/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.4461 - accuracy: 0.1398 - val_loss: 2.3563 - val_accuracy: 0.1800
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3351 - accuracy: 0.1611 - val_loss: 2.1988 - val_accuracy: 0.1704
# Epoch 4/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.2624 - accuracy: 0.1771 - val_loss: 2.2931 - val_accuracy: 0.1741
# Epoch 5/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.2322 - accuracy: 0.1828 - val_loss: 2.1981 - val_accuracy: 0.1822
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.1951 - accuracy: 0.1915 - val_loss: 2.1435 - val_accuracy: 0.2081
# Epoch 7/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.1733 - accuracy: 0.1996 - val_loss: 2.1086 - val_accuracy: 0.2289
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.1565 - accuracy: 0.1981 - val_loss: 2.1236 - val_accuracy: 0.2141
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.1516 - accuracy: 0.2005 - val_loss: 2.1070 - val_accuracy: 0.2230
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.1449 - accuracy: 0.1993 - val_loss: 2.1112 - val_accuracy: 0.2215
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.3}, learning rate: 0.01, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 7s 31ms/step - loss: 2.8098 - accuracy: 0.1275 - val_loss: 4.0337 - val_accuracy: 0.1200
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.4414 - accuracy: 0.1484 - val_loss: 2.5964 - val_accuracy: 0.1674
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3229 - accuracy: 0.1687 - val_loss: 2.2014 - val_accuracy: 0.1800
# Epoch 4/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.2889 - accuracy: 0.1688 - val_loss: 2.1984 - val_accuracy: 0.1867
# Epoch 5/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.2277 - accuracy: 0.1832 - val_loss: 2.1568 - val_accuracy: 0.2178
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.1907 - accuracy: 0.1818 - val_loss: 2.1487 - val_accuracy: 0.1896
# Epoch 7/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.1671 - accuracy: 0.1922 - val_loss: 2.1306 - val_accuracy: 0.1963
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.1639 - accuracy: 0.1990 - val_loss: 2.1589 - val_accuracy: 0.2111
# Epoch 9/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.1527 - accuracy: 0.1994 - val_loss: 2.1134 - val_accuracy: 0.2141
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.1427 - accuracy: 0.2062 - val_loss: 2.1082 - val_accuracy: 0.2074
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.5}, learning rate: 0.01, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 8s 32ms/step - loss: 3.0124 - accuracy: 0.1192 - val_loss: 3.0127 - val_accuracy: 0.1370
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.4917 - accuracy: 0.1325 - val_loss: 2.3531 - val_accuracy: 0.1541
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3879 - accuracy: 0.1380 - val_loss: 2.2559 - val_accuracy: 0.1681
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3100 - accuracy: 0.1440 - val_loss: 2.2064 - val_accuracy: 0.1756
# Epoch 5/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.2695 - accuracy: 0.1535 - val_loss: 2.1970 - val_accuracy: 0.1637
# Epoch 6/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.2341 - accuracy: 0.1634 - val_loss: 2.2004 - val_accuracy: 0.1696
# Epoch 7/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.2193 - accuracy: 0.1709 - val_loss: 2.1801 - val_accuracy: 0.1956
# Epoch 8/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.2062 - accuracy: 0.1767 - val_loss: 2.1801 - val_accuracy: 0.1822
# Epoch 9/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.1967 - accuracy: 0.1764 - val_loss: 2.1725 - val_accuracy: 0.1815
# Epoch 10/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.1944 - accuracy: 0.1814 - val_loss: 2.1669 - val_accuracy: 0.1830
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.5}, learning rate: 0.01, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 11s 33ms/step - loss: 2.9883 - accuracy: 0.1152 - val_loss: 3.5810 - val_accuracy: 0.1148
# Epoch 2/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.5015 - accuracy: 0.1328 - val_loss: 2.3236 - val_accuracy: 0.1437
# Epoch 3/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3947 - accuracy: 0.1372 - val_loss: 2.3092 - val_accuracy: 0.1437
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3167 - accuracy: 0.1469 - val_loss: 2.2208 - val_accuracy: 0.1719
# Epoch 5/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.2680 - accuracy: 0.1558 - val_loss: 2.1981 - val_accuracy: 0.1615
# Epoch 6/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.2322 - accuracy: 0.1621 - val_loss: 2.1936 - val_accuracy: 0.1770
# Epoch 7/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.2196 - accuracy: 0.1745 - val_loss: 2.1731 - val_accuracy: 0.1793
# Epoch 8/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.2042 - accuracy: 0.1751 - val_loss: 2.1746 - val_accuracy: 0.1748
# Epoch 9/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.2010 - accuracy: 0.1763 - val_loss: 2.1823 - val_accuracy: 0.1807
# Epoch 10/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.2026 - accuracy: 0.1733 - val_loss: 2.1655 - val_accuracy: 0.1807
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.5}, learning rate: 0.01, seed: 9
# Epoch 1/10
# 74/74 [==============================] - 8s 32ms/step - loss: 2.9868 - accuracy: 0.1195 - val_loss: 4.3345 - val_accuracy: 0.1230
# Epoch 2/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.5064 - accuracy: 0.1278 - val_loss: 2.4156 - val_accuracy: 0.1148
# Epoch 3/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.3883 - accuracy: 0.1354 - val_loss: 2.2457 - val_accuracy: 0.1563
# Epoch 4/10
# 74/74 [==============================] - 1s 13ms/step - loss: 2.3154 - accuracy: 0.1480 - val_loss: 2.2085 - val_accuracy: 0.1689
# Epoch 5/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.2667 - accuracy: 0.1604 - val_loss: 2.2107 - val_accuracy: 0.1711
# Epoch 6/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.2258 - accuracy: 0.1654 - val_loss: 2.1995 - val_accuracy: 0.1711
# Epoch 7/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.2177 - accuracy: 0.1676 - val_loss: 2.2015 - val_accuracy: 0.1711
# Epoch 8/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.2143 - accuracy: 0.1727 - val_loss: 2.1792 - val_accuracy: 0.1919
# Epoch 9/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.2007 - accuracy: 0.1714 - val_loss: 2.1563 - val_accuracy: 0.1874
# Epoch 10/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.1970 - accuracy: 0.1710 - val_loss: 2.1567 - val_accuracy: 0.1800
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.8}, learning rate: 0.01, seed: 123
# Epoch 1/10
# 74/74 [==============================] - 7s 33ms/step - loss: 3.6740 - accuracy: 0.1029 - val_loss: 2.3145 - val_accuracy: 0.1178
# Epoch 2/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.7197 - accuracy: 0.1061 - val_loss: 2.3164 - val_accuracy: 0.1185
# Epoch 3/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.5206 - accuracy: 0.1076 - val_loss: 2.3133 - val_accuracy: 0.1141
# Epoch 4/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.4172 - accuracy: 0.1101 - val_loss: 2.3193 - val_accuracy: 0.0941
# Epoch 5/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.3476 - accuracy: 0.1131 - val_loss: 2.3150 - val_accuracy: 0.1022
# Epoch 6/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.3185 - accuracy: 0.1156 - val_loss: 2.3078 - val_accuracy: 0.0948
# Epoch 7/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.3016 - accuracy: 0.1198 - val_loss: 2.3061 - val_accuracy: 0.1067
# Epoch 8/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.3016 - accuracy: 0.1185 - val_loss: 2.3028 - val_accuracy: 0.0993
# Epoch 9/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.2969 - accuracy: 0.1231 - val_loss: 2.3005 - val_accuracy: 0.1185
# Epoch 10/10
# 74/74 [==============================] - 1s 12ms/step - loss: 2.2969 - accuracy: 0.1222 - val_loss: 2.3023 - val_accuracy: 0.1089
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.8}, learning rate: 0.01, seed: 42
# Epoch 1/10
# 74/74 [==============================] - 7s 31ms/step - loss: 3.6536 - accuracy: 0.1058 - val_loss: 2.3359 - val_accuracy: 0.1089
# Epoch 2/10
# ...
# Epoch 6/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.2141 - accuracy: 0.1820 - val_loss: 2.1690 - val_accuracy: 0.2044
# Epoch 7/10
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1867 - accuracy: 0.1911 - val_loss: 2.1249 - val_accuracy: 0.2281
# Epoch 8/10
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1719 - accuracy: 0.1892 - val_loss: 2.1220 - val_accuracy: 0.2178
# Epoch 9/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.1564 - accuracy: 0.2044 - val_loss: 2.1844 - val_accuracy: 0.1896
# Epoch 10/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.1498 - accuracy: 0.1978 - val_loss: 2.1019 - val_accuracy: 0.2341
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 64, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.3}, learning rate: 0.005, seed: 9
# Epoch 1/10
# 148/148 [==============================] - 8s 20ms/step - loss: 2.7078 - accuracy: 0.1327 - val_loss: 2.4878 - val_accuracy: 0.1304
# Epoch 2/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.4120 - accuracy: 0.1507 - val_loss: 2.3238 - val_accuracy: 0.1637
# Epoch 3/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.3427 - accuracy: 0.1617 - val_loss: 2.2676 - val_accuracy: 0.1674
# Epoch 4/10
# 148/148 [==============================] - 2s 12ms/step - loss: 2.2736 - accuracy: 0.1693 - val_loss: 2.2046 - val_accuracy: 0.1793
# Epoch 5/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.2414 - accuracy: 0.1838 - val_loss: 2.1384 - val_accuracy: 0.2200
# Epoch 6/10
# 148/148 [==============================] - 2s 10ms/step - loss: 2.2003 - accuracy: 0.1908 - val_loss: 2.1599 - val_accuracy: 0.1941
# Epoch 7/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.1810 - accuracy: 0.1949 - val_loss: 2.1497 - val_accuracy: 0.1985
# Epoch 8/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.1765 - accuracy: 0.1974 - val_loss: 2.1755 - val_accuracy: 0.1970
# Epoch 9/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.1545 - accuracy: 0.2028 - val_loss: 2.1156 - val_accuracy: 0.2267
# Epoch 10/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.1511 - accuracy: 0.2020 - val_loss: 2.1107 - val_accuracy: 0.2022
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 64, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.3}, learning rate: 0.001, seed: 123
# Epoch 1/10
# 148/148 [==============================] - 8s 21ms/step - loss: 2.8953 - accuracy: 0.1294 - val_loss: 2.5516 - val_accuracy: 0.1370
# Epoch 2/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.5239 - accuracy: 0.1428 - val_loss: 2.2400 - val_accuracy: 0.1733
# Epoch 3/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.4010 - accuracy: 0.1545 - val_loss: 2.2015 - val_accuracy: 0.1822
# Epoch 4/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.3356 - accuracy: 0.1560 - val_loss: 2.2019 - val_accuracy: 0.1756
# Epoch 5/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.2885 - accuracy: 0.1686 - val_loss: 2.1955 - val_accuracy: 0.2022
# Epoch 6/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.2467 - accuracy: 0.1711 - val_loss: 2.1674 - val_accuracy: 0.1896
# Epoch 7/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.2392 - accuracy: 0.1758 - val_loss: 2.1552 - val_accuracy: 0.1970
# Epoch 8/10
# 148/148 [==============================] - 2s 12ms/step - loss: 2.2188 - accuracy: 0.1832 - val_loss: 2.1389 - val_accuracy: 0.1889
# Epoch 9/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.2086 - accuracy: 0.1805 - val_loss: 2.1728 - val_accuracy: 0.1978
# Epoch 10/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.2015 - accuracy: 0.1940 - val_loss: 2.1842 - val_accuracy: 0.2015
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 64, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.3}, learning rate: 0.001, seed: 42
# Epoch 1/10
# 148/148 [==============================] - 13s 23ms/step - loss: 2.8845 - accuracy: 0.1325 - val_loss: 2.3389 - val_accuracy: 0.1467
# Epoch 2/10
# 148/148 [==============================] - 2s 12ms/step - loss: 2.5043 - accuracy: 0.1406 - val_loss: 2.2101 - val_accuracy: 0.1674
# Epoch 3/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.3990 - accuracy: 0.1516 - val_loss: 2.2187 - val_accuracy: 0.1630
# Epoch 4/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.3273 - accuracy: 0.1595 - val_loss: 2.1882 - val_accuracy: 0.1830
# Epoch 5/10
# 148/148 [==============================] - 2s 12ms/step - loss: 2.2742 - accuracy: 0.1735 - val_loss: 2.2121 - val_accuracy: 0.1607
# Epoch 6/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.2567 - accuracy: 0.1701 - val_loss: 2.2195 - val_accuracy: 0.1667
# Epoch 7/10
# 148/148 [==============================] - 2s 12ms/step - loss: 2.2316 - accuracy: 0.1811 - val_loss: 2.2079 - val_accuracy: 0.1919
# Epoch 8/10
# 148/148 [==============================] - 2s 13ms/step - loss: 2.2246 - accuracy: 0.1781 - val_loss: 2.1502 - val_accuracy: 0.2007
# Epoch 9/10
# 148/148 [==============================] - 2s 12ms/step - loss: 2.2090 - accuracy: 0.1898 - val_loss: 2.1796 - val_accuracy: 0.1956
# Epoch 10/10
# 148/148 [==============================] - 2s 12ms/step - loss: 2.2013 - accuracy: 0.1897 - val_loss: 2.1455 - val_accuracy: 0.2037
# 1688/1688 [==============================] - 14s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 64, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.3}, learning rate: 0.001, seed: 9
# Epoch 1/10
# 148/148 [==============================] - 9s 21ms/step - loss: 2.8837 - accuracy: 0.1327 - val_loss: 2.3332 - val_accuracy: 0.1437
# Epoch 2/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.5252 - accuracy: 0.1429 - val_loss: 2.2174 - val_accuracy: 0.1874
# Epoch 3/10
# 148/148 [==============================] - 2s 12ms/step - loss: 2.3888 - accuracy: 0.1527 - val_loss: 2.2323 - val_accuracy: 0.1563
# Epoch 4/10
# 148/148 [==============================] - 2s 12ms/step - loss: 2.3341 - accuracy: 0.1544 - val_loss: 2.2177 - val_accuracy: 0.1800
# Epoch 5/10
# 148/148 [==============================] - 2s 12ms/step - loss: 2.2897 - accuracy: 0.1687 - val_loss: 2.1746 - val_accuracy: 0.1807
# Epoch 6/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.2579 - accuracy: 0.1707 - val_loss: 2.2304 - val_accuracy: 0.1674
# Epoch 7/10
# 148/148 [==============================] - 2s 12ms/step - loss: 2.2337 - accuracy: 0.1743 - val_loss: 2.2088 - val_accuracy: 0.1644
# Epoch 8/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.2237 - accuracy: 0.1804 - val_loss: 2.1542 - val_accuracy: 0.1919
# Epoch 9/10
# 148/148 [==============================] - 2s 11ms/step - loss: 2.2002 - accuracy: 0.1853 - val_loss: 2.1495 - val_accuracy: 0.2037
# Epoch 10/10
# 148/148 [==============================] - 2s 12ms/step - loss: 2.2005 - accuracy: 0.1857 - val_loss: 2.1437 - val_accuracy: 0.1963
# 1688/1688 [==============================] - 13s 7ms/step
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Performing experiment with model: ModelType.MobileNet, batch size: 64, epochs: 50, augmentation: AugmentationTechnique.NoAugmentation, regularizer: {'type': <RegularizationType.Dropout: 3>, 'value': 0.3}, learning rate: 0.005, seed: 9
# Epoch 1/50
# 148/148 [==============================] - 9s 22ms/step - loss: 2.7078 - accuracy: 0.1327 - val_loss: 2.4878 - val_accuracy: 0.1304
# Epoch 2/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.4120 - accuracy: 0.1507 - val_loss: 2.3238 - val_accuracy: 0.1637
# Epoch 3/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.3427 - accuracy: 0.1617 - val_loss: 2.2676 - val_accuracy: 0.1674
# Epoch 4/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.2736 - accuracy: 0.1693 - val_loss: 2.2046 - val_accuracy: 0.1793
# Epoch 5/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.2414 - accuracy: 0.1838 - val_loss: 2.1384 - val_accuracy: 0.2200
# Epoch 6/50
# 148/148 [==============================] - 2s 13ms/step - loss: 2.2003 - accuracy: 0.1908 - val_loss: 2.1599 - val_accuracy: 0.1941
# Epoch 7/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1810 - accuracy: 0.1949 - val_loss: 2.1497 - val_accuracy: 0.1985
# Epoch 8/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1765 - accuracy: 0.1974 - val_loss: 2.1755 - val_accuracy: 0.1970
# Epoch 9/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1545 - accuracy: 0.2028 - val_loss: 2.1156 - val_accuracy: 0.2267
# Epoch 10/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1511 - accuracy: 0.2020 - val_loss: 2.1107 - val_accuracy: 0.2022
# Epoch 11/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1406 - accuracy: 0.2051 - val_loss: 2.0938 - val_accuracy: 0.2430
# Epoch 12/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1367 - accuracy: 0.2088 - val_loss: 2.1585 - val_accuracy: 0.2015
# Epoch 13/50
# 148/148 [==============================] - 2s 13ms/step - loss: 2.1347 - accuracy: 0.2178 - val_loss: 2.0899 - val_accuracy: 0.2281
# Epoch 14/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1255 - accuracy: 0.2164 - val_loss: 2.1131 - val_accuracy: 0.2200
# Epoch 15/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1298 - accuracy: 0.2150 - val_loss: 2.1005 - val_accuracy: 0.2089
# Epoch 16/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1263 - accuracy: 0.2177 - val_loss: 2.0929 - val_accuracy: 0.2244
# Epoch 17/50
# 148/148 [==============================] - 2s 11ms/step - loss: 2.1277 - accuracy: 0.2157 - val_loss: 2.0981 - val_accuracy: 0.2207
# Epoch 18/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1279 - accuracy: 0.2206 - val_loss: 2.1014 - val_accuracy: 0.2244
# Epoch 19/50
# 148/148 [==============================] - 2s 13ms/step - loss: 2.1255 - accuracy: 0.2150 - val_loss: 2.0953 - val_accuracy: 0.2170
# Epoch 20/50
# 148/148 [==============================] - 2s 13ms/step - loss: 2.1281 - accuracy: 0.2116 - val_loss: 2.0794 - val_accuracy: 0.2304
# Epoch 21/50
# 148/148 [==============================] - 2s 11ms/step - loss: 2.1240 - accuracy: 0.2198 - val_loss: 2.0813 - val_accuracy: 0.2222
# Epoch 22/50
# 148/148 [==============================] - 2s 11ms/step - loss: 2.1199 - accuracy: 0.2214 - val_loss: 2.0822 - val_accuracy: 0.2378
# Epoch 23/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1242 - accuracy: 0.2137 - val_loss: 2.0839 - val_accuracy: 0.2481
# Epoch 24/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1210 - accuracy: 0.2164 - val_loss: 2.0980 - val_accuracy: 0.2193
# Epoch 25/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1207 - accuracy: 0.2165 - val_loss: 2.0828 - val_accuracy: 0.2356
# Epoch 26/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1205 - accuracy: 0.2213 - val_loss: 2.0776 - val_accuracy: 0.2430
# Epoch 27/50
# 148/148 [==============================] - 2s 13ms/step - loss: 2.1154 - accuracy: 0.2183 - val_loss: 2.0919 - val_accuracy: 0.2163
# Epoch 28/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1188 - accuracy: 0.2156 - val_loss: 2.0837 - val_accuracy: 0.2370
# Epoch 29/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1190 - accuracy: 0.2248 - val_loss: 2.0855 - val_accuracy: 0.2311
# Epoch 30/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1222 - accuracy: 0.2200 - val_loss: 2.1159 - val_accuracy: 0.2156
# Epoch 31/50
# 148/148 [==============================] - 2s 11ms/step - loss: 2.1195 - accuracy: 0.2130 - val_loss: 2.0927 - val_accuracy: 0.2067
# Epoch 32/50
# 148/148 [==============================] - 2s 11ms/step - loss: 2.1219 - accuracy: 0.2142 - val_loss: 2.0788 - val_accuracy: 0.2563
# Epoch 33/50
# 148/148 [==============================] - 2s 11ms/step - loss: 2.1133 - accuracy: 0.2207 - val_loss: 2.0753 - val_accuracy: 0.2304
# Epoch 34/50
# 148/148 [==============================] - 2s 13ms/step - loss: 2.1190 - accuracy: 0.2187 - val_loss: 2.0834 - val_accuracy: 0.2304
# Epoch 35/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1183 - accuracy: 0.2212 - val_loss: 2.0912 - val_accuracy: 0.2200
# Epoch 36/50
# 148/148 [==============================] - 2s 11ms/step - loss: 2.1191 - accuracy: 0.2126 - val_loss: 2.0798 - val_accuracy: 0.2296
# Epoch 37/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1114 - accuracy: 0.2219 - val_loss: 2.0956 - val_accuracy: 0.2363
# Epoch 38/50
# 148/148 [==============================] - 2s 11ms/step - loss: 2.1170 - accuracy: 0.2205 - val_loss: 2.0861 - val_accuracy: 0.2237
# Epoch 39/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1182 - accuracy: 0.2159 - val_loss: 2.0678 - val_accuracy: 0.2444
# Epoch 40/50
# 148/148 [==============================] - 2s 11ms/step - loss: 2.1174 - accuracy: 0.2193 - val_loss: 2.0862 - val_accuracy: 0.2237
# Epoch 41/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1122 - accuracy: 0.2199 - val_loss: 2.0700 - val_accuracy: 0.2370
# Epoch 42/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1104 - accuracy: 0.2202 - val_loss: 2.0891 - val_accuracy: 0.2281
# Epoch 43/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1208 - accuracy: 0.2234 - val_loss: 2.0789 - val_accuracy: 0.2178
# Epoch 44/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1097 - accuracy: 0.2233 - val_loss: 2.0868 - val_accuracy: 0.2356
# Epoch 45/50
# 148/148 [==============================] - 2s 13ms/step - loss: 2.1213 - accuracy: 0.2187 - val_loss: 2.0762 - val_accuracy: 0.2230
# Epoch 46/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1229 - accuracy: 0.2172 - val_loss: 2.0905 - val_accuracy: 0.2274
# Epoch 47/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1088 - accuracy: 0.2202 - val_loss: 2.0689 - val_accuracy: 0.2504
# Epoch 48/50
# 148/148 [==============================] - 2s 14ms/step - loss: 2.1128 - accuracy: 0.2213 - val_loss: 2.1008 - val_accuracy: 0.2326
# Epoch 49/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1099 - accuracy: 0.2185 - val_loss: 2.0518 - val_accuracy: 0.2422
# Epoch 50/50
# 148/148 [==============================] - 2s 12ms/step - loss: 2.1105 - accuracy: 0.2169 - val_loss: 2.0661 - val_accuracy: 0.2422
# 1688/1688 [==============================] - 14s 7ms/step

# %%
print(results)
print(best)
print(histories)

with open("results-mobilenet","wb") as my_csv:
    pickle.dump(results,my_csv)

with open("best-mobilenet","wb") as my_csv:
    pickle.dump(best,my_csv)
with open("histories-mobilenet","wb") as my_csv:
    pickle.dump(histories,my_csv)




# Plot training and validation accuracy
plt.plot(histories[len(histories)-1].history['accuracy'], label='Training Accuracy')
plt.plot(histories[len(histories)-1].history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.savefig("MobileNet-50epochs-TrainingandValidationAccuracy.pdf", format="pdf", bbox_inches="tight")
plt.show()

# Plot training and validation loss
plt.plot(histories[len(histories)-1].history['loss'], label='Training Loss')
plt.plot(histories[len(histories)-1].history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.savefig("MobileNet-50epochs-TrainingandValidationLoss.pdf", format="pdf", bbox_inches="tight")
plt.show()

model = createModel(modelType=ModelType.MobileNet,regularizer={"type":RegularizationType.NoRegularization,"value":0},optimizer=getOptimizer(type=OptimizerType.Adam,learningRate=0.01), loss='categorical_crossentropy', metrics=['accuracy'],seed=123, augmentation=AugmentationTechnique.NoAugmentation)
# train the model
history = model.fit(batch_size=64,epochs=10, train_images=train_images,train_labels=train_labels,valid_images=valid_images,valid_labels=valid_labels)



with open("mobilenet-history","wb") as my_csv:
    pickle.dump(history,my_csv)



# get accuracy
y_pred = model.predict(test_images)
# Convert probabilities to class labels
predicted_classes = np.argmax(y_pred, axis=1)

# Get true class labels
true_classes = np.argmax(test_labels, axis=1)
accuracy = getAccuracy(predicted_classes,true_classes)


# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.savefig("MobileNet-TrainingandValidationAccuracy.pdf", format="pdf", bbox_inches="tight")
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.savefig("MobileNet-TrainingandValidationLoss.pdf", format="pdf", bbox_inches="tight")
plt.show()


# Predict probabilities for test data
predictions = model.predict(test_images)
# Convert probabilities to class labels
predicted_classes = np.argmax(predictions, axis=1)

# Get true class labels
true_classes = np.argmax(test_labels, axis=1)

# Get class labels
class_labels = sorted(os.listdir(test_data_dir))
class_labels = [class_name for class_name in class_labels if class_name != '.DS_Store']

# Create confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Normalize confusion matrix
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plot confusion matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.savefig("MobileNet-ConfusionMatrix.pdf", format="pdf", bbox_inches="tight")
plt.show()
# Out:
# [[0.17644444444444443, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 123], [0.10472222222222222, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 42], [0.16505555555555557, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 9], [0.1, <AugmentationTechnique.Rotation: 1>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 123], [0.1, <AugmentationTechnique.Rotation: 1>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 42], [0.1, <AugmentationTechnique.Rotation: 1>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 9], [0.1, <AugmentationTechnique.Flipping: 2>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 123], [0.1, <AugmentationTechnique.Flipping: 2>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 42], [0.1, <AugmentationTechnique.Flipping: 2>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 9], [0.1, <AugmentationTechnique.Zoom: 4>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 123], [0.1, <AugmentationTechnique.Zoom: 4>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 42], [0.1, <AugmentationTechnique.Zoom: 4>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 9], [0.1, <AugmentationTechnique.Brightness: 5>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 123], [0.1, <AugmentationTechnique.Brightness: 5>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 42], [0.1, <AugmentationTechnique.Brightness: 5>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 9], [0.1, <AugmentationTechnique.RandomErasing: 6>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 123], [0.1, <AugmentationTechnique.RandomErasing: 6>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 42], [0.1, <AugmentationTechnique.RandomErasing: 6>, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, 128, 0.01, 10, 9], [0.20777777777777778, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.3}, 128, 0.01, 10, 123], [0.22922222222222222, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.3}, 128, 0.01, 10, 42], [0.22024074074074074, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.3}, 128, 0.01, 10, 9], [0.19253703703703703, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.5}, 128, 0.01, 10, 123], [0.1925, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.5}, 128, 0.01, 10, 42], [0.19011111111111112, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.5}, 128, 0.01, 10, 9], [0.111, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.8}, 128, 0.01, 10, 123], [0.1057037037037037, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.8}, 128, 0.01, 10, 42], [0.10664814814814814, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.8}, 128, 0.01, 10, 9], [0.10316666666666667, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.L2: 2>, 'value': 0.001}, 128, 0.01, 10, 123], [0.1434074074074074, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.L2: 2>, 'value': 0.001}, 128, 0.01, 10, 42], [0.103, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.L2: 2>, 'value': 0.001}, 128,  ...
# [0.24322222222222223, 64, 0.005, 10, <AugmentationTechnique.NoAugmentation: 0>, {'type': <RegularizationType.Dropout: 3>, 'value': 0.3}]
# [<keras.src.callbacks.History object at 0x7e422683b6a0>]
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/10
# 2954/2954 [==============================] - 40s 12ms/step - loss: 1.9681 - accuracy: 0.2901 - val_loss: 2.1436 - val_accuracy: 0.2698
# Epoch 2/10
# 2954/2954 [==============================] - 32s 11ms/step - loss: 1.8592 - accuracy: 0.3211 - val_loss: 2.2162 - val_accuracy: 0.2173
# Epoch 3/10
# 2954/2954 [==============================] - 33s 11ms/step - loss: 1.8427 - accuracy: 0.3286 - val_loss: 7.7028 - val_accuracy: 0.2018
# Epoch 4/10
# 2954/2954 [==============================] - 32s 11ms/step - loss: 1.8311 - accuracy: 0.3327 - val_loss: 2.7248 - val_accuracy: 0.2139
# Epoch 5/10
# 2954/2954 [==============================] - 31s 10ms/step - loss: 1.8206 - accuracy: 0.3365 - val_loss: 2.4853 - val_accuracy: 0.2121
# Epoch 6/10
# 2954/2954 [==============================] - 30s 10ms/step - loss: 1.8113 - accuracy: 0.3409 - val_loss: 2.1001 - val_accuracy: 0.2682
# Epoch 7/10
# 2954/2954 [==============================] - 31s 10ms/step - loss: 1.8106 - accuracy: 0.3423 - val_loss: 6.7003 - val_accuracy: 0.1288
# Epoch 8/10
# 2954/2954 [==============================] - 31s 10ms/step - loss: 1.8026 - accuracy: 0.3462 - val_loss: 2.5864 - val_accuracy: 0.2223
# Epoch 9/10
# 2954/2954 [==============================] - 32s 11ms/step - loss: 1.8008 - accuracy: 0.3457 - val_loss: 16.6895 - val_accuracy: 0.1202
# Epoch 10/10
# 2954/2954 [==============================] - 31s 10ms/step - loss: 1.7970 - accuracy: 0.3470 - val_loss: 2.2568 - val_accuracy: 0.2474
# 1688/1688 [==============================] - 13s 7ms/step
# 1688/1688 [==============================] - 11s 7ms/step

# %%
indicesAugmentation = [0,17]
indicesRegularization = [18,35]
indicesBatchSize = [36,41]
indicesLearningRates = [42,47]
columns = ['Accuracy','Augmentation','Regularizer','Batch Size','Learning Rate','Number of Epochs','Seed']

# %%
def extractAugmentationName(augmentation):
    match augmentation:
        case AugmentationTechnique.NoAugmentation:
            return 'No Augmentation';
        case AugmentationTechnique.Rotation:
            return 'Rotation'
        case AugmentationTechnique.Flipping:
            return 'Flipping'
        case AugmentationTechnique.Brightness:
            return 'Brightness'
        case AugmentationTechnique.Contrast:
            return 'Contrast'
        case AugmentationTechnique.RandomErasing:
            return 'Random Erasing'
        case AugmentationTechnique.Zoom:
            return 'Zoom'
def extractRegularizationType(regularization):
    match regularization['type']:
        case RegularizationType.Dropout:
            return "Dropout ("+str(regularization['value'])+")"
        case RegularizationType.NoRegularization:
            return "None"
        case RegularizationType.L2:
            return "L2 ("+str(regularization['value'])+")"

# %%
def extractResults(results,best, modelName):
    # bestDF = pd.DataFrame(best,columns = ['Accuracy','Batch Size','Learning Rate','Number of Epochs','Augmentation','Regularizer'])
    augmentationResults = pd.DataFrame(results[indicesAugmentation[0]:indicesAugmentation[1]+1], columns=columns)
    regularizationResults = pd.DataFrame(results[indicesRegularization[0]:indicesRegularization[1]+1], columns=columns)
    batchSizesResults = pd.DataFrame(results[indicesBatchSize[0]:indicesBatchSize[1]+1], columns=columns)
    learningRatesResults = pd.DataFrame(results[indicesLearningRates[0]:indicesLearningRates[1]+1], columns=columns)

    result1 = augmentationResults.loc[augmentationResults['Regularizer'] == regularizers[0]]
    result2 = result1.loc[result1['Augmentation'] == best[4]]
    regularizationResults = pd.concat([regularizationResults, result2], ignore_index=True, sort=False)


    result1 = regularizationResults.loc[regularizationResults['Batch Size'] == batchSizes[0]]
    result2 = result1.loc[result1['Regularizer'] == best[5]]
    batchSizesResults = pd.concat([batchSizesResults, result2], ignore_index=True, sort=False)

    result1 = batchSizesResults.loc[batchSizesResults['Learning Rate'] == learningRates[0]]
    result2 = result1.loc[result1['Batch Size'] == best[1]]
    learningRatesResults = pd.concat([learningRatesResults, result2], ignore_index=True, sort=False)


    augmentationResults['Augmentation'] = augmentationResults['Augmentation'].apply(extractAugmentationName)
    regularizationResults['Regularizer'] = regularizationResults['Regularizer'].apply(extractRegularizationType)

    plt.figure(figsize=(8,8))
    plt.title("Accuracy vs Augmentation ("+modelName+")")
    sns.boxplot(data=augmentationResults,x='Augmentation',y='Accuracy')
    plt.savefig("AccuracyvsAugmentation"+f"{modelName}.pdf", format="pdf", bbox_inches="tight")
    plt.show()
    plt.figure(figsize=(9,9))
    plt.title("Accuracy vs Regularizer ("+modelName+")")
    sns.boxplot(data=regularizationResults,x='Regularizer',y='Accuracy')
    plt.savefig("AccuracyvsRegularizer"+f"{modelName}.pdf", format="pdf", bbox_inches="tight")
    plt.show()

    plt.title("Accuracy vs Batch Size ("+modelName+")")
    sns.boxplot(data=batchSizesResults,x='Batch Size',y='Accuracy')
    plt.savefig("AccuracyvsBatchSize"+f"{modelName}.pdf", format="pdf", bbox_inches="tight")
    plt.show()

    plt.title("Accuracy vs Learning Rate ("+modelName+")")
    sns.boxplot(data=learningRatesResults,x='Learning Rate',y='Accuracy')
    plt.savefig("AccuracyvsLearningRate"+f"{modelName}.pdf", format="pdf", bbox_inches="tight")
    plt.show()

# %%
with open(r"results", "rb") as input_file:
    results = pickle.load(input_file)

with open(r"best", "rb") as input_file:
    best = pickle.load(input_file)

extractResults(results=results,best=best,modelName='EfficientNet')

with open(r"results-mobilenet", "rb") as input_file:
    results = pickle.load(input_file)

with open(r"best-mobilenet", "rb") as input_file:
    best = pickle.load(input_file)

extractResults(results=results,best=best,modelName='MobileNet')
