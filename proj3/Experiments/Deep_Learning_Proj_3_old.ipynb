# %% [markdown]
# # Deep Learning Project 3 - Patryk Prusak,  Dutt Salveen Singh

# %% [markdown]
# # Imports and consts

# %%
IS_IN_COLAB = False
# If the background noise is not split (it's in its original form) set it to False
BG_IS_ALREADY_SPLIT = False

# %%
if IS_IN_COLAB:
    # !pip install pydub
    # !pip install faster_whisper
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
# Collecting faster_whisper
#   Downloading faster_whisper-1.0.2-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 23.9 MB/s eta 0:00:00
# Collecting av<13,>=11.0 (from faster_whisper)
#   Downloading av-12.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 38.1 MB/s eta 0:00:00
# Collecting ctranslate2<5,>=4.0 (from faster_whisper)
#   Downloading ctranslate2-4.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (179.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.4/179.4 MB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.13 in /usr/local/lib/python3.10/dist-packages (from faster_whisper) (0.20.3)
# Requirement already satisfied: tokenizers<1,>=0.13 in /usr/local/lib/python3.10/dist-packages (from faster_whisper) (0.19.1)
# Collecting onnxruntime<2,>=1.14 (from faster_whisper)
#   Downloading onnxruntime-1.17.3-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 102.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from ctranslate2<5,>=4.0->faster_whisper) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ctranslate2<5,>=4.0->faster_whisper) (1.25.2)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.10/dist-packages (from ctranslate2<5,>=4.0->faster_whisper) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster_whisper) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster_whisper) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster_whisper) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster_whisper) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster_whisper) (4.11.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster_whisper) (24.0)
# Collecting coloredlogs (from onnxruntime<2,>=1.14->faster_whisper)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster_whisper) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster_whisper) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster_whisper) (1.12)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<2,>=1.14->faster_whisper)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster_whisper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster_whisper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster_whisper) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster_whisper) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime<2,>=1.14->faster_whisper) (1.3.0)
# Installing collected packages: humanfriendly, ctranslate2, av, coloredlogs, onnxruntime, faster_whisper
# Successfully installed av-12.0.0 coloredlogs-15.0.1 ctranslate2-4.2.1 faster_whisper-1.0.2 humanfriendly-10.0 onnxruntime-1.17.3

# %%
import os
import pandas as pd
import numpy as np
from scipy.fftpack import fft
from scipy import signal
from scipy.io import wavfile
import librosa
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
import cv2
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, LSTM, Dense, Flatten, Reshape, Dropout
from keras.optimizers import Adam, SGD, Lion
from keras.regularizers import L2
import keras.regularizers
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score
import shutil
import random
import pickle
import pandas as pd
from enum import Enum
from pydub import AudioSegment
from faster_whisper import WhisperModel

# %%
if IS_IN_COLAB:
    from google.colab import drive

    drive.mount("/content/drive")
    !7z x /content/drive/'My Drive'/Studia/Masters/DeepLearning/Project2/Dataset/train.7z -o/content/dataset/
# Out:
# Mounted at /content/drive
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,8 CPUs Intel(R) Xeon(R) CPU @ 2.00GHz (50653),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 1121103842 bytes (1070 MiB)
#
# Extracting archive: /content/drive/My Drive/Studia/Masters/DeepLearning/Project2/Dataset/train.7z
# --
# Path = /content/drive/My Drive/Studia/Masters/DeepLearning/Project2/Dataset/train.7z
# Type = 7z
# Physical Size = 1121103842
# Headers Size = 389133
# Method = Delta LZMA2:24
# Solid = +
# Blocks = 2
#
# Everything is Ok
#
# Folders: 33
# Files: 64732
# Size:       2055161498
# Compressed: 1121103842

# %%
# !7z x /content/drive/'My Drive'/Studia/Masters/DeepLearning/Project2/Dataset/test.7z -o/content/dataset/

# %%
if IS_IN_COLAB:
    DATASET_DIR = "/content/dataset/train/audio/"
else:
    DATASET_DIR = "../Dataset/train/audio/"
# DATASET_DIR_TEST = '/content/dataset/test/audio/'

# %% [markdown]
# # Helper Functions

# %%
def set_seed(seed=0):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    random.seed(seed)
    os.environ["TF_DETERMINISTIC_OPS"] = "1"
    os.environ["TF_CUDNN_DETERMINISM"] = "1"
    os.environ["PYTHONHASHSEED"] = str(seed)

# %%
def log_specgram(audio, sample_rate, window_size=20, step_size=10, eps=1e-10):
    nperseg = int(round(window_size * sample_rate / 1e3))
    noverlap = int(round(step_size * sample_rate / 1e3))
    freqs, times, spec = signal.spectrogram(
        audio,
        fs=sample_rate,
        window="hann",
        nperseg=nperseg,
        noverlap=noverlap,
        detrend=False,
    )
    return freqs, times, np.log(spec.T.astype(np.float32) + eps)

# %%
def preprocess_data(row, num_classes):
    signal_path = DATASET_DIR + row["label_name"] + "/" + row["path"]
    samples, sample_rate = librosa.load(signal_path, mono=True, sr=None)
    freqs, times, spectrogram = log_specgram(samples, sample_rate)
    img = cv2.resize(spectrogram, (32, 32))
    img = np.divide((img - np.mean(img)), np.std(img), out=img, where=np.std(img) != 0)
    img = np.stack((img,) * 3, axis=-1).astype(np.float32)
    label = np.zeros(num_classes)
    label[row["label"]] = 1
    return img, label


def create_dataset(df, num_classes, batch_size):
    def generator():
        for index, row in df.iterrows():
            img, label = preprocess_data(row, num_classes)
            yield img, label

    dataset = tf.data.Dataset.from_generator(
        generator,
        output_signature=(
            tf.TensorSpec(shape=(32, 32, 3), dtype=tf.float32),
            tf.TensorSpec(shape=(num_classes,), dtype=tf.float32),
        ),
    )
    # dataset = dataset.shuffle(buffer_size=len(df))
    dataset = dataset.batch(batch_size)
    # dataset = dataset.prefetch(2)
    return dataset

# %%
def split_audio_file(input_file, output_dir, split_length=1000, overlap=0.99):
    audio = AudioSegment.from_wav(input_file)
    file_name = os.path.basename(input_file)
    file_name_no_extension = os.path.splitext(file_name)[0]

    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Calculate the overlap duration
    overlap_duration = int(split_length * overlap)

    # Split the audio with overlap
    start_time = 0
    end_time = split_length
    i = 1
    while end_time < len(audio):
        chunk = audio[start_time:end_time]
        chunk.export(
            os.path.join(output_dir, f"{file_name_no_extension}_{i}.wav"), format="wav"
        )
        i += 1
        start_time = end_time - overlap_duration
        end_time = start_time + split_length

# %%
def count_files(directory):
    if os.path.exists(directory):
        return len(
            [
                name
                for name in os.listdir(directory)
                if os.path.isfile(os.path.join(directory, name))
            ]
        )
    else:
        return 0

# %% [markdown]
# # Prepare data

# %% [markdown]
# ## Load data without background noise

# %%
# This block of code was insipired by the following link:
# https://github.com/OldBonhart/TensorFlow_Speech_Recognition_Challenge/blob/master/Train___EfficientNet.ipynb
labels = os.listdir(DATASET_DIR)
data_map = {}
for ind, label in enumerate(labels):
    data_path = DATASET_DIR + label
    data_map[data_path] = label, os.listdir(data_path), ind
data_map.keys()
data_map = {}
for ind, label in enumerate(labels):
    data_path = DATASET_DIR + label
    data_map[ind] = label, os.listdir(data_path), ind

df = pd.DataFrame(data_map.values(), columns=["label_name", "path", "label"])
df = df.set_index(["label_name", "label"])
df.reset_index(inplace=True)
# background = df[df['label_name'] == '_background_noise_']
df = df[df["label_name"] != "_background_noise_"]
element_to_remove = "_background_noise_"
if element_to_remove in labels:
    labels.remove(element_to_remove)


rows = []
_ = df.apply(
    lambda row: [rows.append([row["label_name"], row["label"], nn]) for nn in row.path],
    axis=1,
)
df_new = pd.DataFrame(rows, columns=df.columns)
df_new.to_csv(r"speech_commands_dataset_all_labels.csv", index=True)


df_new["label"] = df_new["label"].apply(lambda x: x if x < 12 else x - 1)

# %%
data = df_new

# %%
input_shape = (32, 32, 3)
num_classes = len(labels)

# %% [markdown]
# ## Split Background Noise

# %%
BKGRND_DIR = os.path.join(DATASET_DIR, "_background_noise_original")
OUTPUT_DIR = os.path.join(DATASET_DIR, "_background_noise_")

# %%
if not BG_IS_ALREADY_SPLIT:
    os.rename(OUTPUT_DIR, BKGRND_DIR)

# %%
if not BG_IS_ALREADY_SPLIT:
    for root, dirs, files in os.walk(BKGRND_DIR):
        for file in files:
            if file.endswith(".wav"):
                input_file_path = os.path.join(root, file)
                split_audio_file(input_file_path, OUTPUT_DIR)

# %%
if not BG_IS_ALREADY_SPLIT:
    shutil.rmtree(BKGRND_DIR)

# %%
# Count files in the output directory
num_files = count_files(OUTPUT_DIR)
print("Number of files in the output directory:", num_files)
# Out:
# Number of files in the output directory: 39342

# %% [markdown]
# ## Load data with split background noise

# %%
# This block of code was insipired by the following link:
# https://github.com/OldBonhart/TensorFlow_Speech_Recognition_Challenge/blob/master/Train___EfficientNet.ipynb
labelsBackgroundNoise = os.listdir(DATASET_DIR)
data_map = {}
for ind, label in enumerate(labelsBackgroundNoise):
    data_path = DATASET_DIR + label
    data_map[data_path] = label, os.listdir(data_path), ind
data_map.keys()
data_map = {}
for ind, label in enumerate(labelsBackgroundNoise):
    data_path = DATASET_DIR + label
    data_map[ind] = label, os.listdir(data_path), ind

dfBackgroundNoise = pd.DataFrame(
    data_map.values(), columns=["label_name", "path", "label"]
)
dfBackgroundNoise = dfBackgroundNoise.set_index(["label_name", "label"])
dfBackgroundNoise.reset_index(inplace=True)


rows = []
_ = dfBackgroundNoise.apply(
    lambda row: [rows.append([row["label_name"], row["label"], nn]) for nn in row.path],
    axis=1,
)
dfBackgroundNoise_new = pd.DataFrame(rows, columns=dfBackgroundNoise.columns)
dfBackgroundNoise_new.to_csv(
    r"speech_commands_dataset_with_bg_noise_labels.csv", index=True
)

# %%
input_shape = (32, 32, 3)
num_classes_with_bg_noise = len(labelsBackgroundNoise)

# %%
dfBackgroundNoise_new.head(5)
# Out:
#   label_name  label                   path
# 0     marvin      0  bfbd0e6b_nohash_0.wav
# 1     marvin      0  cb8f8307_nohash_0.wav
# 2     marvin      0  66774579_nohash_1.wav
# 3     marvin      0  0d53e045_nohash_0.wav
# 4     marvin      0  2a0b413e_nohash_0.wav

# %%
dfBackgroundNoise_new.groupby("label_name").count()
# Out:
#                     label   path
# label_name
# _background_noise_  39342  39342
# bed                  1713   1713
# bird                 1731   1731
# cat                  1733   1733
# dog                  1746   1746
# down                 2359   2359
# eight                2352   2352
# five                 2357   2357
# four                 2372   2372
# go                   2372   2372
# happy                1742   1742
# house                1750   1750
# left                 2353   2353
# marvin               1746   1746
# nine                 2364   2364
# no                   2375   2375
# off                  2357   2357
# on                   2367   2367
# one                  2370   2370
# right                2367   2367
# seven                2377   2377
# sheila               1734   1734
# six                  2369   2369
# stop                 2380   2380
# three                2356   2356
# tree                 1733   1733
# two                  2373   2373
# up                   2375   2375
# wow                  1745   1745
# yes                  2377   2377
# zero                 2376   2376

# %%
dfBackgroundNoise_new[
    dfBackgroundNoise_new["label_name"] != "_background_noise_"
].groupby("label_name").count().mean()
# Out:
# label    2157.366667
# path     2157.366667
# dtype: float64

# %%
dfBackgroundNoise_new = (
    dfBackgroundNoise_new.groupby("label").head(2157).reset_index(drop=True)
)

# %%
dfBackgroundNoise_new.groupby("label_name").count()
# Out:
#                     label  path
# label_name
# _background_noise_   2157  2157
# bed                  1713  1713
# bird                 1731  1731
# cat                  1733  1733
# dog                  1746  1746
# down                 2157  2157
# eight                2157  2157
# five                 2157  2157
# four                 2157  2157
# go                   2157  2157
# happy                1742  1742
# house                1750  1750
# left                 2157  2157
# marvin               1746  1746
# nine                 2157  2157
# no                   2157  2157
# off                  2157  2157
# on                   2157  2157
# one                  2157  2157
# right                2157  2157
# seven                2157  2157
# sheila               1734  1734
# six                  2157  2157
# stop                 2157  2157
# three                2157  2157
# tree                 1733  1733
# two                  2157  2157
# up                   2157  2157
# wow                  1745  1745
# yes                  2157  2157
# zero                 2157  2157

# %%
onlyBackgroundNoise = dfBackgroundNoise_new[
    dfBackgroundNoise_new["label_name"] == "_background_noise_"
]
normalisedBinaryBackgroundNoise = (
    dfBackgroundNoise_new[dfBackgroundNoise_new["label_name"] != "_background_noise_"]
    .groupby("label_name")
    .head(72)
    .reset_index(drop=True)
)
normalisedBinaryBackgroundNoise = pd.concat(
    [onlyBackgroundNoise, normalisedBinaryBackgroundNoise]
)

# %%
normalisedBinaryBackgroundNoise.groupby("label_name").count()
# Out:
#                     label  path
# label_name
# _background_noise_   2157  2157
# bed                    72    72
# bird                   72    72
# cat                    72    72
# dog                    72    72
# down                   72    72
# eight                  72    72
# five                   72    72
# four                   72    72
# go                     72    72
# happy                  72    72
# house                  72    72
# left                   72    72
# marvin                 72    72
# nine                   72    72
# no                     72    72
# off                    72    72
# on                     72    72
# one                    72    72
# right                  72    72
# seven                  72    72
# sheila                 72    72
# six                    72    72
# stop                   72    72
# three                  72    72
# tree                   72    72
# two                    72    72
# up                     72    72
# wow                    72    72
# yes                    72    72
# zero                   72    72

# %% [markdown]
# # LSTM Test

# %%
epochs = 10
batch_size = 128
learning_rate = 0.001

# %%
model = Sequential(
    [
        Conv2D(32, (3, 3), activation="relu", input_shape=input_shape),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation="relu"),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation="relu"),
        MaxPooling2D((2, 2)),
        Flatten(),
        Reshape((-1, 128)),
        LSTM(128),
        Dense(num_classes, activation="softmax"),
    ]
)
model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  reshape (Reshape)           (None, 4, 128)            0
#
#  lstm (LSTM)                 (None, 128)               131584
#
#  dense (Dense)               (None, 30)                3870
#
# =================================================================
# Total params: 228702 (893.37 KB)
# Trainable params: 228702 (893.37 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
train_df, val_df = train_test_split(data, stratify=data["label"], test_size=0.1)
train_df, test_df = train_test_split(
    train_df, stratify=train_df["label"], test_size=0.1
)
print(train_df.shape, val_df.shape)
print(train_df.dtypes)
print(train_df.head())
# Out:
# (52423, 3) (6473, 3)
# label_name    object
# label          int64
# path          object
# dtype: object
#       label_name  label                   path
# 25790       tree     11  44fb4274_nohash_0.wav
# 20386       five      9  6fca237d_nohash_2.wav
# 16159        one      7  da7689f1_nohash_0.wav
# 16314        one      7  2fa39636_nohash_0.wav
# 61279      right     28  f5733968_nohash_0.wav

# %%
train_dataset = create_dataset(train_df, num_classes, batch_size)
val_dataset = create_dataset(val_df, num_classes, batch_size)

# %%
model.fit(
    train_dataset, epochs=epochs, batch_size=batch_size, validation_data=val_dataset
)
# Out:
# Epoch 1/10
# 410/410 [==============================] - 100s 203ms/step - loss: 1.6526 - accuracy: 0.5178 - val_loss: 0.9411 - val_accuracy: 0.7123
# Epoch 2/10
# 410/410 [==============================] - 82s 200ms/step - loss: 0.7271 - accuracy: 0.7825 - val_loss: 0.6808 - val_accuracy: 0.7979
# Epoch 3/10
# 410/410 [==============================] - 82s 199ms/step - loss: 0.5407 - accuracy: 0.8368 - val_loss: 0.6063 - val_accuracy: 0.8219
# Epoch 4/10
# 410/410 [==============================] - 82s 200ms/step - loss: 0.4410 - accuracy: 0.8665 - val_loss: 0.5352 - val_accuracy: 0.8409
# Epoch 5/10
# 410/410 [==============================] - 82s 200ms/step - loss: 0.3773 - accuracy: 0.8847 - val_loss: 0.5384 - val_accuracy: 0.8426
# Epoch 6/10
# 410/410 [==============================] - 82s 201ms/step - loss: 0.3323 - accuracy: 0.8988 - val_loss: 0.5072 - val_accuracy: 0.8511
# Epoch 7/10
# 410/410 [==============================] - 82s 199ms/step - loss: 0.2989 - accuracy: 0.9079 - val_loss: 0.5288 - val_accuracy: 0.8494
# Epoch 8/10
# 410/410 [==============================] - 82s 200ms/step - loss: 0.2649 - accuracy: 0.9189 - val_loss: 0.5129 - val_accuracy: 0.8571
# Epoch 9/10
# 410/410 [==============================] - 82s 200ms/step - loss: 0.2297 - accuracy: 0.9292 - val_loss: 0.5537 - val_accuracy: 0.8460
# Epoch 10/10
# 410/410 [==============================] - 82s 200ms/step - loss: 0.2028 - accuracy: 0.9372 - val_loss: 0.5298 - val_accuracy: 0.8546

# %%
test_data = create_dataset(test_df, num_classes, batch_size)

# %%
result = model.predict(test_data)
# Out:
# 46/46 [==============================] - 9s 183ms/step

# %%
y_pred = np.argmax(result, axis=1)

# %%
y_true = []
for index, row in test_df.iterrows():
    y_true.append(row["label"])

# %%
correct = 0
for i, y in enumerate(y_pred):
    if y == y_true[i]:
        correct += 1
correct / len(y_true)
# Out:
# 0.8624892703862661

# %%
# Calculate accuracy
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)

# Plot confusion matrix
conf_mat = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
plt.imshow(conf_mat, cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

# Set tick labels
plt.xticks(np.arange(len(labels)), labels, rotation=90)
plt.yticks(np.arange(len(labels)), labels, rotation=0)
plt.show()
# Out:
# Accuracy: 0.8624892703862661

# %% [markdown]
# # Experiments Pipeline

# %% [markdown]
# ## Functions and classes

# %%
class AugmentationTechnique(Enum):
    NoAugmentation = 0
    Tempo = 1
    Echo = 2
    Noise = 3


class ModelType(Enum):
    LSTM = 1
    Transformer = 2
    LSTM_BG = 3
    CustomLSTMShort = 4


class OptimizerType(Enum):
    Adam = 1
    Sgd = 2
    Lion = 3


class RegularizationType(Enum):
    NoRegularization = 1
    L2 = 2
    Dropout = 3


def getRegularizer(regularizerType, value):
    match regularizerType:
        case RegularizationType.L2:
            return L2(value)


def getDenseLayer(model, regularization, activation, nodes):
    match regularization["type"]:
        case RegularizationType.Dropout:
            model.add(Dropout(rate=regularization["value"]))
            model.add(Dense(nodes, activation=activation))
        case RegularizationType.NoRegularization:
            model.add(Dense(nodes, activation=activation))
        case RegularizationType.L2:
            model.add(
                Dense(
                    nodes,
                    activation=activation,
                    kernel_regularizer=getRegularizer(
                        regularizerType=regularization["type"],
                        value=regularization["value"],
                    ),
                )
            )


def getAugmentationLayer(model, technique, seed):
    match technique:
        case AugmentationTechnique.NoAugmentation:
            return


class Model:
    def fit(
        self, batch_size, epochs, train_images, train_labels, valid_images, valid_labels
    ):
        pass

    def predict(self, test_images):
        pass

    def __init__(self, optimizer, loss, metrics):
        pass


class CustomLSTM(Model):
    def __init__(
        self, optimizer, loss, metrics, regularizer, seed, augmentation, num_classes
    ):
        self.model = Sequential(
            [
                Conv2D(32, (3, 3), activation="relu", input_shape=input_shape),
                MaxPooling2D((2, 2)),
                Conv2D(64, (3, 3), activation="relu"),
                MaxPooling2D((2, 2)),
                Conv2D(128, (3, 3), activation="relu"),
                MaxPooling2D((2, 2)),
                Flatten(),
                Reshape((-1, 128)),
                LSTM(128),
                Dense(num_classes, activation="softmax"),
            ]
        )
        self.model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    def fit(self, batch_size, epochs, train_dataset, val_dataset):
        return self.model.fit(
            train_dataset,
            epochs=epochs,
            batch_size=batch_size,
            validation_data=val_dataset,
        )

    def predict(self, test_df):
        result = self.model.predict(test_df)
        return np.argmax(result, axis=1)


class CustomLSTMShort(Model):
    def __init__(
        self, optimizer, loss, metrics, regularizer, seed, augmentation, num_classes
    ):
        self.model = Sequential(
            [
                Flatten(),
                Reshape((-1, 128)),
                LSTM(128),
                Dense(num_classes, activation="softmax"),
            ]
        )
        self.model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    def fit(self, batch_size, epochs, train_dataset, val_dataset):
        return self.model.fit(
            train_dataset,
            epochs=epochs,
            batch_size=batch_size,
            validation_data=val_dataset,
        )

    def predict(self, test_df):
        result = self.model.predict(test_df)
        return np.argmax(result, axis=1)


class CustomLSTMBackgroundNoise(Model):
    def __init__(
        self, optimizer, loss, metrics, regularizer, seed, augmentation, num_classes
    ):
        self.model = Sequential(
            [
                Conv2D(32, (3, 3), activation="relu", input_shape=input_shape),
                MaxPooling2D((2, 2)),
                Conv2D(64, (3, 3), activation="relu"),
                Dropout(0.2),
                MaxPooling2D((2, 2)),
                Conv2D(128, (3, 3), activation="relu"),
                Dropout(0.2),
                MaxPooling2D((2, 2)),
                Flatten(),
                Reshape((-1, 128)),
                LSTM(128),
                Dropout(0.2),
                Dense(
                    1,
                    activation="sigmoid",
                    kernel_regularizer=keras.regularizers.L1L2(l1=1e-5, l2=1e-4),
                    bias_regularizer=keras.regularizers.L2(1e-4),
                    activity_regularizer=keras.regularizers.L2(1e-5),
                ),
            ]
        )

        self.model.compile(
            optimizer=optimizer, loss="binary_crossentropy", metrics=metrics
        )

    def fit(self, batch_size, epochs, train_dataset, val_dataset):
        return self.model.fit(
            train_dataset,
            epochs=epochs,
            batch_size=batch_size,
            validation_data=val_dataset,
        )

    def predict(self, test_df):
        result = self.model.predict(test_df)
        return np.argmax(result, axis=1)

# %%
def createModel(
    modelType, optimizer, loss, metrics, regularizer, seed, augmentation, num_classes
) -> Model:
    match modelType:
        case ModelType.LSTM:
            return CustomLSTM(
                optimizer=optimizer,
                loss=loss,
                metrics=metrics,
                regularizer=regularizer,
                seed=seed,
                augmentation=augmentation,
                num_classes=num_classes,
            )
        case ModelType.CustomLSTMShort:
            return CustomLSTMShort(
                optimizer=optimizer,
                loss=loss,
                metrics=metrics,
                regularizer=regularizer,
                seed=seed,
                augmentation=augmentation,
                num_classes=num_classes,
            )
        case ModelType.LSTM_BG:
            return CustomLSTMBackgroundNoise(
                optimizer=optimizer,
                loss=loss,
                metrics=metrics,
                regularizer=regularizer,
                seed=seed,
                augmentation=augmentation,
                num_classes=num_classes,
            )


def getOptimizer(optimizer_type, learningRate):
    match optimizer_type:
        case OptimizerType.Adam:
            return Adam(learning_rate=learningRate)
        case OptimizerType.Sgd:
            return SGD(learning_rate=learningRate)
        case OptimizerType.Lion:
            return Lion(learning_rate=learningRate)

# %%
def preprocess_background_data(row):
    signal_path = DATASET_DIR + row["label_name"] + "/" + row["path"]
    samples, sample_rate = librosa.load(signal_path, mono=True, sr=None)
    freqs, times, spectrogram = log_specgram(samples, sample_rate)
    img = cv2.resize(spectrogram, (32, 32))
    img = np.divide((img - np.mean(img)), np.std(img), out=img, where=np.std(img) != 0)
    img = np.stack((img,) * 3, axis=-1).astype(np.float32)
    label = np.array([row["label"]], dtype=np.float32)
    return img, label

# %%
def create_dataset_lstm(df, num_classes, batch_size):
    def generator():
        for index, row in df.iterrows():
            img, label = preprocess_data(row, num_classes)
            yield img, label

    dataset = tf.data.Dataset.from_generator(
        generator,
        output_signature=(
            tf.TensorSpec(shape=(32, 32, 3), dtype=tf.float32),
            tf.TensorSpec(shape=(num_classes,), dtype=tf.float32),
        ),
    )
    # dataset = dataset.shuffle(buffer_size=len(df))
    dataset = dataset.batch(batch_size)
    # dataset = dataset.prefetch(2)
    return dataset


def create_dataset_background_lstm(df, num_classes, batch_size):
    df_gen = df.copy()
    df_gen["label"] = df_gen["label_name"].apply(
        lambda x: 1 if x == "_background_noise_" else 0
    )

    def generator():
        for index, row in df_gen.iterrows():
            img, label = preprocess_background_data(row)
            yield img, label

    dataset = tf.data.Dataset.from_generator(
        generator,
        output_signature=(
            tf.TensorSpec(shape=(32, 32, 3), dtype=tf.float32),
            tf.TensorSpec(shape=(1,), dtype=tf.float32),
        ),
    )
    # dataset = dataset.shuffle(buffer_size=len(df_gen))
    dataset = dataset.batch(batch_size)
    # dataset = dataset.prefetch(2)
    return dataset


def getDatasetGenerator(modelType, df, num_classes, batch_size):
    match (modelType):
        case ModelType.LSTM:
            return create_dataset_lstm(df, num_classes, batch_size)
        case ModelType.CustomLSTMShort:
            return create_dataset_lstm(df, num_classes, batch_size)
        case ModelType.LSTM_BG:
            return create_dataset_background_lstm(df, num_classes, batch_size)

# %%
def reduceDataset(df, percentToKeep):
    return (
        df.groupby("label")
        .head(int(df.shape[0] * float(percentToKeep / 100) / num_classes))
        .reset_index(drop=True)
    )

# %%
def performSingleExperiment(
    modelType,
    batchSize,
    epochNumber,
    augmentation,
    learningRate,
    seed,
    optimizerType,
    num_classes,
    train_data,
    val_data,
    test_split_dataset,
    split,
    regularizer,
):
    # print(f"Performing experiment with model: {modelType}, batch size: {batchSize}, epochs: {epochNumber}, augmentation: {augmentation}, regularizer: {regularizer}, learning rate: {learningRate}, seed: {seed}")
    print(
        f"Performing experiment with model: {modelType}, batch size: {batchSize}, epochs: {epochNumber}, augmentation: {augmentation}, regularization: {regularizer['type'].name},learning rate: {learningRate}, seed: {seed}, optimizer: {optimizerType.name}, split: {split}"
    )
    set_seed(seed)
    train_dataset = getDatasetGenerator(
        modelType, reduceDataset(train_data, 20), num_classes, batchSize
    )
    val_dataset = getDatasetGenerator(
        modelType, reduceDataset(val_data, 20), num_classes, batchSize
    )
    model = createModel(
        num_classes=num_classes,
        modelType=modelType,
        regularizer={"type": regularizer["type"], "value": regularizer["value"]},
        optimizer=getOptimizer(optimizer_type=optimizerType, learningRate=learningRate),
        loss="categorical_crossentropy",
        metrics=["accuracy"],
        seed=seed,
        augmentation=augmentation,
    )
    # train the model
    history = model.fit(
        batch_size=batchSize,
        epochs=epochNumber,
        train_dataset=train_dataset,
        val_dataset=val_dataset,
    )

    # get accuracy
    test_split_dataset_generator = getDatasetGenerator(
        modelType, test_split_dataset, num_classes, batchSize
    )
    y_pred = model.predict(test_split_dataset_generator)
    y_true = []
    if modelType == ModelType.LSTM_BG:
        for index, row in test_split_dataset.iterrows():
            if row["label_name"] == "_background_noise_":
                y_true.append(1)
            else:
                y_true.append(0)
    else:
        for index, row in test_split_dataset.iterrows():
            y_true.append(row["label"])

    accuracy = accuracy_score(y_true, y_pred)
    return [
        accuracy,
        augmentation,
        optimizerType,
        batchSize,
        learningRate,
        epochNumber,
        seed,
        split,
        regularizer,
        modelType,
    ], history


def performExperiment(
    batchSizes,
    learningRates,
    numberOfEpochs,
    augmentationTechniques,
    regularizers,
    modelType,
    seeds,
    optimizers,
    num_classes,
    trainData,
    splits,
):
    results = []
    histories = []
    accuracy = 0
    accuracyMean = 0
    accuracyArray = []
    train_split_dataset, val_split_dataset = train_test_split(
        trainData, stratify=trainData["label"], test_size=0.1
    )
    train_split_dataset, test_split_dataset = train_test_split(
        train_split_dataset, stratify=train_split_dataset["label"], test_size=splits[0]
    )

    currentBestBatchSize = batchSizes[0]
    currentBestLearningRate = learningRates[0]
    currentBestNumberOfEpochs = 10
    lastExperimentNumberOfEpochs = 50
    currentBestAugmentation = augmentationTechniques[0]
    currentBestOptimizer = optimizers[0]
    currentBestSplit = splits[0]
    currentBestRegularizer = regularizers[0]
    bestSeed = seeds[0]
    tempSeed = seeds[0]
    bestSeedAccuracy = 0
    tempSeedAccuracy = 0

    for seed in seeds:

        result, history = performSingleExperiment(
            regularizer=currentBestRegularizer,
            split=currentBestSplit,
            test_split_dataset=test_split_dataset,
            train_data=train_split_dataset,
            val_data=val_split_dataset,
            num_classes=num_classes,
            modelType=modelType,
            learningRate=currentBestLearningRate,
            batchSize=currentBestBatchSize,
            epochNumber=currentBestNumberOfEpochs,
            augmentation=currentBestAugmentation,
            seed=seed,
            optimizerType=currentBestOptimizer,
        )
        results.append(result)
        accuracyArray.append(result[0])
    accuracyMean = np.mean(accuracyArray)
    bestSeedAccuracy = accuracyArray[0]
    accuracyArray = []

    for augmentation in augmentationTechniques:
        for seed in seeds:
            result, history = performSingleExperiment(
                regularizer=currentBestRegularizer,
                split=currentBestSplit,
                test_split_dataset=test_split_dataset,
                train_data=train_split_dataset,
                val_data=val_split_dataset,
                num_classes=num_classes,
                modelType=modelType,
                learningRate=currentBestLearningRate,
                batchSize=currentBestBatchSize,
                epochNumber=currentBestNumberOfEpochs,
                augmentation=augmentation,
                seed=seed,
                optimizerType=currentBestOptimizer,
            )
            result.append("augmentation")
            results.append(result)
            accuracyArray.append(result[0])
        if np.mean(accuracyArray) > accuracyMean:
            currentBestAugmentation = augmentation
            accuracyMean = np.mean(accuracyArray)

        accuracyArray = []

    for optimizer in optimizers:
        for learningRate in learningRates:
            for seed in seeds:
                result, history = performSingleExperiment(
                    regularizer=currentBestRegularizer,
                    split=currentBestSplit,
                    test_split_dataset=test_split_dataset,
                    train_data=train_split_dataset,
                    val_data=val_split_dataset,
                    num_classes=num_classes,
                    modelType=modelType,
                    learningRate=learningRate,
                    batchSize=currentBestBatchSize,
                    epochNumber=currentBestNumberOfEpochs,
                    augmentation=currentBestAugmentation,
                    seed=seed,
                    optimizerType=optimizer,
                )
                result.append("optimizer-learning rate")
                results.append(result)
                accuracyArray.append(result[0])
            if np.mean(accuracyArray) > accuracyMean:
                currentBestLearningRate = learningRate
                currentBestOptimizer = optimizer
                accuracyMean = np.mean(accuracyArray)

            accuracyArray = []

    for batchSize in batchSizes:
        for seed in seeds:
            result, history = performSingleExperiment(
                regularizer=currentBestRegularizer,
                split=currentBestSplit,
                test_split_dataset=test_split_dataset,
                train_data=train_split_dataset,
                val_data=val_split_dataset,
                num_classes=num_classes,
                modelType=modelType,
                learningRate=currentBestLearningRate,
                batchSize=batchSize,
                epochNumber=currentBestNumberOfEpochs,
                augmentation=currentBestAugmentation,
                seed=seed,
                optimizerType=currentBestOptimizer,
            )
            result.append("batch size")
            results.append(result)
            accuracyArray.append(result[0])
        if np.mean(accuracyArray) > accuracyMean:
            currentBestBatchSize = batchSize
            accuracyMean = np.mean(accuracyArray)

        accuracyArray = []

    for split in splits:
        for seed in seeds:
            set_seed(seed)
            train_split_dataset, val_split_dataset = train_test_split(
                trainData, stratify=trainData["label"], test_size=0.1
            )
            train_split_dataset, test_split_dataset = train_test_split(
                train_split_dataset,
                stratify=train_split_dataset["label"],
                test_size=split,
            )

            result, history = performSingleExperiment(
                regularizer=currentBestRegularizer,
                split=split,
                test_split_dataset=test_split_dataset,
                train_data=train_split_dataset,
                val_data=val_split_dataset,
                num_classes=num_classes,
                modelType=modelType,
                learningRate=currentBestLearningRate,
                batchSize=currentBestBatchSize,
                epochNumber=currentBestNumberOfEpochs,
                augmentation=currentBestAugmentation,
                seed=seed,
                optimizerType=currentBestOptimizer,
            )
            result.append("split")
            results.append(result)
            if tempSeedAccuracy < result[0]:
                tempSeed = seed
                tempSeedAccuracy = result[0]
            accuracyArray.append(result[0])

        if np.mean(accuracyArray) > accuracyMean:
            bestSeed = tempSeed
            bestSeedAccuracy = tempSeedAccuracy
            currentBestSplit = split
            accuracyMean = np.mean(accuracyArray)
        tempSeedAccuracy = 0

        accuracyArray = []

    result, history = performSingleExperiment(
        regularizer=currentBestRegularizer,
        split=currentBestSplit,
        test_split_dataset=test_split_dataset,
        train_data=train_split_dataset,
        val_data=val_split_dataset,
        num_classes=num_classes,
        modelType=modelType,
        learningRate=currentBestLearningRate,
        batchSize=currentBestBatchSize,
        epochNumber=lastExperimentNumberOfEpochs,
        augmentation=currentBestAugmentation,
        seed=seed,
        optimizerType=currentBestOptimizer,
    )
    accuracy = result[0]
    results.append(result)
    histories.append(history)

    return (
        results,
        [
            accuracy,
            currentBestBatchSize,
            currentBestLearningRate,
            currentBestNumberOfEpochs,
            currentBestAugmentation,
            currentBestOptimizer,
            currentBestSplit,
            currentBestRegularizer,
            modelType,
            bestSeed,
        ],
        histories,
    )

# %%
def performExperimentsOnModel(modelType, num_classes, data):
    results, best, histories = performExperiment(
        modelType=modelType,
        batchSizes=batchSizes,
        learningRates=learningRates,
        numberOfEpochs=numberOfEpochs,
        augmentationTechniques=augmentationTechniques,
        regularizers=regularizers,
        seeds=seeds,
        optimizers=optimizers,
        num_classes=num_classes,
        splits=splits,
        trainData=data,
    )
    print(results)
    print(best)
    print(histories)

    return results, best, histories

# %% [markdown]
# ## Parameters

# %%
# training process
batchSizes = [128, 64, 32]
# batchSizes = [64]
learningRates = [0.01, 0.001, 0.0001]
# learningRates=[0.001]
# numberOfEpochs =[5,10,15]
numberOfEpochs = [10]

# regularization
# regularizers = [{"type":RegularizationType.NoRegularization,"value":0},{"type":RegularizationType.Dropout,"value":0.5},{"type":RegularizationType.L2,"value":0.01}]
# regularizers=[{"type":RegularizationType.NoRegularization,"value":0},{"type":RegularizationType.Dropout,"value":0.3},{"type":RegularizationType.Dropout,"value":0.5},{"type":RegularizationType.Dropout,"value":0.8},{"type":RegularizationType.L2,"value":0.001},{"type":RegularizationType.L2,"value":0.01},{"type":RegularizationType.L2,"value":0.1}]
regularizers = [{"type": RegularizationType.NoRegularization, "value": 0}]
seeds = [123, 42, 9, 13, 4]
# splits = [0.1, 0.2, 0.3]
# seeds=[42]
splits = [0.1, 0.2, 0.3]
# splits=[0.1]
models = [ModelType.LSTM]

optimizers = [OptimizerType.Adam, OptimizerType.Sgd, OptimizerType.Lion]
# optimizers=[OptimizerType.Adam]
# augmentation
augmentationTechniques = [AugmentationTechnique.NoAugmentation]
# augmentationTechniques=[AugmentationTechnique.Flipping]

# %% [markdown]
# ## Process

# %% [markdown]
# ### LSTM

# %% [markdown]
# #### LSTM - artificially removed background noise

# %%
modelType = ModelType.LSTM

# %%
# %%time
results, best, histories = performExperimentsOnModel(modelType, num_classes, data)
# Out:
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 123, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 19s 207ms/step - loss: 2.9286 - accuracy: 0.1489 - val_loss: 6.0628 - val_accuracy: 0.0890
# Epoch 2/10
# 80/80 [==============================] - 16s 198ms/step - loss: 2.6012 - accuracy: 0.2567 - val_loss: 4.2380 - val_accuracy: 0.1508
# Epoch 3/10
# 80/80 [==============================] - 16s 199ms/step - loss: 2.1801 - accuracy: 0.3565 - val_loss: 3.3840 - val_accuracy: 0.2229
# Epoch 4/10
# 80/80 [==============================] - 16s 196ms/step - loss: 1.9110 - accuracy: 0.4231 - val_loss: 2.6786 - val_accuracy: 0.2654
# Epoch 5/10
# 80/80 [==============================] - 16s 197ms/step - loss: 1.7583 - accuracy: 0.4651 - val_loss: 2.3428 - val_accuracy: 0.3424
# Epoch 6/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.4962 - accuracy: 0.5410 - val_loss: 2.1722 - val_accuracy: 0.4034
# Epoch 7/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.3794 - accuracy: 0.5755 - val_loss: 2.3387 - val_accuracy: 0.3617
# Epoch 8/10
# 80/80 [==============================] - 16s 201ms/step - loss: 1.3522 - accuracy: 0.5834 - val_loss: 2.1109 - val_accuracy: 0.4098
# Epoch 9/10
# 80/80 [==============================] - 16s 201ms/step - loss: 1.2661 - accuracy: 0.6050 - val_loss: 1.8506 - val_accuracy: 0.4643
# Epoch 10/10
# 80/80 [==============================] - 16s 198ms/step - loss: 1.1581 - accuracy: 0.6380 - val_loss: 1.8522 - val_accuracy: 0.4892
# 46/46 [==============================] - 9s 178ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 42, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 19s 203ms/step - loss: 3.1330 - accuracy: 0.1015 - val_loss: 4.8057 - val_accuracy: 0.0906
# Epoch 2/10
# 80/80 [==============================] - 16s 201ms/step - loss: 3.3970 - accuracy: 0.0471 - val_loss: 4.6823 - val_accuracy: 0.0345
# Epoch 3/10
# 80/80 [==============================] - 16s 197ms/step - loss: 3.4004 - accuracy: 0.0424 - val_loss: 3.5533 - val_accuracy: 0.0345
# Epoch 4/10
# 80/80 [==============================] - 16s 198ms/step - loss: 3.3903 - accuracy: 0.0368 - val_loss: 3.8127 - val_accuracy: 0.0345
# Epoch 5/10
# 80/80 [==============================] - 16s 198ms/step - loss: 3.4176 - accuracy: 0.0357 - val_loss: 3.4056 - val_accuracy: 0.0345
# Epoch 6/10
# 80/80 [==============================] - 16s 200ms/step - loss: 3.3963 - accuracy: 0.0266 - val_loss: 3.3806 - val_accuracy: 0.0345
# Epoch 7/10
# 80/80 [==============================] - 16s 198ms/step - loss: 3.3963 - accuracy: 0.0293 - val_loss: 3.3717 - val_accuracy: 0.0345
# Epoch 8/10
# 80/80 [==============================] - 16s 198ms/step - loss: 3.3874 - accuracy: 0.0328 - val_loss: 3.3709 - val_accuracy: 0.0345
# Epoch 9/10
# 80/80 [==============================] - 16s 197ms/step - loss: 3.3853 - accuracy: 0.0345 - val_loss: 3.3702 - val_accuracy: 0.0345
# Epoch 10/10
# 80/80 [==============================] - 16s 199ms/step - loss: 3.3837 - accuracy: 0.0345 - val_loss: 3.3699 - val_accuracy: 0.0345
# 46/46 [==============================] - 8s 173ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 9, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 19s 208ms/step - loss: 2.9641 - accuracy: 0.1421 - val_loss: 5.0643 - val_accuracy: 0.0898
# Epoch 2/10
# 80/80 [==============================] - 16s 205ms/step - loss: 2.6639 - accuracy: 0.2311 - val_loss: 4.6156 - val_accuracy: 0.1307
# Epoch 3/10
# 80/80 [==============================] - 16s 203ms/step - loss: 2.2970 - accuracy: 0.3283 - val_loss: 3.3131 - val_accuracy: 0.2237
# Epoch 4/10
# 80/80 [==============================] - 16s 203ms/step - loss: 2.0143 - accuracy: 0.3955 - val_loss: 2.9332 - val_accuracy: 0.2486
# Epoch 5/10
# 80/80 [==============================] - 16s 202ms/step - loss: 1.7854 - accuracy: 0.4643 - val_loss: 2.4657 - val_accuracy: 0.3248
# Epoch 6/10
# 80/80 [==============================] - 16s 203ms/step - loss: 1.6192 - accuracy: 0.5145 - val_loss: 2.5341 - val_accuracy: 0.3312
# Epoch 7/10
# 80/80 [==============================] - 16s 202ms/step - loss: 1.4582 - accuracy: 0.5608 - val_loss: 2.1690 - val_accuracy: 0.3929
# Epoch 8/10
# 80/80 [==============================] - 16s 201ms/step - loss: 1.3345 - accuracy: 0.5922 - val_loss: 1.9132 - val_accuracy: 0.4507
# Epoch 9/10
# 80/80 [==============================] - 16s 202ms/step - loss: 1.2874 - accuracy: 0.6113 - val_loss: 1.7908 - val_accuracy: 0.4956
# Epoch 10/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.1567 - accuracy: 0.6434 - val_loss: 1.8514 - val_accuracy: 0.4908
# 46/46 [==============================] - 9s 177ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 13, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 18s 202ms/step - loss: 3.1106 - accuracy: 0.1055 - val_loss: 6.2827 - val_accuracy: 0.0786
# Epoch 2/10
# 80/80 [==============================] - 16s 201ms/step - loss: 2.7568 - accuracy: 0.2113 - val_loss: 4.2390 - val_accuracy: 0.1291
# Epoch 3/10
# 80/80 [==============================] - 16s 200ms/step - loss: 2.4434 - accuracy: 0.2812 - val_loss: 3.0201 - val_accuracy: 0.2053
# Epoch 4/10
# 80/80 [==============================] - 16s 200ms/step - loss: 2.1729 - accuracy: 0.3446 - val_loss: 2.9424 - val_accuracy: 0.1941
# Epoch 5/10
# 80/80 [==============================] - 16s 202ms/step - loss: 2.0415 - accuracy: 0.3840 - val_loss: 2.7517 - val_accuracy: 0.2318
# Epoch 6/10
# 80/80 [==============================] - 16s 202ms/step - loss: 1.9367 - accuracy: 0.4090 - val_loss: 2.5455 - val_accuracy: 0.2783
# Epoch 7/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.8040 - accuracy: 0.4482 - val_loss: 2.6387 - val_accuracy: 0.2871
# Epoch 8/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.7505 - accuracy: 0.4589 - val_loss: 2.5016 - val_accuracy: 0.3192
# Epoch 9/10
# 80/80 [==============================] - 16s 201ms/step - loss: 1.7167 - accuracy: 0.4754 - val_loss: 2.3089 - val_accuracy: 0.3536
# Epoch 10/10
# 80/80 [==============================] - 16s 201ms/step - loss: 1.6077 - accuracy: 0.5038 - val_loss: 2.4887 - val_accuracy: 0.3216
# 46/46 [==============================] - 9s 178ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 4, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 18s 201ms/step - loss: 3.1030 - accuracy: 0.1126 - val_loss: 4.2746 - val_accuracy: 0.1034
# Epoch 2/10
# 80/80 [==============================] - 16s 201ms/step - loss: 2.8649 - accuracy: 0.1825 - val_loss: 4.3449 - val_accuracy: 0.1131
# Epoch 3/10
# 80/80 [==============================] - 16s 202ms/step - loss: 2.5408 - accuracy: 0.2604 - val_loss: 3.1551 - val_accuracy: 0.1732
# Epoch 4/10
# 80/80 [==============================] - 16s 203ms/step - loss: 2.1997 - accuracy: 0.3370 - val_loss: 3.2176 - val_accuracy: 0.2061
# Epoch 5/10
# 80/80 [==============================] - 16s 202ms/step - loss: 1.9800 - accuracy: 0.3978 - val_loss: 3.2304 - val_accuracy: 0.2318
# Epoch 6/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.8040 - accuracy: 0.4540 - val_loss: 2.3855 - val_accuracy: 0.3071
# Epoch 7/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.6065 - accuracy: 0.4987 - val_loss: 2.1198 - val_accuracy: 0.3905
# Epoch 8/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.4660 - accuracy: 0.5473 - val_loss: 1.8249 - val_accuracy: 0.4459
# Epoch 9/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.3630 - accuracy: 0.5733 - val_loss: 1.8765 - val_accuracy: 0.4387
# Epoch 10/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.3019 - accuracy: 0.5951 - val_loss: 2.1051 - val_accuracy: 0.4226
# 46/46 [==============================] - 9s 179ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 123, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 18s 202ms/step - loss: 2.9286 - accuracy: 0.1509 - val_loss: 6.0253 - val_accuracy: 0.0906
# Epoch 2/10
# 80/80 [==============================] - 16s 201ms/step - loss: 2.8074 - accuracy: 0.2000 - val_loss: 4.0771 - val_accuracy: 0.1355
# Epoch 3/10
# 80/80 [==============================] - 16s 202ms/step - loss: 2.2361 - accuracy: 0.3384 - val_loss: 3.1513 - val_accuracy: 0.2414
# Epoch 4/10
# 80/80 [==============================] - 16s 202ms/step - loss: 2.0161 - accuracy: 0.3969 - val_loss: 2.9880 - val_accuracy: 0.2558
# Epoch 5/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.7209 - accuracy: 0.4795 - val_loss: 2.4216 - val_accuracy: 0.3264
# Epoch 6/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.5322 - accuracy: 0.5344 - val_loss: 2.0685 - val_accuracy: 0.4106
# Epoch 7/10
# 80/80 [==============================] - 16s 201ms/step - loss: 1.4032 - accuracy: 0.5718 - val_loss: 2.1239 - val_accuracy: 0.4066
# Epoch 8/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.2952 - accuracy: 0.5957 - val_loss: 1.9807 - val_accuracy: 0.4515
# Epoch 9/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.2521 - accuracy: 0.6057 - val_loss: 2.0658 - val_accuracy: 0.4419
# Epoch 10/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.2454 - accuracy: 0.6101 - val_loss: 1.8194 - val_accuracy: 0.4940
# 46/46 [==============================] - 9s 178ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 42, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 19s 203ms/step - loss: 3.1114 - accuracy: 0.1034 - val_loss: 5.4482 - val_accuracy: 0.0970
# Epoch 2/10
# 80/80 [==============================] - 16s 203ms/step - loss: 2.8474 - accuracy: 0.1855 - val_loss: 4.1937 - val_accuracy: 0.1435
# Epoch 3/10
# 80/80 [==============================] - 16s 200ms/step - loss: 2.5275 - accuracy: 0.2622 - val_loss: 3.4491 - val_accuracy: 0.1877
# Epoch 4/10
# 80/80 [==============================] - 16s 203ms/step - loss: 2.2603 - accuracy: 0.3318 - val_loss: 3.2902 - val_accuracy: 0.2109
# Epoch 5/10
# 80/80 [==============================] - 16s 197ms/step - loss: 2.0713 - accuracy: 0.3804 - val_loss: 2.5525 - val_accuracy: 0.2919
# Epoch 6/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.8917 - accuracy: 0.4240 - val_loss: 2.6198 - val_accuracy: 0.2735
# Epoch 7/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.7852 - accuracy: 0.4546 - val_loss: 2.4399 - val_accuracy: 0.3055
# Epoch 8/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.6954 - accuracy: 0.4800 - val_loss: 2.3194 - val_accuracy: 0.3424
# Epoch 9/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.6114 - accuracy: 0.5001 - val_loss: 2.3228 - val_accuracy: 0.3625
# Epoch 10/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.5380 - accuracy: 0.5209 - val_loss: 2.3972 - val_accuracy: 0.3641
# 46/46 [==============================] - 9s 179ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 9, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 19s 204ms/step - loss: 2.9310 - accuracy: 0.1493 - val_loss: 4.8631 - val_accuracy: 0.1002
# Epoch 2/10
# 80/80 [==============================] - 16s 199ms/step - loss: 2.6794 - accuracy: 0.2229 - val_loss: 4.3460 - val_accuracy: 0.1532
# Epoch 3/10
# 80/80 [==============================] - 16s 200ms/step - loss: 2.3661 - accuracy: 0.2994 - val_loss: 3.5348 - val_accuracy: 0.1804
# Epoch 4/10
# 80/80 [==============================] - 16s 199ms/step - loss: 2.1988 - accuracy: 0.3464 - val_loss: 3.2518 - val_accuracy: 0.2334
# Epoch 5/10
# 80/80 [==============================] - 16s 202ms/step - loss: 1.8998 - accuracy: 0.4263 - val_loss: 2.6880 - val_accuracy: 0.2823
# Epoch 6/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.7124 - accuracy: 0.4860 - val_loss: 2.5640 - val_accuracy: 0.3144
# Epoch 7/10
# 80/80 [==============================] - 16s 201ms/step - loss: 1.5827 - accuracy: 0.5153 - val_loss: 2.3393 - val_accuracy: 0.3400
# Epoch 8/10
# 80/80 [==============================] - 16s 203ms/step - loss: 1.4843 - accuracy: 0.5472 - val_loss: 2.1491 - val_accuracy: 0.3889
# Epoch 9/10
# 80/80 [==============================] - 16s 197ms/step - loss: 1.3407 - accuracy: 0.5858 - val_loss: 1.9843 - val_accuracy: 0.4178
# Epoch 10/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.2821 - accuracy: 0.6050 - val_loss: 1.7118 - val_accuracy: 0.4956
# 46/46 [==============================] - 9s 179ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 13, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 19s 204ms/step - loss: 3.1147 - accuracy: 0.1040 - val_loss: 6.5169 - val_accuracy: 0.0666
# Epoch 2/10
# 80/80 [==============================] - 16s 197ms/step - loss: 2.8620 - accuracy: 0.1896 - val_loss: 3.9330 - val_accuracy: 0.1371
# Epoch 3/10
# 80/80 [==============================] - 16s 199ms/step - loss: 2.5400 - accuracy: 0.2512 - val_loss: 3.0102 - val_accuracy: 0.1885
# Epoch 4/10
# 80/80 [==============================] - 16s 198ms/step - loss: 2.2868 - accuracy: 0.3108 - val_loss: 2.8154 - val_accuracy: 0.2358
# Epoch 5/10
# 80/80 [==============================] - 16s 203ms/step - loss: 2.1146 - accuracy: 0.3620 - val_loss: 2.7727 - val_accuracy: 0.2582
# Epoch 6/10
# 80/80 [==============================] - 16s 199ms/step - loss: 2.0025 - accuracy: 0.3924 - val_loss: 2.5975 - val_accuracy: 0.2991
# Epoch 7/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.8558 - accuracy: 0.4376 - val_loss: 2.4449 - val_accuracy: 0.3055
# Epoch 8/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.7702 - accuracy: 0.4551 - val_loss: 2.4307 - val_accuracy: 0.3160
# Epoch 9/10
# 80/80 [==============================] - 16s 197ms/step - loss: 1.7362 - accuracy: 0.4671 - val_loss: 2.3542 - val_accuracy: 0.3456
# Epoch 10/10
# 80/80 [==============================] - 16s 197ms/step - loss: 1.6727 - accuracy: 0.4831 - val_loss: 2.3165 - val_accuracy: 0.3408
# 46/46 [==============================] - 9s 178ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 4, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 18s 203ms/step - loss: 3.1149 - accuracy: 0.1114 - val_loss: 4.0668 - val_accuracy: 0.0874
# Epoch 2/10
# 80/80 [==============================] - 16s 199ms/step - loss: 2.9141 - accuracy: 0.1686 - val_loss: 4.4859 - val_accuracy: 0.1379
# Epoch 3/10
# 80/80 [==============================] - 16s 197ms/step - loss: 2.6149 - accuracy: 0.2374 - val_loss: 3.8094 - val_accuracy: 0.1596
# Epoch 4/10
# 80/80 [==============================] - 16s 198ms/step - loss: 2.4545 - accuracy: 0.2754 - val_loss: 3.5241 - val_accuracy: 0.2021
# Epoch 5/10
# 80/80 [==============================] - 16s 200ms/step - loss: 2.1941 - accuracy: 0.3310 - val_loss: 3.4263 - val_accuracy: 0.2021
# Epoch 6/10
# 80/80 [==============================] - 16s 202ms/step - loss: 1.9256 - accuracy: 0.4220 - val_loss: 2.3926 - val_accuracy: 0.3208
# Epoch 7/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.6761 - accuracy: 0.4893 - val_loss: 2.2230 - val_accuracy: 0.3641
# Epoch 8/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.5048 - accuracy: 0.5457 - val_loss: 2.3001 - val_accuracy: 0.3512
# Epoch 9/10
# 80/80 [==============================] - 16s 203ms/step - loss: 1.4085 - accuracy: 0.5708 - val_loss: 1.9265 - val_accuracy: 0.4403
# Epoch 10/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.2883 - accuracy: 0.6085 - val_loss: 2.2191 - val_accuracy: 0.3913
# 46/46 [==============================] - 8s 175ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 123, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 18s 203ms/step - loss: 2.9281 - accuracy: 0.1467 - val_loss: 5.8313 - val_accuracy: 0.0834
# Epoch 2/10
# 80/80 [==============================] - 16s 199ms/step - loss: 2.4977 - accuracy: 0.2829 - val_loss: 3.7843 - val_accuracy: 0.1788
# Epoch 3/10
# 80/80 [==============================] - 16s 198ms/step - loss: 2.0299 - accuracy: 0.3911 - val_loss: 2.9964 - val_accuracy: 0.2334
# Epoch 4/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.8016 - accuracy: 0.4540 - val_loss: 2.5737 - val_accuracy: 0.3079
# Epoch 5/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.5568 - accuracy: 0.5238 - val_loss: 2.3213 - val_accuracy: 0.3673
# Epoch 6/10
# 80/80 [==============================] - 16s 202ms/step - loss: 1.4083 - accuracy: 0.5662 - val_loss: 2.2703 - val_accuracy: 0.3801
# Epoch 7/10
# 80/80 [==============================] - 16s 196ms/step - loss: 1.3630 - accuracy: 0.5779 - val_loss: 2.0876 - val_accuracy: 0.4226
# Epoch 8/10
# 80/80 [==============================] - 16s 198ms/step - loss: 1.2740 - accuracy: 0.6036 - val_loss: 1.8440 - val_accuracy: 0.4868
# Epoch 9/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.1485 - accuracy: 0.6435 - val_loss: 1.9114 - val_accuracy: 0.4940
# Epoch 10/10
# 80/80 [==============================] - 16s 198ms/step - loss: 1.0931 - accuracy: 0.6526 - val_loss: 2.0197 - val_accuracy: 0.4587
# 46/46 [==============================] - 8s 175ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 42, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 19s 201ms/step - loss: 3.1326 - accuracy: 0.1023 - val_loss: 4.8359 - val_accuracy: 0.0906
# Epoch 2/10
# 80/80 [==============================] - 16s 198ms/step - loss: 3.3979 - accuracy: 0.0464 - val_loss: 4.7011 - val_accuracy: 0.0345
# Epoch 3/10
# 80/80 [==============================] - 16s 199ms/step - loss: 3.4015 - accuracy: 0.0437 - val_loss: 3.5481 - val_accuracy: 0.0345
# Epoch 4/10
# 80/80 [==============================] - 16s 196ms/step - loss: 3.3740 - accuracy: 0.0419 - val_loss: 4.3123 - val_accuracy: 0.0345
# Epoch 5/10
# 80/80 [==============================] - 16s 199ms/step - loss: 3.4106 - accuracy: 0.0413 - val_loss: 3.4650 - val_accuracy: 0.0345
# Epoch 6/10
# 80/80 [==============================] - 16s 202ms/step - loss: 3.4058 - accuracy: 0.0238 - val_loss: 3.3771 - val_accuracy: 0.0345
# Epoch 7/10
# 80/80 [==============================] - 16s 203ms/step - loss: 3.3872 - accuracy: 0.0338 - val_loss: 3.3716 - val_accuracy: 0.0345
# Epoch 8/10
# 80/80 [==============================] - 16s 198ms/step - loss: 3.3820 - accuracy: 0.0345 - val_loss: 3.3705 - val_accuracy: 0.0345
# Epoch 9/10
# 80/80 [==============================] - 16s 198ms/step - loss: 3.3806 - accuracy: 0.0345 - val_loss: 3.3701 - val_accuracy: 0.0345
# Epoch 10/10
# 80/80 [==============================] - 16s 199ms/step - loss: 3.3801 - accuracy: 0.0345 - val_loss: 3.3698 - val_accuracy: 0.0345
# 46/46 [==============================] - 9s 180ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 9, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 19s 203ms/step - loss: 2.9308 - accuracy: 0.1485 - val_loss: 4.8631 - val_accuracy: 0.1123
# Epoch 2/10
# 80/80 [==============================] - 16s 200ms/step - loss: 2.4750 - accuracy: 0.2707 - val_loss: 3.9136 - val_accuracy: 0.1764
# Epoch 3/10
# 80/80 [==============================] - 16s 201ms/step - loss: 2.0693 - accuracy: 0.3871 - val_loss: 2.8941 - val_accuracy: 0.2502
# Epoch 4/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.8212 - accuracy: 0.4420 - val_loss: 2.8558 - val_accuracy: 0.2927
# Epoch 5/10
# 80/80 [==============================] - 16s 201ms/step - loss: 1.6344 - accuracy: 0.4964 - val_loss: 2.3565 - val_accuracy: 0.3625
# Epoch 6/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.4730 - accuracy: 0.5484 - val_loss: 2.2848 - val_accuracy: 0.3617
# Epoch 7/10
# 80/80 [==============================] - 16s 201ms/step - loss: 1.3557 - accuracy: 0.5868 - val_loss: 2.2138 - val_accuracy: 0.3913
# Epoch 8/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.2910 - accuracy: 0.6009 - val_loss: 1.8230 - val_accuracy: 0.4796
# Epoch 9/10
# 80/80 [==============================] - 16s 198ms/step - loss: 1.1920 - accuracy: 0.6285 - val_loss: 1.7402 - val_accuracy: 0.5116
# Epoch 10/10
# 80/80 [==============================] - 16s 202ms/step - loss: 1.0912 - accuracy: 0.6564 - val_loss: 1.7589 - val_accuracy: 0.5036
# 46/46 [==============================] - 8s 176ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 13, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 19s 202ms/step - loss: 3.1149 - accuracy: 0.1046 - val_loss: 6.6136 - val_accuracy: 0.0690
# Epoch 2/10
# 80/80 [==============================] - 16s 197ms/step - loss: 2.8868 - accuracy: 0.1837 - val_loss: 3.5304 - val_accuracy: 0.1411
# Epoch 3/10
# 80/80 [==============================] - 16s 199ms/step - loss: 2.4924 - accuracy: 0.2604 - val_loss: 3.6993 - val_accuracy: 0.1732
# Epoch 4/10
# 80/80 [==============================] - 16s 199ms/step - loss: 2.3262 - accuracy: 0.3120 - val_loss: 2.9560 - val_accuracy: 0.1925
# Epoch 5/10
# 80/80 [==============================] - 16s 201ms/step - loss: 2.1303 - accuracy: 0.3551 - val_loss: 2.7546 - val_accuracy: 0.2398
# Epoch 6/10
# 80/80 [==============================] - 16s 197ms/step - loss: 2.0163 - accuracy: 0.3851 - val_loss: 2.4895 - val_accuracy: 0.2895
# Epoch 7/10
# 80/80 [==============================] - 16s 202ms/step - loss: 1.8665 - accuracy: 0.4313 - val_loss: 2.4950 - val_accuracy: 0.2991
# Epoch 8/10
# 80/80 [==============================] - 16s 201ms/step - loss: 1.7754 - accuracy: 0.4580 - val_loss: 2.3494 - val_accuracy: 0.3256
# Epoch 9/10
# 80/80 [==============================] - 16s 197ms/step - loss: 1.6788 - accuracy: 0.4830 - val_loss: 2.4999 - val_accuracy: 0.3055
# Epoch 10/10
# 80/80 [==============================] - 16s 198ms/step - loss: 1.6206 - accuracy: 0.4964 - val_loss: 2.4277 - val_accuracy: 0.3328
# 46/46 [==============================] - 8s 175ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 4, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 18s 200ms/step - loss: 3.1080 - accuracy: 0.1132 - val_loss: 4.0020 - val_accuracy: 0.0962
# Epoch 2/10
# 80/80 [==============================] - 16s 198ms/step - loss: 2.8615 - accuracy: 0.1801 - val_loss: 4.3682 - val_accuracy: 0.1532
# Epoch 3/10
# 80/80 [==============================] - 16s 198ms/step - loss: 2.5959 - accuracy: 0.2405 - val_loss: 3.2731 - val_accuracy: 0.1636
# Epoch 4/10
# 80/80 [==============================] - 16s 199ms/step - loss: 2.2136 - accuracy: 0.3307 - val_loss: 3.1405 - val_accuracy: 0.2053
# Epoch 5/10
# 80/80 [==============================] - 16s 197ms/step - loss: 1.9716 - accuracy: 0.4056 - val_loss: 3.2168 - val_accuracy: 0.2285
# Epoch 6/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.8685 - accuracy: 0.4409 - val_loss: 2.1785 - val_accuracy: 0.3585
# Epoch 7/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.6620 - accuracy: 0.4899 - val_loss: 2.2489 - val_accuracy: 0.3609
# Epoch 8/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.5368 - accuracy: 0.5295 - val_loss: 2.6384 - val_accuracy: 0.3047
# Epoch 9/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.4997 - accuracy: 0.5469 - val_loss: 2.0301 - val_accuracy: 0.4138
# Epoch 10/10
# 80/80 [==============================] - 16s 196ms/step - loss: 1.4050 - accuracy: 0.5673 - val_loss: 1.8024 - val_accuracy: 0.4555
# 46/46 [==============================] - 8s 175ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.001, seed: 123, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 18s 203ms/step - loss: 2.9627 - accuracy: 0.1548 - val_loss: 3.4470 - val_accuracy: 0.1075
# Epoch 2/10
# 80/80 [==============================] - 16s 198ms/step - loss: 2.4217 - accuracy: 0.3019 - val_loss: 2.7871 - val_accuracy: 0.2053
# Epoch 3/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.9578 - accuracy: 0.4292 - val_loss: 2.2110 - val_accuracy: 0.3304
# Epoch 4/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.5307 - accuracy: 0.5466 - val_loss: 1.7901 - val_accuracy: 0.4443
# Epoch 5/10
# 80/80 [==============================] - 16s 201ms/step - loss: 1.2036 - accuracy: 0.6426 - val_loss: 1.5226 - val_accuracy: 0.5341
# Epoch 6/10
# 80/80 [==============================] - 16s 197ms/step - loss: 0.9989 - accuracy: 0.7056 - val_loss: 1.3594 - val_accuracy: 0.5934
# Epoch 7/10
# 80/80 [==============================] - 16s 201ms/step - loss: 0.8395 - accuracy: 0.7522 - val_loss: 1.2948 - val_accuracy: 0.6119
# Epoch 8/10
# 80/80 [==============================] - 16s 199ms/step - loss: 0.7412 - accuracy: 0.7805 - val_loss: 1.2440 - val_accuracy: 0.6247
# Epoch 9/10
# 80/80 [==============================] - 16s 201ms/step - loss: 0.6560 - accuracy: 0.8033 - val_loss: 1.2175 - val_accuracy: 0.6303
# Epoch 10/10
# 80/80 [==============================] - 16s 199ms/step - loss: 0.5763 - accuracy: 0.8295 - val_loss: 1.0483 - val_accuracy: 0.6840
# 46/46 [==============================] - 9s 178ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.001, seed: 42, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 18s 202ms/step - loss: 3.0112 - accuracy: 0.1377 - val_loss: 3.6260 - val_accuracy: 0.0850
# Epoch 2/10
# 80/80 [==============================] - 16s 200ms/step - loss: 2.4882 - accuracy: 0.2910 - val_loss: 2.8200 - val_accuracy: 0.1957
# Epoch 3/10
# 80/80 [==============================] - 16s 198ms/step - loss: 1.9209 - accuracy: 0.4334 - val_loss: 2.2879 - val_accuracy: 0.3360
# Epoch 4/10
# 80/80 [==============================] - 16s 197ms/step - loss: 1.4661 - accuracy: 0.5721 - val_loss: 1.9006 - val_accuracy: 0.4411
# Epoch 5/10
# 80/80 [==============================] - 16s 201ms/step - loss: 1.1994 - accuracy: 0.6474 - val_loss: 1.6593 - val_accuracy: 0.5036
# Epoch 6/10
# 80/80 [==============================] - 16s 200ms/step - loss: 0.9776 - accuracy: 0.7134 - val_loss: 1.4988 - val_accuracy: 0.5437
# Epoch 7/10
# 80/80 [==============================] - 16s 200ms/step - loss: 0.8151 - accuracy: 0.7616 - val_loss: 1.2528 - val_accuracy: 0.6175
# Epoch 8/10
# 80/80 [==============================] - 16s 197ms/step - loss: 0.7007 - accuracy: 0.7956 - val_loss: 1.1590 - val_accuracy: 0.6544
# Epoch 9/10
# 80/80 [==============================] - 16s 200ms/step - loss: 0.6246 - accuracy: 0.8167 - val_loss: 1.1943 - val_accuracy: 0.6464
# Epoch 10/10
# 80/80 [==============================] - 16s 198ms/step - loss: 0.5646 - accuracy: 0.8327 - val_loss: 1.0530 - val_accuracy: 0.6961
# 46/46 [==============================] - 9s 177ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.001, seed: 9, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 19s 213ms/step - loss: 2.9058 - accuracy: 0.1650 - val_loss: 3.5560 - val_accuracy: 0.0922
# Epoch 2/10
# 80/80 [==============================] - 16s 201ms/step - loss: 2.3947 - accuracy: 0.3028 - val_loss: 2.8150 - val_accuracy: 0.2005
# Epoch 3/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.9468 - accuracy: 0.4248 - val_loss: 2.1859 - val_accuracy: 0.3216
# Epoch 4/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.5445 - accuracy: 0.5450 - val_loss: 1.7922 - val_accuracy: 0.4354
# Epoch 5/10
# 80/80 [==============================] - 16s 197ms/step - loss: 1.2230 - accuracy: 0.6350 - val_loss: 1.5195 - val_accuracy: 0.5301
# Epoch 6/10
# 80/80 [==============================] - 16s 201ms/step - loss: 1.0071 - accuracy: 0.7016 - val_loss: 1.2995 - val_accuracy: 0.6055
# Epoch 7/10
# 80/80 [==============================] - 16s 201ms/step - loss: 0.8456 - accuracy: 0.7488 - val_loss: 1.3085 - val_accuracy: 0.5998
# Epoch 8/10
# 80/80 [==============================] - 16s 197ms/step - loss: 0.7407 - accuracy: 0.7816 - val_loss: 1.1662 - val_accuracy: 0.6447
# Epoch 9/10
# 80/80 [==============================] - 16s 198ms/step - loss: 0.6513 - accuracy: 0.8101 - val_loss: 0.9885 - val_accuracy: 0.7057
# Epoch 10/10
# 80/80 [==============================] - 16s 200ms/step - loss: 0.5716 - accuracy: 0.8311 - val_loss: 1.0096 - val_accuracy: 0.6921
# 46/46 [==============================] - 8s 176ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.001, seed: 13, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 18s 201ms/step - loss: 3.0057 - accuracy: 0.1400 - val_loss: 3.6463 - val_accuracy: 0.0970
# Epoch 2/10
# 80/80 [==============================] - 16s 199ms/step - loss: 2.4997 - accuracy: 0.2877 - val_loss: 2.8266 - val_accuracy: 0.1804
# Epoch 3/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.9888 - accuracy: 0.4153 - val_loss: 2.2282 - val_accuracy: 0.3087
# Epoch 4/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.5700 - accuracy: 0.5349 - val_loss: 1.8530 - val_accuracy: 0.4186
# Epoch 5/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.2523 - accuracy: 0.6279 - val_loss: 1.6835 - val_accuracy: 0.4739
# Epoch 6/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.0364 - accuracy: 0.6937 - val_loss: 1.5083 - val_accuracy: 0.5405
# Epoch 7/10
# 80/80 [==============================] - 16s 202ms/step - loss: 0.8763 - accuracy: 0.7409 - val_loss: 1.3891 - val_accuracy: 0.5718
# Epoch 8/10
# 80/80 [==============================] - 16s 197ms/step - loss: 0.7837 - accuracy: 0.7691 - val_loss: 1.1691 - val_accuracy: 0.6279
# Epoch 9/10
# 80/80 [==============================] - 16s 201ms/step - loss: 0.6786 - accuracy: 0.7986 - val_loss: 1.0155 - val_accuracy: 0.6848
# Epoch 10/10
# 80/80 [==============================] - 16s 200ms/step - loss: 0.5703 - accuracy: 0.8349 - val_loss: 0.9994 - val_accuracy: 0.7001
# 46/46 [==============================] - 9s 180ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.001, seed: 4, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 18s 202ms/step - loss: 2.9373 - accuracy: 0.1647 - val_loss: 3.5555 - val_accuracy: 0.1002
# Epoch 2/10
# 80/80 [==============================] - 16s 197ms/step - loss: 2.4027 - accuracy: 0.3119 - val_loss: 2.8092 - val_accuracy: 0.1941
# Epoch 3/10
# 80/80 [==============================] - 16s 198ms/step - loss: 1.8683 - accuracy: 0.4538 - val_loss: 2.3568 - val_accuracy: 0.2855
# Epoch 4/10
# 80/80 [==============================] - 16s 200ms/step - loss: 1.4946 - accuracy: 0.5570 - val_loss: 1.7939 - val_accuracy: 0.4403
# Epoch 5/10
# 80/80 [==============================] - 16s 199ms/step - loss: 1.1840 - accuracy: 0.6521 - val_loss: 1.5631 - val_accuracy: 0.5245
# Epoch 6/10
# 80/80 [==============================] - 16s 200ms/step - loss: 0.9697 - accuracy: 0.7168 - val_loss: 1.4140 - val_accuracy: 0.5718
# Epoch 7/10
# 80/80 [==============================] - 16s 198ms/step - loss: 0.8403 - accuracy: 0.7519 - val_loss: 1.3725 - val_accuracy: 0.5894
# Epoch 8/10
# 80/80 [==============================] - 16s 200ms/step - loss: 0.7496 - accuracy: 0.7759 - val_loss: 1.2052 - val_accuracy: 0.6351
# Epoch 9/10
# 80/80 [==============================] - 16s 199ms/step - loss: 0.6802 - accuracy: 0.7955 - val_loss: 1.0333 - val_accuracy: 0.6848
# Epoch 10/10
# 80/80 [==============================] - 16s 197ms/step - loss: 0.5812 - accuracy: 0.8293 - val_loss: 0.9150 - val_accuracy: 0.7217
# 46/46 [==============================] - 9s 177ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.0001, seed: 123, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 19s 204ms/step - loss: 3.3816 - accuracy: 0.0355 - val_loss: 3.3508 - val_accuracy: 0.0361
# Epoch 2/10
# 80/80 [==============================] - 16s 199ms/step - loss: 3.3073 - accuracy: 0.0638 - val_loss: 3.2087 - val_accuracy: 0.0994
# Epoch 3/10
# 80/80 [==============================] - 16s 199ms/step - loss: 3.0858 - accuracy: 0.1346 - val_loss: 3.0113 - val_accuracy: 0.1395
# Epoch 4/10
# 80/80 [==============================] - 16s 200ms/step - loss: 2.8585 - accuracy: 0.1777 - val_loss: 2.8319 - val_accuracy: 0.2013
# Epoch 5/10
# 80/80 [==============================] - 16s 199ms/step - loss: 2.6292 - accuracy: 0.2456 - val_loss: 2.6528 - val_accuracy: 0.2366
# Epoch 6/10
# 80/80 [==============================] - 16s 199ms/step - loss: 2.4354 - accuracy: 0.3084 - val_loss: 2.5198 - val_accuracy: 0.2622
# Epoch 7/10
# 80/80 [==============================] - 16s 198ms/step - loss: 2.2822 - accuracy: 0.3543 - val_loss: 2.3947 - val_accuracy: 0.2887
# Epoch 8/10
# 80/80 [==============================] - 16s 202ms/step - loss: 2.1568 - accuracy: 0.3902 - val_loss: 2.2819 - val_accuracy: 0.3144
# Epoch 9/10
# 80/80 [==============================] - 16s 197ms/step - loss: 2.0502 - accuracy: 0.4198 - val_loss: 2.1889 - val_accuracy: 0.3464
# Epoch 10/10
# 80/80 [==============================] - 16s 197ms/step - loss: 1.9587 - accuracy: 0.4471 - val_loss: 2.1073 - val_accuracy: 0.3721
# 46/46 [==============================] - 8s 174ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.0001, seed: 42, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 18s 198ms/step - loss: 3.3811 - accuracy: 0.0433 - val_loss: 3.3508 - val_accuracy: 0.0738
# Epoch 2/10
# 80/80 [==============================] - 16s 197ms/step - loss: 3.3082 - accuracy: 0.0742 - val_loss: 3.2400 - val_accuracy: 0.0970
# Epoch 3/10
# 80/80 [==============================] - 16s 198ms/step - loss: 3.1213 - accuracy: 0.1127 - val_loss: 3.1158 - val_accuracy: 0.1171
# Epoch 4/10
# 80/80 [==============================] - 16s 201ms/step - loss: 2.9458 - accuracy: 0.1652 - val_loss: 2.9876 - val_accuracy: 0.1476
# Epoch 5/10
# 80/80 [==============================] - 16s 203ms/step - loss: 2.7642 - accuracy: 0.2082 - val_loss: 2.8504 - val_accuracy: 0.1692
# Epoch 6/10
# 80/80 [==============================] - 16s 201ms/step - loss: 2.5613 - accuracy: 0.2728 - val_loss: 2.6813 - val_accuracy: 0.2069
# Epoch 7/10
# 80/80 [==============================] - 16s 202ms/step - loss: 2.3523 - accuracy: 0.3365 - val_loss: 2.5016 - val_accuracy: 0.2494
# Epoch 8/10
# 80/80 [==============================] - 16s 204ms/step - loss: 2.1706 - accuracy: 0.3932 - val_loss: 2.3365 - val_accuracy: 0.2991
# Epoch 9/10
# 80/80 [==============================] - 16s 202ms/step - loss: 2.0248 - accuracy: 0.4358 - val_loss: 2.1926 - val_accuracy: 0.3512
# Epoch 10/10
# 80/80 [==============================] - 16s 203ms/step - loss: 1.9072 - accuracy: 0.4691 - val_loss: 2.0717 - val_accuracy: 0.3921
# 46/46 [==============================] - 9s 179ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.0001, seed: 9, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 19s 206ms/step - loss: 3.3758 - accuracy: 0.0445 - val_loss: 3.3376 - val_accuracy: 0.0746
# Epoch 2/10
# 80/80 [==============================] - 16s 201ms/step - loss: 3.2698 - accuracy: 0.0713 - val_loss: 3.1644 - val_accuracy: 0.1155
# Epoch 3/10
# 80/80 [==============================] - 16s 199ms/step - loss: 3.0482 - accuracy: 0.1272 - val_loss: 3.0006 - val_accuracy: 0.1468
# Epoch 4/10
# 80/80 [==============================] - 16s 201ms/step - loss: 2.8265 - accuracy: 0.1894 - val_loss: 2.8219 - val_accuracy: 0.1820
# Epoch 5/10
# 80/80 [==============================] - 16s 201ms/step - loss: 2.6127 - accuracy: 0.2528 - val_loss: 2.6382 - val_accuracy: 0.2342
# Epoch 6/10
# 80/80 [==============================] - 16s 203ms/step - loss: 2.4209 - accuracy: 0.3137 - val_loss: 2.4749 - val_accuracy: 0.2799
# Epoch 7/10
# 80/80 [==============================] - 16s 198ms/step - loss: 2.2610 - accuracy: 0.3669 - val_loss: 2.3416 - val_accuracy: 0.3023
# Epoch 8/10
# 80/80 [==============================] - 16s 198ms/step - loss: 2.1298 - accuracy: 0.4051 - val_loss: 2.2232 - val_accuracy: 0.3408
# Epoch 9/10
# 80/80 [==============================] - 16s 199ms/step - loss: 2.0155 - accuracy: 0.4390 - val_loss: 2.1190 - val_accuracy: 0.3745
# Epoch 10/10
# 80/80 [==============================] - 16s 197ms/step - loss: 1.9131 - accuracy: 0.4697 - val_loss: 2.0351 - val_accuracy: 0.4002
# 46/46 [==============================] - 8s 174ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.0001, seed: 13, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 18s 202ms/step - loss: 3.3860 - accuracy: 0.0339 - val_loss: 3.3524 - val_accuracy: 0.0690
# Epoch 2/10
# 80/80 [==============================] - 16s 199ms/step - loss: 3.3244 - accuracy: 0.0569 - val_loss: 3.2418 - val_accuracy: 0.0898
# Epoch 3/10
# 80/80 [==============================] - 16s 197ms/step - loss: 3.1319 - accuracy: 0.1099 - val_loss: 3.0850 - val_accuracy: 0.1331
# Epoch 4/10
# 80/80 [==============================] - 16s 197ms/step - loss: 2.8911 - accuracy: 0.1829 - val_loss: 2.8967 - val_accuracy: 0.1644
# Epoch 5/10
# 80/80 [==============================] - 16s 198ms/step - loss: 2.6762 - accuracy: 0.2426 - val_loss: 2.6977 - val_accuracy: 0.2037
# Epoch 6/10
# 80/80 [==============================] - 16s 199ms/step - loss: 2.4889 - accuracy: 0.2944 - val_loss: 2.5149 - val_accuracy: 0.2582
# Epoch 7/10
# 80/80 [==============================] - 16s 199ms/step - loss: 2.3327 - accuracy: 0.3352 - val_loss: 2.3586 - val_accuracy: 0.3111
# Epoch 8/10
# 80/80 [==============================] - 16s 196ms/step - loss: 2.1960 - accuracy: 0.3736 - val_loss: 2.2399 - val_accuracy: 0.3488
# Epoch 9/10
# 80/80 [==============================] - 16s 200ms/step - loss: 2.0765 - accuracy: 0.4116 - val_loss: 2.1382 - val_accuracy: 0.3793
# Epoch 10/10
# 80/80 [==============================] - 16s 198ms/step - loss: 1.9704 - accuracy: 0.4449 - val_loss: 2.0561 - val_accuracy: 0.3970
# 46/46 [==============================] - 8s 175ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.0001, seed: 4, optimizer: Adam, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 18s 200ms/step - loss: 3.3688 - accuracy: 0.0487 - val_loss: 3.3242 - val_accuracy: 0.0810
# Epoch 2/10
# 80/80 [==============================] - 16s 198ms/step - loss: 3.2609 - accuracy: 0.0806 - val_loss: 3.1652 - val_accuracy: 0.1315
# Epoch 3/10
# 80/80 [==============================] - 16s 200ms/step - loss: 3.0319 - accuracy: 0.1450 - val_loss: 2.9796 - val_accuracy: 0.1628
# Epoch 4/10
# 80/80 [==============================] - 16s 198ms/step - loss: 2.7950 - accuracy: 0.2172 - val_loss: 2.8464 - val_accuracy: 0.1772
# Epoch 5/10
# 80/80 [==============================] - 16s 198ms/step - loss: 2.5791 - accuracy: 0.2756 - val_loss: 2.6691 - val_accuracy: 0.2221
# Epoch 6/10
# 80/80 [==============================] - 16s 200ms/step - loss: 2.3962 - accuracy: 0.3278 - val_loss: 2.5192 - val_accuracy: 0.2638
# Epoch 7/10
# 80/80 [==============================] - 16s 198ms/step - loss: 2.2462 - accuracy: 0.3717 - val_loss: 2.3892 - val_accuracy: 0.3007
# Epoch 8/10
# 80/80 [==============================] - 16s 197ms/step - loss: 2.1192 - accuracy: 0.4082 - val_loss: 2.2740 - val_accuracy: 0.3360
# Epoch 9/10
# 80/80 [==============================] - 16s 195ms/step - loss: 2.0077 - accuracy: 0.4393 - val_loss: 2.1753 - val_accuracy: 0.3649
# Epoch 10/10
# 80/80 [==============================] - 16s 198ms/step - loss: 1.9093 - accuracy: 0.4680 - val_loss: 2.0877 - val_accuracy: 0.3929
# 46/46 [==============================] - 8s 173ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 123, optimizer: Sgd, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 19s 201ms/step - loss: 3.4010 - accuracy: 0.0346 - val_loss: 3.3949 - val_accuracy: 0.0313
# Epoch 2/10
# 80/80 [==============================] - 16s 197ms/step - loss: 3.3895 - accuracy: 0.0360 - val_loss: 3.3865 - val_accuracy: 0.0417
# Epoch 3/10
# 80/80 [==============================] - 16s 200ms/step - loss: 3.3812 - accuracy: 0.0410 - val_loss: 3.3795 - val_accuracy: 0.0385
# Epoch 4/10
# 80/80 [==============================] - 16s 197ms/step - loss: 3.3734 - accuracy: 0.0465 - val_loss: 3.3723 - val_accuracy: 0.0377
# Epoch 5/10
# 80/80 [==============================] - 16s 199ms/step - loss: 3.3645 - accuracy: 0.0481 - val_loss: 3.3639 - val_accuracy: 0.0377
# Epoch 6/10
# 80/80 [==============================] - 16s 198ms/step - loss: 3.3533 - accuracy: 0.0536 - val_loss: 3.3534 - val_accuracy: 0.0385
# Epoch 7/10
# 80/80 [==============================] - 16s 200ms/step - loss: 3.3377 - accuracy: 0.0628 - val_loss: 3.3395 - val_accuracy: 0.0393
# Epoch 8/10
# 80/80 [==============================] - 16s 199ms/step - loss: 3.3141 - accuracy: 0.0744 - val_loss: 3.3231 - val_accuracy: 0.0377
# Epoch 9/10
# 80/80 [==============================] - 16s 195ms/step - loss: 3.2775 - accuracy: 0.0834 - val_loss: 3.3113 - val_accuracy: 0.0369
# Epoch 10/10
# 80/80 [==============================] - 16s 200ms/step - loss: 3.2251 - accuracy: 0.0995 - val_loss: 3.3119 - val_accuracy: 0.0369
# 46/46 [==============================] - 9s 178ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 42, optimizer: Sgd, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 18s 202ms/step - loss: 3.3959 - accuracy: 0.0417 - val_loss: 3.3934 - val_accuracy: 0.0457
# Epoch 2/10
# 80/80 [==============================] - 16s 198ms/step - loss: 3.3907 - accuracy: 0.0367 - val_loss: 3.3886 - val_accuracy: 0.0457
# Epoch 3/10
# 80/80 [==============================] - 16s 197ms/step - loss: 3.3857 - accuracy: 0.0376 - val_loss: 3.3836 - val_accuracy: 0.0489
# Epoch 4/10
# 80/80 [==============================] - 16s 198ms/step - loss: 3.3803 - accuracy: 0.0383 - val_loss: 3.3782 - val_accuracy: 0.0369
# Epoch 5/10
# 80/80 [==============================] - 16s 199ms/step - loss: 3.3742 - accuracy: 0.0368 - val_loss: 3.3720 - val_accuracy: 0.0345
# Epoch 6/10
# 80/80 [==============================] - 16s 199ms/step - loss: 3.3668 - accuracy: 0.0438 - val_loss: 3.3647 - val_accuracy: 0.0345
# Epoch 7/10
# 80/80 [==============================] - 16s 198ms/step - loss: 3.3576 - accuracy: 0.0498 - val_loss: 3.3559 - val_accuracy: 0.0369
# Epoch 8/10
# 80/80 [==============================] - 16s 197ms/step - loss: 3.3456 - accuracy: 0.0560 - val_loss: 3.3449 - val_accuracy: 0.0417
# Epoch 9/10
# 80/80 [==============================] - 16s 202ms/step - loss: 3.3288 - accuracy: 0.0611 - val_loss: 3.3316 - val_accuracy: 0.0441
# Epoch 10/10
# 80/80 [==============================] - 16s 202ms/step - loss: 3.3040 - accuracy: 0.0745 - val_loss: 3.3189 - val_accuracy: 0.0489
# 46/46 [==============================] - 9s 182ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 9, optimizer: Sgd, split: 0.1
# Epoch 1/10
# 80/80 [==============================] - 18s 209ms/step - loss: 3.4014 - accuracy: 0.0337 - val_loss: 3.3932 - val_accuracy: 0.0433
# Epoch 2/10
# 80/80 [==============================] - 16s 203ms/step - loss: 3.3880 - accuracy: 0.0450 - val_loss: 3.3829 - val_accuracy: 0.0561
# Epoch 3/10
# 80/80 [==============================] - 16s 203ms/step - loss: 3.3780 - accuracy: 0.0703 - val_loss: 3.3737 - val_accuracy: 0.0489
# Epoch 4/10
# 80/80 [==============================] - 16s 205ms/step - loss: 3.3679 - accuracy: 0.0662 - val_loss: 3.3635 - val_accuracy: 0.0465
# Epoch 5/10
# 80/80 [==============================] - 16s 202ms/step - loss: 3.3560 - accuracy: 0.0662 - val_loss: 3.3515 - val_accuracy: 0.0417
# Epoch 6/10
# 80/80 [==============================] - 16s 200ms/step - loss: 3.3403 - accuracy: 0.0682 - val_loss: 3.3359 - val_accuracy: 0.0409
# Epoch 7/10
# 80/80 [==============================] - 16s 197ms/step - loss: 3.3183 - accuracy: 0.0699 - val_loss: 3.3152 - val_accuracy: 0.0457
# Epoch 8/10
# 80/80 [==============================] - 16s 202ms/step - loss: 3.2855 - accuracy: 0.0747 - val_loss: 3.2899 - val_accuracy: 0.0513
# Epoch 9/10
# 80/80 [==============================] - 16s 201ms/step - loss: 3.2372 - accuracy: 0.0841 - val_loss: 3.2694 - val_accuracy: 0.0545
# Epoch 10/10
# 80/80 [==============================] - 16s 205ms/step - loss: 3.1749 - accuracy: 0.0982 - val_loss: 3.2825 - val_accuracy: 0.0497
# 46/46 [==============================] - 9s 179ms/step
# ...
# Epoch 7/10
# 62/62 [==============================] - 14s 218ms/step - loss: 0.3855 - accuracy: 0.8822 - val_loss: 1.1724 - val_accuracy: 0.6985
# Epoch 8/10
# 62/62 [==============================] - 13s 215ms/step - loss: 0.3084 - accuracy: 0.9046 - val_loss: 1.1580 - val_accuracy: 0.7025
# Epoch 9/10
# 62/62 [==============================] - 13s 217ms/step - loss: 0.2469 - accuracy: 0.9224 - val_loss: 1.1320 - val_accuracy: 0.7089
# Epoch 10/10
# 62/62 [==============================] - 14s 221ms/step - loss: 0.2053 - accuracy: 0.9337 - val_loss: 1.2065 - val_accuracy: 0.7145
# 137/137 [==============================] - 26s 188ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.001, seed: 13, optimizer: Lion, split: 0.3
# Epoch 1/10
# 62/62 [==============================] - 15s 218ms/step - loss: 3.0404 - accuracy: 0.1402 - val_loss: 3.4114 - val_accuracy: 0.1051
# Epoch 2/10
# 62/62 [==============================] - 13s 211ms/step - loss: 2.3071 - accuracy: 0.3213 - val_loss: 2.5361 - val_accuracy: 0.2622
# Epoch 3/10
# 62/62 [==============================] - 13s 214ms/step - loss: 1.5462 - accuracy: 0.5347 - val_loss: 1.7376 - val_accuracy: 0.4763
# Epoch 4/10
# 62/62 [==============================] - 13s 214ms/step - loss: 1.0396 - accuracy: 0.6814 - val_loss: 1.3553 - val_accuracy: 0.5982
# Epoch 5/10
# 62/62 [==============================] - 13s 213ms/step - loss: 0.7290 - accuracy: 0.7740 - val_loss: 1.1038 - val_accuracy: 0.6760
# Epoch 6/10
# 62/62 [==============================] - 13s 217ms/step - loss: 0.5086 - accuracy: 0.8451 - val_loss: 1.0602 - val_accuracy: 0.6977
# Epoch 7/10
# 62/62 [==============================] - 13s 218ms/step - loss: 0.3737 - accuracy: 0.8866 - val_loss: 1.0730 - val_accuracy: 0.7041
# Epoch 8/10
# 62/62 [==============================] - 13s 217ms/step - loss: 0.2835 - accuracy: 0.9088 - val_loss: 1.0653 - val_accuracy: 0.7185
# Epoch 9/10
# 62/62 [==============================] - 13s 214ms/step - loss: 0.2419 - accuracy: 0.9219 - val_loss: 1.0312 - val_accuracy: 0.7273
# Epoch 10/10
# 62/62 [==============================] - 13s 216ms/step - loss: 0.2107 - accuracy: 0.9328 - val_loss: 1.1821 - val_accuracy: 0.7273
# 137/137 [==============================] - 26s 189ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.001, seed: 4, optimizer: Lion, split: 0.3
# Epoch 1/10
# 62/62 [==============================] - 16s 225ms/step - loss: 2.9739 - accuracy: 0.1456 - val_loss: 3.6460 - val_accuracy: 0.0802
# Epoch 2/10
# 62/62 [==============================] - 13s 218ms/step - loss: 2.2076 - accuracy: 0.3591 - val_loss: 2.2313 - val_accuracy: 0.3007
# Epoch 3/10
# 62/62 [==============================] - 13s 217ms/step - loss: 1.4788 - accuracy: 0.5576 - val_loss: 1.8454 - val_accuracy: 0.4242
# Epoch 4/10
# 62/62 [==============================] - 14s 223ms/step - loss: 1.0501 - accuracy: 0.6760 - val_loss: 1.3511 - val_accuracy: 0.6038
# Epoch 5/10
# 62/62 [==============================] - 14s 225ms/step - loss: 0.7586 - accuracy: 0.7622 - val_loss: 1.2802 - val_accuracy: 0.6327
# Epoch 6/10
# 62/62 [==============================] - 14s 223ms/step - loss: 0.5499 - accuracy: 0.8300 - val_loss: 1.1429 - val_accuracy: 0.6744
# Epoch 7/10
# 62/62 [==============================] - 14s 221ms/step - loss: 0.4205 - accuracy: 0.8673 - val_loss: 1.0855 - val_accuracy: 0.6977
# Epoch 8/10
# 62/62 [==============================] - 13s 217ms/step - loss: 0.3188 - accuracy: 0.9006 - val_loss: 1.0772 - val_accuracy: 0.7121
# Epoch 9/10
# 62/62 [==============================] - 14s 221ms/step - loss: 0.2497 - accuracy: 0.9206 - val_loss: 1.1419 - val_accuracy: 0.6953
# Epoch 10/10
# 62/62 [==============================] - 14s 220ms/step - loss: 0.2261 - accuracy: 0.9263 - val_loss: 1.1754 - val_accuracy: 0.7081
# 137/137 [==============================] - 26s 188ms/step
# Performing experiment with model: ModelType.LSTM, batch size: 128, epochs: 50, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.001, seed: 4, optimizer: Lion, split: 0.1
# Epoch 40/50
# 62/62 [==============================] - 13s 211ms/step - loss: 0.2755 - accuracy: 0.9084 - val_loss: 1.3249 - val_accuracy: 0.7306
# Epoch 41/50
# 62/62 [==============================] - 13s 213ms/step - loss: 0.3038 - accuracy: 0.8988 - val_loss: 1.2812 - val_accuracy: 0.7265
# Epoch 42/50
# 62/62 [==============================] - 13s 214ms/step - loss: 0.2884 - accuracy: 0.9038 - val_loss: 1.3126 - val_accuracy: 0.7249
# Epoch 43/50
# 62/62 [==============================] - 13s 215ms/step - loss: 0.2882 - accuracy: 0.9028 - val_loss: 1.2847 - val_accuracy: 0.7145
# Epoch 44/50
# 62/62 [==============================] - 13s 218ms/step - loss: 0.2903 - accuracy: 0.9025 - val_loss: 1.3191 - val_accuracy: 0.7306
# Epoch 45/50
# 62/62 [==============================] - 14s 223ms/step - loss: 0.3211 - accuracy: 0.8926 - val_loss: 1.4210 - val_accuracy: 0.6840
# Epoch 46/50
# 62/62 [==============================] - 14s 223ms/step - loss: 0.3338 - accuracy: 0.8885 - val_loss: 1.4003 - val_accuracy: 0.7193
# Epoch 47/50
# 62/62 [==============================] - 14s 224ms/step - loss: 0.3227 - accuracy: 0.8957 - val_loss: 1.3974 - val_accuracy: 0.7033
# Epoch 48/50
# 62/62 [==============================] - 14s 224ms/step - loss: 0.3555 - accuracy: 0.8878 - val_loss: 1.3703 - val_accuracy: 0.7089
# Epoch 49/50
# 62/62 [==============================] - 14s 225ms/step - loss: 0.3335 - accuracy: 0.8879 - val_loss: 1.3853 - val_accuracy: 0.7113
# Epoch 50/50
# 62/62 [==============================] - 14s 221ms/step - loss: 0.3489 - accuracy: 0.8809 - val_loss: 1.2989 - val_accuracy: 0.7273
# 137/137 [==============================] - 26s 190ms/step
# [[0.4533905579399142, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 123, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>], [0.026437768240343346, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 42, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>], [0.4515021459227468, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 9, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>], [0.2896137339055794, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 13, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>], [0.3775107296137339, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 4, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>], [0.4593991416309013, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 123, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>, 'augmentation'], [0.33493562231759655, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 42, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>, 'augmentation'], [0.45527896995708156, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 9, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>, 'augmentation'], [0.3026609442060086, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 13, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>, 'augmentation'], [0.3610300429184549, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 4, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>, 'augmentation'], [0.4490987124463519, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 123, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>, 'optimizer-learning rate'], [0.026437768240343346, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 42, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>, 'optimizer-learning rate'], [0.4733047210300429, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 9, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>, 'optimizer-learning rate'], [0.3043776824034335, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 13, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>, 'optimizer-learning rate'], [0.42626609442060087, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 4, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>, 'optimizer-learning rate'], [0.6580257510729614, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.001, 10, 123, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>, 'optimizer-learning rate'], [0.6525321888412017, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.001, 10, 42, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>, 'optimizer-learning rate'], [0.6705579399141631, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.001, 10, 9, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>, 'optimizer-learning rate'], [0.6703862660944206, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.001, 10, 13, 0.1,  ...
# [0.6915593705293276, 128, 0.001, 10, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Lion: 3>, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM: 1>, 4]
# [<keras.src.callbacks.History object at 0x7b9224c84430>]
# CPU times: user 4h 23min 35s, sys: 15min 15s, total: 4h 38min 51s
# Wall time: 4h 18min 44s

# %%
titleComment = " - artificial"
with open("results-" + str(modelType.name) + titleComment, "wb") as my_csv:
    pickle.dump(results, my_csv)
with open("best-" + str(modelType.name) + titleComment, "wb") as my_csv:
    pickle.dump(best, my_csv)
with open("histories-" + str(modelType.name) + titleComment, "wb") as my_csv:
    pickle.dump(histories, my_csv)
if IS_IN_COLAB:
    shutil.copy(
        "/content/results-" + str(modelType.name) + titleComment,
        "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
    )
    shutil.copy(
        "/content/best-" + str(modelType.name) + titleComment,
        "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
    )
    shutil.copy(
        "/content/histories-" + str(modelType.name) + titleComment,
        "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
    )

# %% [markdown]
# #### LSTM - Background detection

# %%
modelType = ModelType.LSTM_BG

# %%
# %%time
results, best, histories = performExperimentsOnModel(
    modelType, num_classes_with_bg_noise, dfBackgroundNoise_new
)
# Out:
# Performing experiment with model: ModelType.LSTM_BG, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 123, optimizer: Adam, split: 0.1
# Epoch 1/10
# 82/82 [==============================] - 34s 218ms/step - loss: 0.1497 - accuracy: 0.9573 - val_loss: 0.1446 - val_accuracy: 0.9677
# Epoch 2/10
# 82/82 [==============================] - 17s 212ms/step - loss: 0.1443 - accuracy: 0.9677 - val_loss: 0.1451 - val_accuracy: 0.9677
# Epoch 3/10
# 82/82 [==============================] - 17s 211ms/step - loss: 0.1444 - accuracy: 0.9677 - val_loss: 0.1451 - val_accuracy: 0.9677
# Epoch 4/10
# 82/82 [==============================] - 17s 211ms/step - loss: 0.1443 - accuracy: 0.9677 - val_loss: 0.1447 - val_accuracy: 0.9677
# Epoch 5/10
# 82/82 [==============================] - 18s 215ms/step - loss: 0.1444 - accuracy: 0.9677 - val_loss: 0.1451 - val_accuracy: 0.9677
# Epoch 6/10
# 82/82 [==============================] - 17s 212ms/step - loss: 0.1444 - accuracy: 0.9677 - val_loss: 0.1451 - val_accuracy: 0.9677
# Epoch 7/10
# 82/82 [==============================] - 17s 211ms/step - loss: 0.1443 - accuracy: 0.9677 - val_loss: 0.1452 - val_accuracy: 0.9677
# Epoch 8/10
# 82/82 [==============================] - 17s 209ms/step - loss: 0.1444 - accuracy: 0.9677 - val_loss: 0.1452 - val_accuracy: 0.9677
# Epoch 9/10
# 82/82 [==============================] - 17s 212ms/step - loss: 0.1444 - accuracy: 0.9677 - val_loss: 0.1452 - val_accuracy: 0.9677
# Epoch 10/10
# 82/82 [==============================] - 17s 210ms/step - loss: 0.1444 - accuracy: 0.9677 - val_loss: 0.1452 - val_accuracy: 0.9677
# 45/45 [==============================] - 8s 179ms/step
# Performing experiment with model: ModelType.LSTM_BG, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 42, optimizer: Adam, split: 0.1
# Epoch 1/10
# 82/82 [==============================] - 20s 218ms/step - loss: 0.1497 - accuracy: 0.9639 - val_loss: 0.1453 - val_accuracy: 0.9677
# Epoch 2/10
# 82/82 [==============================] - 17s 210ms/step - loss: 0.1441 - accuracy: 0.9677 - val_loss: 0.1450 - val_accuracy: 0.9677
# Epoch 3/10
# 82/82 [==============================] - 17s 211ms/step - loss: 0.1440 - accuracy: 0.9677 - val_loss: 0.1450 - val_accuracy: 0.9677
# Epoch 4/10
# 82/82 [==============================] - 17s 210ms/step - loss: 0.1440 - accuracy: 0.9677 - val_loss: 0.1450 - val_accuracy: 0.9677
# Epoch 5/10
# 82/82 [==============================] - 17s 213ms/step - loss: 0.1440 - accuracy: 0.9677 - val_loss: 0.1450 - val_accuracy: 0.9677
# Epoch 6/10
# 82/82 [==============================] - 17s 210ms/step - loss: 0.1440 - accuracy: 0.9677 - val_loss: 0.1450 - val_accuracy: 0.9677
# Epoch 7/10
# 82/82 [==============================] - 17s 210ms/step - loss: 0.1440 - accuracy: 0.9677 - val_loss: 0.1450 - val_accuracy: 0.9677
# Epoch 8/10
# 82/82 [==============================] - 17s 213ms/step - loss: 0.1441 - accuracy: 0.9677 - val_loss: 0.1448 - val_accuracy: 0.9677
# Epoch 9/10
# 82/82 [==============================] - 17s 210ms/step - loss: 0.1442 - accuracy: 0.9677 - val_loss: 0.1452 - val_accuracy: 0.9677
# Epoch 10/10
# 82/82 [==============================] - 17s 212ms/step - loss: 0.1442 - accuracy: 0.9677 - val_loss: 0.1451 - val_accuracy: 0.9677
# 45/45 [==============================] - 8s 178ms/step
# Performing experiment with model: ModelType.LSTM_BG, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 9, optimizer: Adam, split: 0.1
# Epoch 1/10
# 82/82 [==============================] - 20s 216ms/step - loss: 0.1491 - accuracy: 0.9677 - val_loss: 0.1443 - val_accuracy: 0.9677
# Epoch 2/10
# 82/82 [==============================] - 17s 211ms/step - loss: 0.1437 - accuracy: 0.9677 - val_loss: 0.1442 - val_accuracy: 0.9677
# Epoch 3/10
# 82/82 [==============================] - 17s 212ms/step - loss: 0.1437 - accuracy: 0.9677 - val_loss: 0.1443 - val_accuracy: 0.9677
# Epoch 4/10
# 82/82 [==============================] - 17s 213ms/step - loss: 0.1437 - accuracy: 0.9677 - val_loss: 0.1443 - val_accuracy: 0.9677
# Epoch 5/10
# 82/82 [==============================] - 17s 213ms/step - loss: 0.1438 - accuracy: 0.9677 - val_loss: 0.1443 - val_accuracy: 0.9677
# Epoch 6/10
# 82/82 [==============================] - 18s 215ms/step - loss: 0.1438 - accuracy: 0.9677 - val_loss: 0.1443 - val_accuracy: 0.9677
# Epoch 7/10
# 82/82 [==============================] - 17s 210ms/step - loss: 0.1438 - accuracy: 0.9677 - val_loss: 0.1443 - val_accuracy: 0.9677
# Epoch 8/10
# 82/82 [==============================] - 17s 211ms/step - loss: 0.1438 - accuracy: 0.9677 - val_loss: 0.1443 - val_accuracy: 0.9677
# Epoch 9/10
# 82/82 [==============================] - 17s 211ms/step - loss: 0.1438 - accuracy: 0.9677 - val_loss: 0.1443 - val_accuracy: 0.9677
# Epoch 10/10
# 82/82 [==============================] - 17s 210ms/step - loss: 0.1438 - accuracy: 0.9677 - val_loss: 0.1443 - val_accuracy: 0.9677
# 45/45 [==============================] - 8s 180ms/step
# Performing experiment with model: ModelType.LSTM_BG, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 13, optimizer: Adam, split: 0.1
# Epoch 1/10
# 82/82 [==============================] - 20s 219ms/step - loss: 0.1504 - accuracy: 0.9568 - val_loss: 0.1450 - val_accuracy: 0.9677
# Epoch 2/10
# 82/82 [==============================] - 17s 210ms/step - loss: 0.1441 - accuracy: 0.9677 - val_loss: 0.1450 - val_accuracy: 0.9677
# Epoch 3/10
# 82/82 [==============================] - 17s 213ms/step - loss: 0.1444 - accuracy: 0.9677 - val_loss: 0.1452 - val_accuracy: 0.9677
# Epoch 4/10
# 82/82 [==============================] - 17s 209ms/step - loss: 0.1443 - accuracy: 0.9677 - val_loss: 0.1451 - val_accuracy: 0.9677
# Epoch 5/10
# 82/82 [==============================] - 17s 211ms/step - loss: 0.1443 - accuracy: 0.9677 - val_loss: 0.1452 - val_accuracy: 0.9677
# Epoch 6/10
# 82/82 [==============================] - 17s 211ms/step - loss: 0.1443 - accuracy: 0.9677 - val_loss: 0.1452 - val_accuracy: 0.9677
# Epoch 7/10
# 82/82 [==============================] - 17s 211ms/step - loss: 0.1443 - accuracy: 0.9677 - val_loss: 0.1452 - val_accuracy: 0.9677
# Epoch 8/10
# 82/82 [==============================] - 17s 211ms/step - loss: 0.1443 - accuracy: 0.9677 - val_loss: 0.1453 - val_accuracy: 0.9677
# Epoch 9/10
# 82/82 [==============================] - 17s 208ms/step - loss: 0.1444 - accuracy: 0.9677 - val_loss: 0.1450 - val_accuracy: 0.9677
# Epoch 10/10
# 82/82 [==============================] - 17s 209ms/step - loss: 0.1449 - accuracy: 0.9677 - val_loss: 0.1542 - val_accuracy: 0.9677
# 45/45 [==============================] - 9s 181ms/step
# Performing experiment with model: ModelType.LSTM_BG, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 4, optimizer: Adam, split: 0.1
# Epoch 1/10
# 82/82 [==============================] - 20s 216ms/step - loss: 0.1487 - accuracy: 0.9677 - val_loss: 0.1438 - val_accuracy: 0.9677
# Epoch 2/10
# Epoch 9/10
# 82/82 [==============================] - 18s 216ms/step - loss: 0.0113 - accuracy: 0.9962 - val_loss: 0.0085 - val_accuracy: 0.9969
# Epoch 10/10
# 82/82 [==============================] - 18s 215ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.0077 - val_accuracy: 0.9984
# 45/45 [==============================] - 9s 185ms/step
# Performing experiment with model: ModelType.LSTM_BG, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.0001, seed: 13, optimizer: Adam, split: 0.1
# Epoch 1/10
# 82/82 [==============================] - 20s 218ms/step - loss: 0.2391 - accuracy: 0.9449 - val_loss: 0.1335 - val_accuracy: 0.9677
# Epoch 2/10
# 82/82 [==============================] - 17s 213ms/step - loss: 0.0863 - accuracy: 0.9729 - val_loss: 0.0336 - val_accuracy: 0.9898
# Epoch 3/10
# 82/82 [==============================] - 17s 210ms/step - loss: 0.0251 - accuracy: 0.9915 - val_loss: 0.0184 - val_accuracy: 0.9937
# Epoch 4/10
# 82/82 [==============================] - 17s 214ms/step - loss: 0.0193 - accuracy: 0.9933 - val_loss: 0.0140 - val_accuracy: 0.9945
# Epoch 5/10
# 82/82 [==============================] - 17s 212ms/step - loss: 0.0167 - accuracy: 0.9940 - val_loss: 0.0119 - val_accuracy: 0.9961
# Epoch 6/10
# 82/82 [==============================] - 18s 215ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0102 - val_accuracy: 0.9969
# Epoch 7/10
# 82/82 [==============================] - 18s 217ms/step - loss: 0.0141 - accuracy: 0.9950 - val_loss: 0.0091 - val_accuracy: 0.9969
# Epoch 8/10
# 82/82 [==============================] - 18s 218ms/step - loss: 0.0131 - accuracy: 0.9953 - val_loss: 0.0084 - val_accuracy: 0.9969
# Epoch 9/10
# 82/82 [==============================] - 18s 218ms/step - loss: 0.0123 - accuracy: 0.9957 - val_loss: 0.0077 - val_accuracy: 0.9969
# Epoch 10/10
# 82/82 [==============================] - 18s 222ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.0070 - val_accuracy: 0.9969
# 45/45 [==============================] - 8s 180ms/step
# Performing experiment with model: ModelType.LSTM_BG, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.0001, seed: 4, optimizer: Adam, split: 0.1
# Epoch 1/10
# 82/82 [==============================] - 20s 219ms/step - loss: 0.1971 - accuracy: 0.9677 - val_loss: 0.1213 - val_accuracy: 0.9677
# Epoch 2/10
# 82/82 [==============================] - 18s 214ms/step - loss: 0.0700 - accuracy: 0.9752 - val_loss: 0.0292 - val_accuracy: 0.9898
# Epoch 3/10
# 82/82 [==============================] - 18s 214ms/step - loss: 0.0240 - accuracy: 0.9918 - val_loss: 0.0181 - val_accuracy: 0.9945
# Epoch 4/10
# 82/82 [==============================] - 18s 214ms/step - loss: 0.0181 - accuracy: 0.9937 - val_loss: 0.0128 - val_accuracy: 0.9945
# Epoch 5/10
# Epoch 10/10
# 82/82 [==============================] - 17s 213ms/step - loss: 0.1006 - accuracy: 0.9677 - val_loss: 0.0990 - val_accuracy: 0.9677
# 45/45 [==============================] - 8s 180ms/step
# ...
# Epoch 7/10
# 64/64 [==============================] - 14s 225ms/step - loss: 0.1499 - accuracy: 0.9677 - val_loss: 0.1564 - val_accuracy: 0.9677
# Epoch 8/10
# 64/64 [==============================] - 14s 222ms/step - loss: 0.1499 - accuracy: 0.9677 - val_loss: 0.1563 - val_accuracy: 0.9677
# Epoch 9/10
# 64/64 [==============================] - 14s 220ms/step - loss: 0.1499 - accuracy: 0.9677 - val_loss: 0.1562 - val_accuracy: 0.9677
# Epoch 10/10
# 64/64 [==============================] - 14s 219ms/step - loss: 0.1499 - accuracy: 0.9677 - val_loss: 0.1562 - val_accuracy: 0.9677
# 133/133 [==============================] - 25s 187ms/step
# Performing experiment with model: ModelType.LSTM_BG, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 13, optimizer: Adam, split: 0.3
# Epoch 1/10
# 64/64 [==============================] - 17s 229ms/step - loss: 0.1553 - accuracy: 0.9528 - val_loss: 0.1461 - val_accuracy: 0.9677
# Epoch 2/10
# 64/64 [==============================] - 14s 222ms/step - loss: 0.1445 - accuracy: 0.9677 - val_loss: 0.1467 - val_accuracy: 0.9677
# Epoch 3/10
# 64/64 [==============================] - 14s 221ms/step - loss: 0.1447 - accuracy: 0.9677 - val_loss: 0.1467 - val_accuracy: 0.9677
# Epoch 4/10
# 64/64 [==============================] - 14s 220ms/step - loss: 0.1447 - accuracy: 0.9677 - val_loss: 0.1467 - val_accuracy: 0.9677
# Epoch 5/10
# 64/64 [==============================] - 14s 220ms/step - loss: 0.1447 - accuracy: 0.9677 - val_loss: 0.1467 - val_accuracy: 0.9677
# Epoch 6/10
# 64/64 [==============================] - 14s 221ms/step - loss: 0.1447 - accuracy: 0.9677 - val_loss: 0.1467 - val_accuracy: 0.9677
# Epoch 7/10
# 64/64 [==============================] - 14s 221ms/step - loss: 0.1447 - accuracy: 0.9677 - val_loss: 0.1467 - val_accuracy: 0.9677
# Epoch 8/10
# 64/64 [==============================] - 14s 222ms/step - loss: 0.1447 - accuracy: 0.9677 - val_loss: 0.1467 - val_accuracy: 0.9677
# Epoch 9/10
# 64/64 [==============================] - 14s 222ms/step - loss: 0.1447 - accuracy: 0.9677 - val_loss: 0.1467 - val_accuracy: 0.9677
# Epoch 10/10
# 64/64 [==============================] - 14s 223ms/step - loss: 0.1447 - accuracy: 0.9677 - val_loss: 0.1467 - val_accuracy: 0.9677
# 133/133 [==============================] - 26s 189ms/step
# Performing experiment with model: ModelType.LSTM_BG, batch size: 128, epochs: 10, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 4, optimizer: Adam, split: 0.3
# Epoch 1/10
# 64/64 [==============================] - 17s 232ms/step - loss: 0.1496 - accuracy: 0.9677 - val_loss: 0.1517 - val_accuracy: 0.9677
# Epoch 2/10
# 64/64 [==============================] - 14s 225ms/step - loss: 0.1450 - accuracy: 0.9677 - val_loss: 0.1522 - val_accuracy: 0.9677
# Epoch 3/10
# 64/64 [==============================] - 14s 222ms/step - loss: 0.1451 - accuracy: 0.9677 - val_loss: 0.1520 - val_accuracy: 0.9677
# Epoch 4/10
# 64/64 [==============================] - 14s 225ms/step - loss: 0.1451 - accuracy: 0.9677 - val_loss: 0.1520 - val_accuracy: 0.9677
# Epoch 5/10
# 64/64 [==============================] - 14s 225ms/step - loss: 0.1451 - accuracy: 0.9677 - val_loss: 0.1519 - val_accuracy: 0.9677
# Epoch 6/10
# 64/64 [==============================] - 14s 226ms/step - loss: 0.1451 - accuracy: 0.9677 - val_loss: 0.1519 - val_accuracy: 0.9677
# Epoch 7/10
# 64/64 [==============================] - 14s 223ms/step - loss: 0.1451 - accuracy: 0.9677 - val_loss: 0.1519 - val_accuracy: 0.9677
# Epoch 8/10
# 64/64 [==============================] - 15s 227ms/step - loss: 0.1451 - accuracy: 0.9677 - val_loss: 0.1519 - val_accuracy: 0.9677
# Epoch 9/10
# 64/64 [==============================] - 15s 230ms/step - loss: 0.1451 - accuracy: 0.9677 - val_loss: 0.1519 - val_accuracy: 0.9677
# Epoch 10/10
# 64/64 [==============================] - 14s 226ms/step - loss: 0.1451 - accuracy: 0.9677 - val_loss: 0.1519 - val_accuracy: 0.9677
# 133/133 [==============================] - 25s 188ms/step
# Performing experiment with model: ModelType.LSTM_BG, batch size: 128, epochs: 50, augmentation: AugmentationTechnique.NoAugmentation, regularization: NoRegularization,learning rate: 0.01, seed: 4, optimizer: Adam, split: 0.1
# Epoch 1/50
# 64/64 [==============================] - 17s 231ms/step - loss: 0.1496 - accuracy: 0.9677 - val_loss: 0.1517 - val_accuracy: 0.9677
# Epoch 2/50
# 64/64 [==============================] - 14s 221ms/step - loss: 0.1450 - accuracy: 0.9677 - val_loss: 0.1522 - val_accuracy: 0.9677
# Epoch 3/50
# 64/64 [==============================] - 14s 222ms/step - loss: 0.1451 - accuracy: 0.9677 - val_loss: 0.1520 - val_accuracy: 0.9677
# Epoch 4/50
# 64/64 [==============================] - 14s 226ms/step - loss: 0.1451 - accuracy: 0.9677 - val_loss: 0.1520 - val_accuracy: 0.9677
# Epoch 5/50
# 64/64 [==============================] - 14s 224ms/step - loss: 0.1451 - accuracy: 0.9677 - val_loss: 0.1519 - val_accuracy: 0.9677
# Epoch 6/50
# 64/64 [==============================] - 15s 227ms/step - loss: 0.1451 - accuracy: 0.9677 - val_loss: 0.1519 - val_accuracy: 0.9677
# Epoch 7/50
# 64/64 [==============================] - 14s 226ms/step - loss: 0.1451 - accuracy: 0.9677 - val_loss: 0.1519 - val_accuracy: 0.9677
# Epoch 8/50
# 64/64 [==============================] - 14s 225ms/step - loss: 0.1451 - accuracy: 0.9677 - val_loss: 0.1519 - val_accuracy: 0.9677
# Epoch 9/50
# 64/64 [==============================] - 14s 226ms/step - loss: 0.1451 - accuracy: 0.9677 - val_loss: 0.1519 - val_accuracy: 0.9677
# Epoch 49/50
# 64/64 [==============================] - 14s 226ms/step - loss: 0.1451 - accuracy: 0.9677 - val_loss: 0.1519 - val_accuracy: 0.9677
# Epoch 50/50
# 64/64 [==============================] - 14s 226ms/step - loss: 0.1451 - accuracy: 0.9677 - val_loss: 0.1519 - val_accuracy: 0.9677
# 133/133 [==============================] - 25s 188ms/step
# [[0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 123, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>], [0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 42, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>], [0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 9, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>], [0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 13, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>], [0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 4, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>], [0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 123, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>, 'augmentation'], [0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 42, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>, 'augmentation'], [0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 9, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>, 'augmentation'], [0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 13, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>, 'augmentation'], [0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 4, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>, 'augmentation'], [0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 123, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>, 'optimizer-learning rate'], [0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 42, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>, 'optimizer-learning rate'], [0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 9, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>, 'optimizer-learning rate'], [0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 13, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>, 'optimizer-learning rate'], [0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.01, 10, 4, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>, 'optimizer-learning rate'], [0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.001, 10, 123, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>, 'optimizer-learning rate'], [0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.001, 10, 42, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>, 'optimizer-learning rate'], [0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 128, 0.001, 10, 9, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>, 'optimizer-learning rate'], [0.9656089345860663, <AugmentationTechnique.NoAugmentation: 0>, <Op ...
# [0.9656048696885526, 128, 0.01, 10, <AugmentationTechnique.NoAugmentation: 0>, <OptimizerType.Adam: 1>, 0.1, {'type': <RegularizationType.NoRegularization: 1>, 'value': 0}, <ModelType.LSTM_BG: 3>, 123]
# [<keras.src.callbacks.History object at 0x7cfaf3a749a0>]
# CPU times: user 4h 34min 4s, sys: 16min 28s, total: 4h 50min 32s
# Wall time: 4h 40min 1s

# %%
titleComment = " - whole"
with open("results-" + str(modelType.name) + titleComment, "wb") as my_csv:
    pickle.dump(results, my_csv)
with open("best-" + str(modelType.name) + titleComment, "wb") as my_csv:
    pickle.dump(best, my_csv)
with open("histories-" + str(modelType.name) + titleComment, "wb") as my_csv:
    pickle.dump(histories, my_csv)
if IS_IN_COLAB:
    shutil.copy(
        "/content/results-" + str(modelType.name) + titleComment,
        "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
    )
    shutil.copy(
        "/content/best-" + str(modelType.name) + titleComment,
        "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
    )
    shutil.copy(
        "/content/histories-" + str(modelType.name) + titleComment,
        "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
    )

# %% [markdown]
# # Results

# %% [markdown]
# ## Functions

# %%
def process50EpochsResults(results, best, histories, model, titleComment):
    # Plot training and validation accuracy
    plt.plot(
        histories[len(histories) - 1].history["accuracy"], label="Training Accuracy"
    )
    plt.plot(
        histories[len(histories) - 1].history["val_accuracy"],
        label="Validation Accuracy",
    )
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    title = (
        "50 epochs Training and Validation Accuracy " + str(model.name) + titleComment
    )
    plt.title(title)
    plt.legend()

    plt.savefig(
        str(model.name) + "-50epochs-TrainingandValidationLoss.png",
        format="png",
        bbox_inches="tight",
    )
    if IS_IN_COLAB:
        shutil.copy(
            "/content/" + str(model.name) + "-50epochs-TrainingandValidationLoss.png",
            "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
        )
    plt.show()

    # Plot training and validation loss
    plt.plot(histories[len(histories) - 1].history["loss"], label="Training Loss")
    plt.plot(histories[len(histories) - 1].history["val_loss"], label="Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    title = "50 epochs Training and Validation Loss " + str(model.name) + titleComment

    plt.title(title)
    plt.legend()

    plt.savefig(title + ".png", format="png", bbox_inches="tight")
    if IS_IN_COLAB:
        shutil.copy(
            "/content/" + title + ".png",
            "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
        )
    plt.show()

# %%
def finalModelTest(
    createModelArgs, fitModelArgs, testData, y_true, titleComment, labels
):
    model = createModel(**createModelArgs)
    # train the model
    history = model.fit(**fitModelArgs)

    # get accuracy
    y_pred = model.predict(testData)

    accuracy = accuracy_score(y_true, y_pred)

    # Plot training and validation accuracy
    plt.plot(history.history["accuracy"], label="Training Accuracy")
    plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    title = (
        createModelArgs["modelType"].name
        + " - Training and Validation Accuracy"
        + titleComment
    )
    plt.title(title)
    plt.legend()
    plt.savefig(title + ".png", format="png", bbox_inches="tight")
    if IS_IN_COLAB:
        shutil.copy(
            "/content/" + title + ".png",
            "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
        )
    plt.show()

    # Plot training and validation loss
    plt.plot(history.history["loss"], label="Training Loss")
    plt.plot(history.history["val_loss"], label="Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    title = (
        createModelArgs["modelType"].name
        + " - Training and Validation Loss"
        + titleComment
    )

    plt.title(title)
    plt.legend()
    plt.savefig(title + ".png", format="png", bbox_inches="tight")
    if IS_IN_COLAB:
        shutil.copy(
            "/content/" + title + ".png",
            "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
        )
    plt.show()

    # Plot confusion matrix
    conf_mat = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    plt.imshow(conf_mat, cmap=plt.cm.Blues)
    title = createModelArgs["modelType"].name + " - Confusion Matrix" + titleComment

    plt.title(title)
    plt.colorbar()
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")

    # Set tick labels
    plt.xticks(np.arange(len(labels)), labels, rotation=90)
    plt.yticks(np.arange(len(labels)), labels, rotation=0)
    plt.savefig(title + ".png", format="png", bbox_inches="tight")
    if IS_IN_COLAB:
        shutil.copy(
            "/content/" + title + ".png",
            "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
        )
    plt.show()

    print("Accuracy:", accuracy)
    return model

# %%
def processParametersResults(results, model, titleComment):
    resultsDf = pd.DataFrame(
        results,
        columns=[
            "accuracy",
            "augmentation",
            "optimizer",
            "batch size",
            "learning rate",
            "number of epochs",
            "seed",
            "split",
            "regularizer",
            "model",
            "section",
        ],
    )
    resultsDf["optimizer"] = resultsDf["optimizer"].apply(lambda x: x.name)
    resultsDf["augmentation"] = resultsDf["augmentation"].apply(lambda x: x.name)

    # Optimizer type and learning rate

    sns.boxplot(data=resultsDf, x="optimizer", y="accuracy", hue="learning rate")
    title = (
        str(model.name) + " - Accuracy per optimzier per learning rate" + titleComment
    )
    plt.title(title)
    plt.tight_layout()
    plt.savefig(title + ".png", format="png", bbox_inches="tight")
    if IS_IN_COLAB:
        shutil.copy(
            "/content/" + title + ".png",
            "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
        )
    plt.show()

    # Batch size

    sns.boxplot(data=resultsDf, x="batch size", y="accuracy")
    title = str(model.name) + " - Accuracy per batch size" + titleComment
    plt.title(title)
    plt.tight_layout()
    plt.savefig(title + ".png", format="png", bbox_inches="tight")
    if IS_IN_COLAB:
        shutil.copy(
            "/content/" + title + ".png",
            "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
        )
    plt.show()

    # Split
    sns.boxplot(data=resultsDf, x="split", y="accuracy")
    title = str(model.name) + " - Accuracy per split" + titleComment
    plt.title(title)
    plt.tight_layout()
    plt.savefig(title + ".png", format="png", bbox_inches="tight")
    if IS_IN_COLAB:
        shutil.copy(
            "/content/" + title + ".png",
            "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
        )
    plt.show()

# %%
def processParametersFilteredResults(results, model, titleComment, best):
    resultsDf = pd.DataFrame(
        results,
        columns=[
            "accuracy",
            "augmentation",
            "optimizer",
            "batch size",
            "learning rate",
            "number of epochs",
            "seed",
            "split",
            "regularizer",
            "model",
            "section",
        ],
    )
    resultsDf["optimizer"] = resultsDf["optimizer"].apply(lambda x: x.name)
    resultsDf["augmentation"] = resultsDf["augmentation"].apply(lambda x: x.name)

    bestDf = pd.DataFrame(
        [best],
        columns=[
            "accuracy",
            "batch size",
            "learning rate",
            "epochs",
            "augmentation",
            "optimizer",
            "split",
            "regularizer",
            "model",
            "seed",
        ],
    )

    # Optimizer type and learning rate

    sns.boxplot(
        data=resultsDf[resultsDf["section"] == "optimizer-learning rate"],
        x="optimizer",
        y="accuracy",
        hue="learning rate",
    )
    title = (
        str(model.name)
        + " - Accuracy per optimzier per learning rate - filtered"
        + titleComment
    )
    plt.title(title)
    plt.tight_layout()
    plt.savefig(title + ".png", format="png", bbox_inches="tight")
    if IS_IN_COLAB:
        shutil.copy(
            "/content/" + title + ".png",
            "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
        )
    plt.show()

    # Batch size

    sns.boxplot(
        data=resultsDf[resultsDf["section"] == "batch size"],
        x="batch size",
        y="accuracy",
    )
    title = str(model.name) + " - Accuracy per batch size - filtered" + titleComment
    plt.title(title)
    plt.tight_layout()
    plt.savefig(title + ".png", format="png", bbox_inches="tight")
    if IS_IN_COLAB:
        shutil.copy(
            "/content/" + title + ".png",
            "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
        )
    plt.show()

    # Split
    sns.boxplot(
        data=resultsDf[resultsDf["section"] == "split"], x="split", y="accuracy"
    )
    title = str(model.name) + " - Accuracy per split - filtered" + titleComment
    plt.title(title)
    plt.tight_layout()
    plt.savefig(title + ".png", format="png", bbox_inches="tight")
    if IS_IN_COLAB:
        shutil.copy(
            "/content/" + title + ".png",
            "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
        )
    plt.show()

# %%
def whisper_preprocess_data(row):
    signal_path = DATASET_DIR + row["label_name"] + "/" + row["path"]
    # Load waveform
    waveform, sample_rate = librosa.load(signal_path, mono=True, sr=None)
    label = row["label_name"]
    return waveform, label

# %%
def predict_with_whisper_on_row(row):
    global correct_predictions
    pd = whisper_preprocess_data(row)
    segments, _ = model.transcribe(pd[0])
    segments = list(segments)
    predicted_label = ""
    if segments:
        predicted_label = segments[0].text.strip().lower()
        predicted_label = (
            predicted_label.replace(".", "")
            .replace(",", "")
            .replace("!", "")
            .replace("?", "")
            .replace(" ", "")
        )
        predicted_label = (
            predicted_label.replace("5", "five")
            .replace("1", "one")
            .replace("2", "two")
            .replace("3", "three")
            .replace("4", "four")
            .replace("6", "six")
            .replace("7", "seven")
            .replace("8", "eight")
            .replace("9", "nine")
            .replace("0", "zero")
        )
    else:
        predicted_label = "_background_noise_"
    original_label = pd[1].strip().lower()

    if predicted_label == original_label:
        correct_predictions += 1

# %% [markdown]
# ## LSTM

# %% [markdown]
# ### LSTM - artificially removed background noise

# %%
model = ModelType.LSTM
titleComment = " - artificial"
if IS_IN_COLAB:
    with open(
        r"/content/results-" + str(model.name) + titleComment, "rb"
    ) as input_file:
        results = pickle.load(input_file)

    with open(r"/content/best-" + str(model.name) + titleComment, "rb") as input_file:
        best = pickle.load(input_file)

    with open(
        r"/content/histories-" + str(model.name) + titleComment, "rb"
    ) as input_file:
        histories = pickle.load(input_file)
else:
    with open(r"results-" + str(model.name) + titleComment, "rb") as input_file:
        results = pickle.load(input_file)

    with open(r"best-" + str(model.name) + titleComment, "rb") as input_file:
        best = pickle.load(input_file)

    with open(r"histories-" + str(model.name) + titleComment, "rb") as input_file:
        histories = pickle.load(input_file)

# %%
process50EpochsResults(results, best, histories, model, titleComment)

# %%
processParametersFilteredResults(results, model, titleComment, best)

# %%
processParametersResults(results, model, titleComment)

# %%
bestDf = pd.DataFrame(
    [best],
    columns=[
        "accuracy",
        "batch size",
        "learning rate",
        "epochs",
        "augmentation",
        "optimizer",
        "split",
        "regularizer",
        "model",
        "seed",
    ],
)

# %%
bestDf.head()
# Out:
#    accuracy  batch size  learning rate  epochs  \
# 0  0.691559         128          0.001      10
#
#                            augmentation           optimizer  split  \
# 0  AugmentationTechnique.NoAugmentation  OptimizerType.Lion    0.1
#
#                                          regularizer           model  seed
# 0  {'type': RegularizationType.NoRegularization, ...  ModelType.LSTM     4

# %%
batchSize = bestDf["batch size"][0]

set_seed(42)
train_split_dataset, val_split_dataset = train_test_split(
    data, stratify=data["label"], test_size=0.1
)
train_split_dataset, test_split_dataset = train_test_split(
    train_split_dataset,
    stratify=train_split_dataset["label"],
    test_size=bestDf["split"][0],
)
# train_split_dataset.head(int(len(train_split_dataset)/20))
trainDataGenerator = getDatasetGenerator(
    model, train_split_dataset, num_classes, batchSize
)
valDataGenerator = getDatasetGenerator(model, val_split_dataset, num_classes, batchSize)
testDataGenerator = getDatasetGenerator(
    model, test_split_dataset, num_classes, batchSize
)

y_true = []
for index, row in test_split_dataset.iterrows():
    y_true.append(row["label"])

# Switching to Adam instead of Lion, on larger dataset Adam seems to be better
createModelArgs = {
    "modelType": model,
    "optimizer": getOptimizer(
        optimizer_type=OptimizerType.Adam, learningRate=bestDf["learning rate"][0]
    ),
    "regularizer": {
        "type": bestDf["regularizer"][0]["type"],
        "value": bestDf["regularizer"][0]["value"],
    },
    "loss": "categorical_crossentropy",
    "metrics": ["accuracy"],
    "augmentation": bestDf["augmentation"][0],
    "seed": bestDf["seed"][0],
    "num_classes": num_classes,
}
fitModelArgs = {
    "batch_size": batchSize,
    "epochs": 10,
    "train_dataset": trainDataGenerator,
    "val_dataset": valDataGenerator,
}

# %%
# %%time
finalModelTest(
    createModelArgs, fitModelArgs, testDataGenerator, y_true, titleComment, labels
)
# Out:
# Epoch 1/10
# 410/410 [==============================] - 113s 232ms/step - loss: 1.7301 - accuracy: 0.4956 - val_loss: 0.8773 - val_accuracy: 0.7437
# Epoch 2/10
# 410/410 [==============================] - 94s 230ms/step - loss: 0.7302 - accuracy: 0.7831 - val_loss: 0.6215 - val_accuracy: 0.8183
# Epoch 3/10
# 410/410 [==============================] - 93s 228ms/step - loss: 0.5377 - accuracy: 0.8374 - val_loss: 0.5558 - val_accuracy: 0.8347
# Epoch 4/10
# 410/410 [==============================] - 94s 230ms/step - loss: 0.4382 - accuracy: 0.8680 - val_loss: 0.5256 - val_accuracy: 0.8441
# Epoch 5/10
# 410/410 [==============================] - 94s 230ms/step - loss: 0.3769 - accuracy: 0.8855 - val_loss: 0.4867 - val_accuracy: 0.8563
# Epoch 6/10
# 410/410 [==============================] - 94s 229ms/step - loss: 0.3281 - accuracy: 0.9012 - val_loss: 0.4999 - val_accuracy: 0.8543
# Epoch 7/10
# 410/410 [==============================] - 94s 229ms/step - loss: 0.2881 - accuracy: 0.9125 - val_loss: 0.5170 - val_accuracy: 0.8491
# Epoch 8/10
# 410/410 [==============================] - 94s 230ms/step - loss: 0.2621 - accuracy: 0.9201 - val_loss: 0.4907 - val_accuracy: 0.8579
# Epoch 9/10
# 410/410 [==============================] - 94s 230ms/step - loss: 0.2299 - accuracy: 0.9290 - val_loss: 0.4993 - val_accuracy: 0.8602
# Epoch 10/10
# 410/410 [==============================] - 94s 229ms/step - loss: 0.1951 - accuracy: 0.9405 - val_loss: 0.4941 - val_accuracy: 0.8617
# 46/46 [==============================] - 10s 201ms/step
# Accuracy: 0.865579399141631
# CPU times: user 15min 49s, sys: 54.2 s, total: 16min 43s
# Wall time: 16min 11s

# %% [markdown]
# ### LSTM - on a dataset with split background noise

# %%
model = ModelType.LSTM
titleComment = " - artificial"
if IS_IN_COLAB:
    with open(r"/content/best-" + str(model.name) + titleComment, "rb") as input_file:
        best = pickle.load(input_file)
else:
    with open(r"best-" + str(model.name) + titleComment, "rb") as input_file:
        best = pickle.load(input_file)

titleComment = " - with bg noise"

# %%
bestDf = pd.DataFrame(
    [best],
    columns=[
        "accuracy",
        "batch size",
        "learning rate",
        "epochs",
        "augmentation",
        "optimizer",
        "split",
        "regularizer",
        "model",
        "seed",
    ],
)

# %%
batchSize = bestDf["batch size"][0]

set_seed(42)
train_split_dataset, val_split_dataset = train_test_split(
    dfBackgroundNoise_new, stratify=dfBackgroundNoise_new["label"], test_size=0.1
)
train_split_dataset, test_split_dataset = train_test_split(
    train_split_dataset,
    stratify=train_split_dataset["label"],
    test_size=bestDf["split"][0],
)
# train_split_dataset.head(int(len(train_split_dataset)/20))
trainDataGenerator = getDatasetGenerator(
    model, train_split_dataset, num_classes_with_bg_noise, batchSize
)
valDataGenerator = getDatasetGenerator(
    model, val_split_dataset, num_classes_with_bg_noise, batchSize
)
testDataGenerator = getDatasetGenerator(
    model, test_split_dataset, num_classes_with_bg_noise, batchSize
)

y_true = []
for index, row in test_split_dataset.iterrows():
    y_true.append(row["label"])

# Switching to Adam instead of Lion, on larger dataset Adam seems to be better
createModelArgs = {
    "modelType": model,
    "optimizer": getOptimizer(
        optimizer_type=OptimizerType.Adam, learningRate=bestDf["learning rate"][0]
    ),
    "regularizer": {
        "type": bestDf["regularizer"][0]["type"],
        "value": bestDf["regularizer"][0]["value"],
    },
    "loss": "categorical_crossentropy",
    "metrics": ["accuracy"],
    "augmentation": bestDf["augmentation"][0],
    "seed": bestDf["seed"][0],
    "num_classes": num_classes_with_bg_noise,
}
fitModelArgs = {
    "batch_size": batchSize,
    "epochs": 10,
    "train_dataset": trainDataGenerator,
    "val_dataset": valDataGenerator,
}

# %%
# %%time
finalAcc = finalModelTest(
    createModelArgs,
    fitModelArgs,
    testDataGenerator,
    y_true,
    titleComment,
    labelsBackgroundNoise,
)
# Out:
# Epoch 1/10
# 397/397 [==============================] - 94s 230ms/step - loss: 1.7423 - accuracy: 0.4960 - val_loss: 0.9202 - val_accuracy: 0.7326
# Epoch 2/10
# 397/397 [==============================] - 91s 228ms/step - loss: 0.7303 - accuracy: 0.7860 - val_loss: 0.6533 - val_accuracy: 0.8087
# Epoch 3/10
# 397/397 [==============================] - 91s 229ms/step - loss: 0.5390 - accuracy: 0.8406 - val_loss: 0.5438 - val_accuracy: 0.8372
# Epoch 4/10
# 397/397 [==============================] - 91s 230ms/step - loss: 0.4362 - accuracy: 0.8690 - val_loss: 0.5199 - val_accuracy: 0.8406
# Epoch 5/10
# 397/397 [==============================] - 91s 229ms/step - loss: 0.3701 - accuracy: 0.8885 - val_loss: 0.4834 - val_accuracy: 0.8546
# Epoch 6/10
# 397/397 [==============================] - 91s 230ms/step - loss: 0.3203 - accuracy: 0.9040 - val_loss: 0.4595 - val_accuracy: 0.8628
# Epoch 7/10
# 397/397 [==============================] - 91s 230ms/step - loss: 0.2900 - accuracy: 0.9114 - val_loss: 0.4642 - val_accuracy: 0.8656
# Epoch 8/10
# 397/397 [==============================] - 91s 230ms/step - loss: 0.2575 - accuracy: 0.9219 - val_loss: 0.4649 - val_accuracy: 0.8660
# Epoch 9/10
# 397/397 [==============================] - 91s 230ms/step - loss: 0.2274 - accuracy: 0.9307 - val_loss: 0.4837 - val_accuracy: 0.8580
# Epoch 10/10
# 397/397 [==============================] - 92s 231ms/step - loss: 0.1979 - accuracy: 0.9400 - val_loss: 0.4996 - val_accuracy: 0.8596
# 45/45 [==============================] - 9s 196ms/step
# Accuracy: 0.8556993440879277
# CPU times: user 15min 9s, sys: 51.1 s, total: 16min 1s
# Wall time: 15min 26s

# %% [markdown]
# ### LSTM on a filtered dataset

# %%
model = ModelType.LSTM_BG
titleComment = " - whole"
if IS_IN_COLAB:
    with open(
        r"/content/results-" + str(model.name) + titleComment, "rb"
    ) as input_file:
        results = pickle.load(input_file)

    with open(r"/content/best-" + str(model.name) + titleComment, "rb") as input_file:
        best = pickle.load(input_file)

    with open(
        r"/content/histories-" + str(model.name) + titleComment, "rb"
    ) as input_file:
        histories = pickle.load(input_file)
else:
    with open(r"results-" + str(model.name) + titleComment, "rb") as input_file:
        results = pickle.load(input_file)

    with open(r"best-" + str(model.name) + titleComment, "rb") as input_file:
        best = pickle.load(input_file)

    with open(r"histories-" + str(model.name) + titleComment, "rb") as input_file:
        histories = pickle.load(input_file)

# %%
processParametersFilteredResults(results, model, titleComment, best)

# %%
bestDf = pd.DataFrame(
    [best],
    columns=[
        "accuracy",
        "batch size",
        "learning rate",
        "epochs",
        "augmentation",
        "optimizer",
        "split",
        "regularizer",
        "model",
        "seed",
    ],
)

# %%
bestDf.head()
# Out:
#    accuracy  batch size  learning rate  epochs  \
# 0  0.965605         128           0.01      10
#
#                            augmentation           optimizer  split  \
# 0  AugmentationTechnique.NoAugmentation  OptimizerType.Adam    0.1
#
#                                          regularizer              model  seed
# 0  {'type': RegularizationType.NoRegularization, ...  ModelType.LSTM_BG   123

# %%
batchSize = 256  # bestDf['batch size'][0]
learningRate = 0.00001  # bestDf['learning rate'][0]
set_seed(42)
train_split_dataset, val_split_dataset = train_test_split(
    normalisedBinaryBackgroundNoise,
    stratify=normalisedBinaryBackgroundNoise["label"],
    test_size=0.2,
)
train_split_dataset, test_split_dataset = train_test_split(
    train_split_dataset, stratify=train_split_dataset["label"], test_size=0.2
)
# train_split_dataset.head(int(len(train_split_dataset)/20))
trainDataGenerator = getDatasetGenerator(
    model, train_split_dataset, num_classes_with_bg_noise, batchSize
)
valDataGenerator = getDatasetGenerator(
    model, val_split_dataset, num_classes_with_bg_noise, batchSize
)
testDataGenerator = getDatasetGenerator(
    model, test_split_dataset, num_classes_with_bg_noise, batchSize
)
y_true = []
for index, row in test_split_dataset.iterrows():
    if row["label_name"] == "_background_noise_":
        y_true.append(1)
    else:
        y_true.append(0)

# Switching to Adam instead of Lion, on a larger dataset Adam seems to be better
createModelArgs = {
    "modelType": model,
    "optimizer": getOptimizer(
        optimizer_type=OptimizerType.Adam, learningRate=learningRate
    ),
    "regularizer": {
        "type": bestDf["regularizer"][0]["type"],
        "value": bestDf["regularizer"][0]["value"],
    },
    "loss": "categorical_crossentropy",
    "metrics": ["accuracy"],
    "augmentation": bestDf["augmentation"][0],
    "seed": bestDf["seed"][0],
    "num_classes": 2,
}
fitModelArgs = {
    "batch_size": batchSize,
    "epochs": 5,
    "train_dataset": trainDataGenerator,
    "val_dataset": valDataGenerator,
}

# %%
# %%time
filterDatasetModel = finalModelTest(
    createModelArgs, fitModelArgs, testDataGenerator, y_true, titleComment, [0, 1]
)
# Out:
# Epoch 1/5
# 11/11 [==============================] - 8s 547ms/step - loss: 0.6872 - accuracy: 0.5565 - val_loss: 0.6847 - val_accuracy: 0.6227
# Epoch 2/5
# 11/11 [==============================] - 5s 487ms/step - loss: 0.6777 - accuracy: 0.5815 - val_loss: 0.6770 - val_accuracy: 0.5440
# Epoch 3/5
# 11/11 [==============================] - 5s 500ms/step - loss: 0.6662 - accuracy: 0.5608 - val_loss: 0.6698 - val_accuracy: 0.5150
# Epoch 4/5
# 11/11 [==============================] - 5s 501ms/step - loss: 0.6572 - accuracy: 0.5398 - val_loss: 0.6628 - val_accuracy: 0.5093
# Epoch 5/5
# 11/11 [==============================] - 5s 498ms/step - loss: 0.6487 - accuracy: 0.5235 - val_loss: 0.6560 - val_accuracy: 0.5069
# 3/3 [==============================] - 1s 315ms/step
# Accuracy: 0.5007235890014472
# CPU times: user 32.3 s, sys: 2.17 s, total: 34.4 s
# Wall time: 32.6 s

# %%
# Filter the dataset
dfToFilter = dfBackgroundNoise_new.copy()
dataToFilterGenerator = getDatasetGenerator(
    model, dfToFilter, num_classes_with_bg_noise, batchSize
)

# %%
# %%time
predicted = filterDatasetModel.predict(dataToFilterGenerator)
# Out:
# 490/490 [==============================] - 90s 3ms/step
# CPU times: user 1min 26s, sys: 5.74 s, total: 1min 32s
# Wall time: 1min 30s

# %%
# There is no data shuffling involved so this should work just fine
for index, value in enumerate(predicted):
    if value == 1:
        dfToFilter = dfToFilter.drop(index)

# %%
dfBackgroundNoise_new.shape[0]
# Out:
# 62670

# %%
dfToFilter.shape[0]
# Out:
# 62670

# %%
model = ModelType.LSTM

titleComment = " - artificial"
if IS_IN_COLAB:
    with open(r"/content/best-" + str(model.name) + titleComment, "rb") as input_file:
        best = pickle.load(input_file)
else:
    with open(r"best-" + str(model.name) + titleComment, "rb") as input_file:
        best = pickle.load(input_file)

titleComment = " - filtered"

# %%
bestDf = pd.DataFrame(
    [best],
    columns=[
        "accuracy",
        "batch size",
        "learning rate",
        "epochs",
        "augmentation",
        "optimizer",
        "split",
        "regularizer",
        "model",
        "seed",
    ],
)

# %%
bestDf.head()

# %%
batchSize = bestDf["batch size"][0]

set_seed(42)
train_split_dataset, val_split_dataset = train_test_split(
    data, stratify=data["label"], test_size=0.1
)
train_split_dataset, test_split_dataset = train_test_split(
    train_split_dataset,
    stratify=train_split_dataset["label"],
    test_size=bestDf["split"][0],
)
# train_split_dataset.head(int(len(train_split_dataset)/20))
trainDataGenerator = getDatasetGenerator(
    model, train_split_dataset, num_classes, batchSize
)
valDataGenerator = getDatasetGenerator(model, val_split_dataset, num_classes, batchSize)
testDataGenerator = getDatasetGenerator(
    model, test_split_dataset, num_classes, batchSize
)

y_true = []
for index, row in test_split_dataset.iterrows():
    y_true.append(row["label"])

# Switching to Adam instead of Lion, on larger dataset Adam seems to be better
createModelArgs = {
    "modelType": model,
    "optimizer": getOptimizer(
        optimizer_type=OptimizerType.Adam, learningRate=bestDf["learning rate"][0]
    ),
    "regularizer": {
        "type": bestDf["regularizer"][0]["type"],
        "value": bestDf["regularizer"][0]["value"],
    },
    "loss": "categorical_crossentropy",
    "metrics": ["accuracy"],
    "augmentation": bestDf["augmentation"][0],
    "seed": bestDf["seed"][0],
    "num_classes": num_classes,
}
fitModelArgs = {
    "batch_size": batchSize,
    "epochs": 10,
    "train_dataset": trainDataGenerator,
    "val_dataset": valDataGenerator,
}

# %%
# %%time
finalModelTest(
    createModelArgs, fitModelArgs, testDataGenerator, y_true, titleComment, labels
)

# %% [markdown]
# ### LSTM - short - without bg noise

# %%
model = ModelType.LSTM
titleComment = " - artificial"
if IS_IN_COLAB:
    with open(r"/content/best-" + str(model.name) + titleComment, "rb") as input_file:
        best = pickle.load(input_file)
else:
    with open(r"best-" + str(model.name) + titleComment, "rb") as input_file:
        best = pickle.load(input_file)

titleComment = " - with bg noise"
model = ModelType.CustomLSTMShort

# %%
bestDf = pd.DataFrame(
    [best],
    columns=[
        "accuracy",
        "batch size",
        "learning rate",
        "epochs",
        "augmentation",
        "optimizer",
        "split",
        "regularizer",
        "model",
        "seed",
    ],
)

# %%
batchSize = bestDf["batch size"][0]

set_seed(42)
train_split_dataset, val_split_dataset = train_test_split(
    data, stratify=data["label"], test_size=0.1
)
train_split_dataset, test_split_dataset = train_test_split(
    train_split_dataset,
    stratify=train_split_dataset["label"],
    test_size=bestDf["split"][0],
)
# train_split_dataset.head(int(len(train_split_dataset)/20))
trainDataGenerator = getDatasetGenerator(
    model, train_split_dataset, num_classes, batchSize
)
valDataGenerator = getDatasetGenerator(model, val_split_dataset, num_classes, batchSize)
testDataGenerator = getDatasetGenerator(
    model, test_split_dataset, num_classes, batchSize
)

y_true = []
for index, row in test_split_dataset.iterrows():
    y_true.append(row["label"])

# Switching to Adam instead of Lion, on larger dataset Adam seems to be better
createModelArgs = {
    "modelType": model,
    "optimizer": getOptimizer(
        optimizer_type=OptimizerType.Adam, learningRate=bestDf["learning rate"][0]
    ),
    "regularizer": {
        "type": bestDf["regularizer"][0]["type"],
        "value": bestDf["regularizer"][0]["value"],
    },
    "loss": "categorical_crossentropy",
    "metrics": ["accuracy"],
    "augmentation": bestDf["augmentation"][0],
    "seed": bestDf["seed"][0],
    "num_classes": num_classes,
}
fitModelArgs = {
    "batch_size": batchSize,
    "epochs": 10,
    "train_dataset": trainDataGenerator,
    "val_dataset": valDataGenerator,
}

# %%
# %%time
finalModelTest(
    createModelArgs, fitModelArgs, testDataGenerator, y_true, titleComment, labels
)
# Out:
# Epoch 1/10
# 410/410 [==============================] - 94s 224ms/step - loss: 1.5959 - accuracy: 0.5318 - val_loss: 0.9173 - val_accuracy: 0.7255
# Epoch 2/10
# 410/410 [==============================] - 90s 218ms/step - loss: 0.8054 - accuracy: 0.7604 - val_loss: 0.7264 - val_accuracy: 0.7846
# Epoch 3/10
# 410/410 [==============================] - 90s 220ms/step - loss: 0.6382 - accuracy: 0.8087 - val_loss: 0.6594 - val_accuracy: 0.8055
# Epoch 4/10
# 410/410 [==============================] - 90s 219ms/step - loss: 0.5439 - accuracy: 0.8367 - val_loss: 0.6106 - val_accuracy: 0.8186
# Epoch 5/10
# 410/410 [==============================] - 90s 220ms/step - loss: 0.4809 - accuracy: 0.8543 - val_loss: 0.5824 - val_accuracy: 0.8260
# Epoch 6/10
# 410/410 [==============================] - 90s 219ms/step - loss: 0.4366 - accuracy: 0.8665 - val_loss: 0.5686 - val_accuracy: 0.8302
# Epoch 7/10
# 410/410 [==============================] - 90s 221ms/step - loss: 0.3985 - accuracy: 0.8790 - val_loss: 0.5709 - val_accuracy: 0.8344
# Epoch 8/10
# 410/410 [==============================] - 90s 219ms/step - loss: 0.3660 - accuracy: 0.8891 - val_loss: 0.5504 - val_accuracy: 0.8412
# Epoch 9/10
# 410/410 [==============================] - 91s 221ms/step - loss: 0.3429 - accuracy: 0.8953 - val_loss: 0.5353 - val_accuracy: 0.8497
# Epoch 10/10
# 410/410 [==============================] - 91s 221ms/step - loss: 0.3216 - accuracy: 0.9021 - val_loss: 0.5419 - val_accuracy: 0.8444
# 46/46 [==============================] - 9s 195ms/step
# Accuracy: 0.8537339055793991
# CPU times: user 14min 53s, sys: 53.6 s, total: 15min 47s
# Wall time: 15min 16s

# %% [markdown]
# ### LSTM - short - with bg noise

# %%
model = ModelType.LSTM
titleComment = " - artificial"
if IS_IN_COLAB:
    with open(r"/content/best-" + str(model.name) + titleComment, "rb") as input_file:
        best = pickle.load(input_file)
else:
    with open(r"best-" + str(model.name) + titleComment, "rb") as input_file:
        best = pickle.load(input_file)

titleComment = " - with bg noise"
model = ModelType.CustomLSTMShort

# %%
bestDf = pd.DataFrame(
    [best],
    columns=[
        "accuracy",
        "batch size",
        "learning rate",
        "epochs",
        "augmentation",
        "optimizer",
        "split",
        "regularizer",
        "model",
        "seed",
    ],
)

# %%
batchSize = bestDf["batch size"][0]

set_seed(42)
train_split_dataset, val_split_dataset = train_test_split(
    dfBackgroundNoise_new, stratify=dfBackgroundNoise_new["label"], test_size=0.1
)
train_split_dataset, test_split_dataset = train_test_split(
    train_split_dataset,
    stratify=train_split_dataset["label"],
    test_size=bestDf["split"][0],
)
# train_split_dataset.head(int(len(train_split_dataset)/20))
trainDataGenerator = getDatasetGenerator(
    model, train_split_dataset, num_classes_with_bg_noise, batchSize
)
valDataGenerator = getDatasetGenerator(
    model, val_split_dataset, num_classes_with_bg_noise, batchSize
)
testDataGenerator = getDatasetGenerator(
    model, test_split_dataset, num_classes_with_bg_noise, batchSize
)

y_true = []
for index, row in test_split_dataset.iterrows():
    y_true.append(row["label"])

# Switching to Adam instead of Lion, on larger dataset Adam seems to be better
createModelArgs = {
    "modelType": model,
    "optimizer": getOptimizer(
        optimizer_type=OptimizerType.Adam, learningRate=bestDf["learning rate"][0]
    ),
    "regularizer": {
        "type": bestDf["regularizer"][0]["type"],
        "value": bestDf["regularizer"][0]["value"],
    },
    "loss": "categorical_crossentropy",
    "metrics": ["accuracy"],
    "augmentation": bestDf["augmentation"][0],
    "seed": bestDf["seed"][0],
    "num_classes": num_classes_with_bg_noise,
}
fitModelArgs = {
    "batch_size": batchSize,
    "epochs": 10,
    "train_dataset": trainDataGenerator,
    "val_dataset": valDataGenerator,
}

# %%
# %%time
finalAcc = finalModelTest(
    createModelArgs,
    fitModelArgs,
    testDataGenerator,
    y_true,
    titleComment,
    labelsBackgroundNoise,
)
# Out:
# Epoch 1/10
# 397/397 [==============================] - 91s 222ms/step - loss: 1.6319 - accuracy: 0.5296 - val_loss: 1.0045 - val_accuracy: 0.7062
# Epoch 2/10
# 397/397 [==============================] - 87s 220ms/step - loss: 0.7908 - accuracy: 0.7677 - val_loss: 0.7144 - val_accuracy: 0.7905
# Epoch 3/10
# 397/397 [==============================] - 88s 221ms/step - loss: 0.6228 - accuracy: 0.8169 - val_loss: 0.6320 - val_accuracy: 0.8131
# Epoch 4/10
# 397/397 [==============================] - 88s 221ms/step - loss: 0.5329 - accuracy: 0.8429 - val_loss: 0.6221 - val_accuracy: 0.8147
# Epoch 5/10
# 397/397 [==============================] - 89s 224ms/step - loss: 0.4735 - accuracy: 0.8605 - val_loss: 0.5759 - val_accuracy: 0.8294
# Epoch 6/10
# 397/397 [==============================] - 89s 223ms/step - loss: 0.4301 - accuracy: 0.8724 - val_loss: 0.5768 - val_accuracy: 0.8296
# Epoch 7/10
# 397/397 [==============================] - 92s 231ms/step - loss: 0.3915 - accuracy: 0.8824 - val_loss: 0.5511 - val_accuracy: 0.8388
# Epoch 8/10
# 397/397 [==============================] - 88s 223ms/step - loss: 0.3581 - accuracy: 0.8923 - val_loss: 0.5312 - val_accuracy: 0.8478
# Epoch 9/10
# 397/397 [==============================] - 89s 223ms/step - loss: 0.3356 - accuracy: 0.8987 - val_loss: 0.5309 - val_accuracy: 0.8502
# Epoch 10/10
# 397/397 [==============================] - 88s 223ms/step - loss: 0.3175 - accuracy: 0.9033 - val_loss: 0.5347 - val_accuracy: 0.8516
# 45/45 [==============================] - 9s 193ms/step
# Accuracy: 0.8383265378478993
# CPU times: user 14min 37s, sys: 52.2 s, total: 15min 29s
# Wall time: 14min 59s

# %% [markdown]
# ## Whisper

# %%
modelType = "Whisper"

# %% [markdown]
# ### Whisper - Dataset with split background noise

# %%
_, test_df = train_test_split(
    dfBackgroundNoise_new, stratify=dfBackgroundNoise_new["label"], test_size=0.1
)

# %%
dfBackgroundNoise_new.groupby("label_name").count()
# Out:
#                     label  path
# label_name
# _background_noise_   2157  2157
# bed                  1713  1713
# bird                 1731  1731
# cat                  1733  1733
# dog                  1746  1746
# down                 2157  2157
# eight                2157  2157
# five                 2157  2157
# four                 2157  2157
# go                   2157  2157
# happy                1742  1742
# house                1750  1750
# left                 2157  2157
# marvin               1746  1746
# nine                 2157  2157
# no                   2157  2157
# off                  2157  2157
# on                   2157  2157
# one                  2157  2157
# right                2157  2157
# seven                2157  2157
# sheila               1734  1734
# six                  2157  2157
# stop                 2157  2157
# three                2157  2157
# tree                 1733  1733
# two                  2157  2157
# up                   2157  2157
# wow                  1745  1745
# yes                  2157  2157
# zero                 2157  2157

# %%
test_df.groupby("label_name").count()
# Out:
#                     label  path
# label_name
# _background_noise_    216   216
# bed                   171   171
# bird                  173   173
# cat                   173   173
# dog                   174   174
# down                  216   216
# eight                 216   216
# five                  216   216
# four                  216   216
# go                    216   216
# happy                 174   174
# house                 175   175
# left                  215   215
# marvin                174   174
# nine                  216   216
# no                    215   215
# off                   216   216
# on                    216   216
# one                   216   216
# right                 216   216
# seven                 216   216
# sheila                173   173
# six                   216   216
# stop                  216   216
# three                 215   215
# tree                  173   173
# two                   216   216
# up                    216   216
# wow                   174   174
# yes                   216   216
# zero                  216   216

# %%
# %%time
correct_predictions = 0
model = WhisperModel("base.en", device="auto", compute_type="float32")
test_df.apply(predict_with_whisper_on_row, axis=1)
print("Accuracy:", correct_predictions / len(test_df))
# Out:
# Accuracy: 0.8418701132918461
# CPU times: user 34min 10s, sys: 1h 11min 16s, total: 1h 45min 26s
# Wall time: 22min 7s

# %%
titleComment = " - whole"
with open("correctpredictions-" + str(modelType) + titleComment, "wb") as my_csv:
    pickle.dump(correct_predictions, my_csv)

if IS_IN_COLAB:
    shutil.copy(
        "/content/correctpredictions-" + str(modelType) + titleComment,
        "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
    )

# %% [markdown]
# ### Dataset with artificially removed background noise

# %%
_, test_df = train_test_split(data, stratify=data["label"], test_size=0.1)

# %%
# %%time
correct_predictions = 0
model = WhisperModel("base.en", device="auto", compute_type="float32")
test_df.apply(predict_with_whisper_on_row, axis=1)
print("Accuracy:", correct_predictions / len(test_df))
# Out:
# Accuracy: 0.8648231113857562
# CPU times: user 35min 48s, sys: 1h 13min 25s, total: 1h 49min 13s
# Wall time: 23min 13s

# %%
titleComment = " - artificial"
with open("correctpredictions-" + str(modelType) + titleComment, "wb") as my_csv:
    pickle.dump(correct_predictions, my_csv)

if IS_IN_COLAB:
    shutil.copy(
        "/content/correctpredictions-" + str(modelType) + titleComment,
        "/content/drive/MyDrive/Studia/Masters/DeepLearning/Project2/Results/",
    )

# %% [markdown]
# # CAREFUL: Disconnect from colab

# %%
if IS_IN_COLAB:
    from google.colab import runtime

    runtime.unassign()
